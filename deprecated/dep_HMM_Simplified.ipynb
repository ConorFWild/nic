# %%
# Magics

# %%
# Imports

# %%
import argparse
import logging
import sys
from pathlib import Path

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.distributions import constraints

import pyro
import pyro.contrib.examples.polyphonic_data_loader as poly
import pyro.distributions as dist
from pyro import poutine
from pyro.infer import SVI, JitTraceEnum_ELBO, TraceEnum_ELBO, TraceTMC_ELBO
from pyro.infer.autoguide import AutoDelta
from pyro.ops.indexing import Vindex
from pyro.optim import Adam
from pyro.util import ignore_jit_warnings

# %%
# Settings

# %%
emission_matrix_path = Path("/nic/emission_matrix.npy")
dataset_path = Path("/nic/sequences.npy")

# %%
# Code

# %%
# Dataset loading
def load_sequences(dataset_path):
    sequences = {"train": {}}
    
#     sequence_list = [torch.Tensor(x) for x in np.load(str(dataset_path))]
    
    sequences_tensor = torch.Tensor(np.load(str(dataset_path))).to(torch.int)
    
    
    sequences["train"]["sequence_lengths"] = torch.Tensor(np.array([len(sequence) for sequence in sequences_tensor])).to(torch.int)
    sequences["train"]["sequences"] = sequences_tensor
    return sequences

# %%
def emission(x):
    return None

# %%
def model_0(sequences, lengths, emission_matrix, args, batch_size=None, include_prior=True):
    with ignore_jit_warnings():
        num_sequences, max_length = map(int, sequences.shape)
        assert lengths.shape == (num_sequences,)
        assert lengths.max() <= max_length
        
    data_dim = 7
    
#     print(sequences)
#     print(lengths)
#     print(num_sequences)
#     print(max_length)


    with poutine.mask(mask=include_prior):
        probs_x = pyro.sample("probs_x",
                              dist.Dirichlet(0.9 * torch.eye(7) + 0.1)
                                  .to_event(1))
        
    with pyro.plate("sequences", num_sequences, batch_size, dim=-2) as batch:
        lengths = lengths[batch]
        
        x = (6* torch.ones(batch_size)).to(torch.int)
        y = (6 * torch.ones(batch_size)).to(torch.int)
        
        for t in pyro.markov(range(max_length if args.jit else lengths.max())):
            with poutine.mask(mask=(t < lengths).unsqueeze(-1)):
#                 print(f"prob_x: {x} {x} {probs_x[x]}")
                x = pyro.sample("x_{}".format(t), dist.Categorical(probs_x[x]),
                                infer={"enumerate": "parallel"})
#                 print(f"prob_x_sampled: {x} {x} {probs_x[x].shape}")
                
                # Note that since each tone depends on all tones at a previous time step
                # the tones at different time steps now need to live in separate plates.
                with pyro.plate("tones_{}".format(t), data_dim, dim=-1):
                    p_y_t = emission_matrix[x]
#                     print(f"p_y_t: {p_y_t.shape}")
                    y = pyro.sample("y_{}".format(t),
                                    dist.Categorical(p_y_t).expand([8, 1]),#.to_event(1),
                                    obs=sequences[batch, t],
                                   )

# %%
def model_0(sequences, lengths, emission_matrix, args, batch_size=None, include_prior=True, prediction=False):
    with ignore_jit_warnings():
        num_sequences, max_length = map(int, sequences.shape)
        assert lengths.shape == (num_sequences,)
        assert lengths.max() <= max_length
        
    data_dim = 7
    
#     print(sequences)
#     print(lengths)
#     print(num_sequences)
#     print(max_length)


    with poutine.mask(mask=include_prior):
        probs_x = pyro.sample("probs_x",
                              dist.Dirichlet(0.9 * torch.eye(7) + 0.1)
                                  .to_event(1))

    tones_plate = pyro.plate("tones", data_dim, dim=-1)


    for i in pyro.plate("sequences", len(sequences), batch_size):
        length = lengths[i]
        sequence = sequences[i, :length]
        if prediction:
            print(f"{i} {length} {sequence}")
        x = 6
        for t in pyro.markov(range(length)):
            # On the next line, we'll overwrite the value of x with an updated
            # value. If we wanted to record all x values, we could instead
            # write x[t] = pyro.sample(...x[t-1]...).
            x = pyro.sample("x_{}_{}".format(i, t), dist.Categorical(probs_x[x]),
                            infer={"enumerate": "parallel"})
            with tones_plate:
                p_y_t = emission_matrix[x]

                pyro.sample("y_{}_{}".format(i, t), 
                            dist.Categorical(p_y_t),
                            obs=sequence[t])
        
#         for t in pyro.markov(range(max_length if args.jit else lengths.max())):
#             with poutine.mask(mask=(t < lengths).unsqueeze(-1)):
# #                 print(f"prob_x: {x}")
#                 x = pyro.sample("x_{}".format(t), dist.Categorical(probs_x[x]),
#                                 infer={"enumerate": "parallel"})
#                 print(f"prob_x_sampled: {x.shape}")
                
#                 # Note that since each tone depends on all tones at a previous time step
#                 # the tones at different time steps now need to live in separate plates.
#                 with pyro.plate("tones_{}".format(t), data_dim, dim=-1):
#                     p_y_t = emission_matrix[x]
#                     print(f"p_y_t: {p_y_t.shape}")
#                     y = pyro.sample("y_{}".format(t),
#                                     dist.Categorical(p_y_t).expand([8, 1]),#.to_event(1),
#                                     obs=sequences[batch, t],
#                                    )

# %%
def model_0(sequences, lengths, emission_matrix, args, batch_size=None, include_prior=True, prediction=False):
    with ignore_jit_warnings():
        num_sequences, max_length = map(int, sequences.shape)
        assert lengths.shape == (num_sequences,)
        assert lengths.max() <= max_length
        
    data_dim = 7
    
#     print(sequences)
#     print(lengths)
#     print(num_sequences)
#     print(max_length)


    with poutine.mask(mask=include_prior):
        probs_x = pyro.sample("probs_x",
                              dist.Dirichlet(0.9 * torch.eye(7) + 0.1)
                                  .to_event(1))

    tones_plate = pyro.plate("tones", data_dim, dim=-1)


    for i in pyro.plate("sequences", len(sequences)):
        length = lengths[i]
        sequence = sequences[i, :length]
        if prediction:
            print(f"{i} {length} {sequence}")
        x = 6
        for t in pyro.markov(range(length)):
            # On the next line, we'll overwrite the value of x with an updated
            # value. If we wanted to record all x values, we could instead
            # write x[t] = pyro.sample(...x[t-1]...).
            x = pyro.sample("x_{}_{}".format(i, t), dist.Categorical(probs_x[x]),
                            infer={"enumerate": "parallel"})
            with tones_plate:
                p_y_t = emission_matrix[x]

                pyro.sample("y_{}_{}".format(i, t), 
                            dist.Categorical(p_y_t),
                            obs=sequence[t])
        
#         for t in pyro.markov(range(max_length if args.jit else lengths.max())):
#             with poutine.mask(mask=(t < lengths).unsqueeze(-1)):
# #                 print(f"prob_x: {x}")
#                 x = pyro.sample("x_{}".format(t), dist.Categorical(probs_x[x]),
#                                 infer={"enumerate": "parallel"})
#                 print(f"prob_x_sampled: {x.shape}")
                
#                 # Note that since each tone depends on all tones at a previous time step
#                 # the tones at different time steps now need to live in separate plates.
#                 with pyro.plate("tones_{}".format(t), data_dim, dim=-1):
#                     p_y_t = emission_matrix[x]
#                     print(f"p_y_t: {p_y_t.shape}")
#                     y = pyro.sample("y_{}".format(t),
#                                     dist.Categorical(p_y_t).expand([8, 1]),#.to_event(1),
#                                     obs=sequences[batch, t],
#                                    )

# %%
# Utility function to print latent sites' quantile information.
def summary(samples):
    site_stats = {}
    for site_name, values in samples.items():
        marginal_site = pd.DataFrame(values)
        describe = marginal_site.describe(percentiles=[.05, 0.25, 0.5, 0.75, 0.95]).transpose()
        site_stats[site_name] = describe[["mean", "std", "5%", "25%", "50%", "75%", "95%"]]
    return site_stats

# %%
def main(args):
    if args.cuda:
        torch.set_default_tensor_type('torch.cuda.FloatTensor')

    logging.info('Loading data')
    data = load_sequences(args.dataset_path)

    logging.info('-' * 40)
    model = model_0
    logging.info('Training {} on {} sequences'.format(
        model.__name__, len(data['train']['sequences'])))
    
    sequences = data['train']['sequences']
#     print(sequences)
    lengths = data['train']['sequence_lengths']
#     print(lengths)
    
    emission_matrix_np = np.load(args.emission_matrix_path)
    emission_matrix = torch.Tensor(emission_matrix_np)
    # find all the notes that are present at least once in the training set
#     present_notes = ((sequences == 1).sum(0).sum(0) > 0)
    # remove notes that are never played (we remove 37/88 notes)
#     sequences = sequences[..., present_notes]

    if args.truncate:
        lengths = lengths.clamp(max=args.truncate)
        sequences = sequences[:, :args.truncate]
    num_observations = float(lengths.sum())
    pyro.set_rng_seed(args.seed)
    pyro.clear_param_store()

    # We'll train using MAP Baum-Welch, i.e. MAP estimation while marginalizing
    # out the hidden state x. This is accomplished via an automatic guide that
    # learns point estimates of all of our conditional probability tables,
    # named probs_*.
    guide = AutoDelta(poutine.block(model, expose_fn=lambda msg: msg["name"].startswith("probs_")))

    # To help debug our tensor shapes, let's print the shape of each site's
    # distribution, value, and log_prob tensor. Note this information is
    # automatically printed on most errors inside SVI.
#     if args.print_shapes:
    first_available_dim = -2 if model is model_0 else -3
    guide_trace = poutine.trace(guide).get_trace(
        sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size)
    model_trace = poutine.trace(
        poutine.replay(poutine.enum(model, first_available_dim), guide_trace)).get_trace(
        sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size)
    logging.info(model_trace.format_shapes())
    print(model_trace.format_shapes())

    # Enumeration requires a TraceEnum elbo and declaring the max_plate_nesting.
    # All of our models have two plates: "data" and "tones".
    optim = Adam({'lr': args.learning_rate})
    if args.tmc:
        if args.jit:
            raise NotImplementedError("jit support not yet added for TraceTMC_ELBO")
        elbo = TraceTMC_ELBO(max_plate_nesting=1 if model is model_0 else 2)
        tmc_model = poutine.infer_config(
            model,
            lambda msg: {"num_samples": args.tmc_num_samples, "expand": False} if msg["infer"].get("enumerate", None) == "parallel" else {})  # noqa: E501
        svi = SVI(tmc_model, guide, optim, elbo)
    else:
        Elbo = JitTraceEnum_ELBO if args.jit else TraceEnum_ELBO
        elbo = Elbo(max_plate_nesting= 2,
                    strict_enumeration_warning=True,
                    jit_options={"time_compilation": args.time_compilation})
        svi = SVI(model, guide, optim, elbo)

    # We'll train on small minibatches.
    logging.info('Step\tLoss')
    for step in range(args.num_steps):
        print(f"\tTraining step: {step}")
        loss = svi.step(sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size)
        logging.info('{: >5d}\t{}'.format(step, loss / num_observations))
        print('\t{: >5d}\t{}'.format(step, loss / num_observations))
        
    return svi, model, guide, sequences, lengths, emission_matrix

    from pyro.infer import Predictive


    num_samples = 1000
    predictive = Predictive(model, guide=guide, num_samples=num_samples)
    svi_samples = {k: v.detach().cpu().numpy()
               for k, v in predictive(sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size, prediction=True).items()
               if k != "obs"}
    
    print(svi_samples)
    
    for site, values in summary(svi_samples).items():
        print("Site: {}".format(site))
        print(values, "\n")
        

        
    print(pyro.param("probs_x").item())

    if args.jit and args.time_compilation:
        logging.debug('time to compile: {} s.'.format(elbo._differentiable_loss.compile_time))

    # We evaluate on the entire training dataset,
    # excluding the prior term so our results are comparable across models.
    train_loss = elbo.loss(model, guide, sequences, lengths, emission_matrix, args, include_prior=False)
    logging.info('training loss = {}'.format(train_loss / num_observations))
    print('training loss = {}'.format(train_loss / num_observations))

    # We expect models with higher capacity to perform better,
    # but eventually overfit to the training set.
    capacity = sum(value.reshape(-1).size(0)
                   for value in pyro.get_param_store().values())
    logging.info('{} capacity = {} parameters'.format(model.__name__, capacity))
    print('{} capacity = {} parameters'.format(model.__name__, capacity))

# %%
# Content

# %%
assert pyro.__version__.startswith('1.6.0')
parser = argparse.ArgumentParser(description="MAP Baum-Welch learning Bach Chorales")

parser.add_argument("-n", "--num-steps", default=100, type=int)
parser.add_argument("-b", "--batch-size", default=1, type=int)
parser.add_argument("-d", "--hidden-dim", default=16, type=int)
parser.add_argument("-nn", "--nn-dim", default=48, type=int)
parser.add_argument("-nc", "--nn-channels", default=2, type=int)
parser.add_argument("-lr", "--learning-rate", default=0.05, type=float)
parser.add_argument("-t", "--truncate", type=int)
parser.add_argument("-p", "--print-shapes", action="store_true")
parser.add_argument("--seed", default=0, type=int)
parser.add_argument('--cuda', action='store_true')
parser.add_argument('--jit', action='store_true')
parser.add_argument('--time-compilation', action='store_true')
parser.add_argument('-rp', '--raftery-parameterization', action='store_true')
parser.add_argument('--tmc', action='store_true',
                    help="Use Tensor Monte Carlo instead of exact enumeration "
                         "to estimate the marginal likelihood. You probably don't want to do this, "
                         "except to see that TMC makes Monte Carlo gradient estimation feasible "
                         "even with very large numbers of non-reparametrized variables.")
parser.add_argument('--tmc-num-samples', default=10, type=int)

parser.add_argument("--dataset_path")
parser.add_argument("--emission_matrix_path")
# Out:
# _StoreAction(option_strings=['--emission_matrix_path'], dest='emission_matrix_path', nargs=None, const=None, default=None, type=None, choices=None, help=None, metavar=None)

# %%
args = parser.parse_args(["--dataset_path", f"{str(dataset_path)}", "--emission_matrix_path", f"{str(emission_matrix_path)}"])

# %%
args
# Out:
# Namespace(batch_size=1, cuda=False, dataset_path='\\nic\\sequences.npy', emission_matrix_path='\\nic\\emission_matrix.npy', hidden_dim=16, jit=False, learning_rate=0.05, nn_channels=2, nn_dim=48, num_steps=100, print_shapes=False, raftery_parameterization=False, seed=0, time_compilation=False, tmc=False, tmc_num_samples=10, truncate=None)

# %%
svi, model, guide, sequences, lengths, emission_matrix = main(args)
# Out:
#  Trace Shapes:
#   Param Sites:
#  Sample Sites:
#   probs_x dist         | 7 7
#          value         | 7 7
#     tones dist         |
#          value       7 |
# sequences dist         |
#          value     172 |
#     x_0_0 dist         |
#          value   7   1 |
#     y_0_0 dist   7   7 |
#          value         |
#     x_0_1 dist   7   1 |
#          value 7 1   1 |
#     y_0_1 dist 7 1   7 |
#          value         |
#     x_0_2 dist 7 1   1 |
#          value   7   1 |
#     y_0_2 dist   7   7 |
#          value         |
#     x_0_3 dist   7   1 |
#          value 7 1   1 |
#     y_0_3 dist 7 1   7 |
#          value         |
#     x_0_4 dist 7 1   1 |
#          value   7   1 |
#     y_0_4 dist   7   7 |
#          value         |
#     x_0_5 dist   7   1 |
#          value 7 1   1 |
#     y_0_5 dist 7 1   7 |
#          value         |
#     x_0_6 dist 7 1   1 |
#          value   7   1 |
#     y_0_6 dist   7   7 |
#          value         |
#     x_0_7 dist   7   1 |
#          value 7 1   1 |
#     y_0_7 dist 7 1   7 |
#          value         |
#     x_0_8 dist 7 1   1 |
#          value   7   1 |
#     y_0_8 dist   7   7 |
#          value         |
#     x_0_9 dist   7   1 |
#          value 7 1   1 |
#     y_0_9 dist 7 1   7 |
#          value         |
#    x_0_10 dist 7 1   1 |
#          value   7   1 |
#    y_0_10 dist   7   7 |
#          value         |
#    x_0_11 dist   7   1 |
#          value 7 1   1 |
#    y_0_11 dist 7 1   7 |
#          value         |
#    x_0_12 dist 7 1   1 |
#          value   7   1 |
#    y_0_12 dist   7   7 |
#          value         |
#    x_0_13 dist   7   1 |
#          value 7 1   1 |
#    y_0_13 dist 7 1   7 |
#          value         |
#    x_0_14 dist 7 1   1 |
#          value   7   1 |
#    y_0_14 dist   7   7 |
#          value         |
#    x_0_15 dist   7   1 |
#          value 7 1   1 |
#    y_0_15 dist 7 1   7 |
#          value         |
#    x_0_16 dist 7 1   1 |
#          value   7   1 |
#    y_0_16 dist   7   7 |
#          value         |
#    x_0_17 dist   7   1 |
#          value 7 1   1 |
#    y_0_17 dist 7 1   7 |
#          value         |
#    x_0_18 dist 7 1   1 |
#          value   7   1 |
#    y_0_18 dist   7   7 |
#          value         |
#    x_0_19 dist   7   1 |
#          value 7 1   1 |
#    y_0_19 dist 7 1   7 |
#          value         |
#     x_1_0 dist         |
#          value   7   1 |
#     y_1_0 dist   7   7 |
#          value         |
#     x_1_1 dist   7   1 |
#          value 7 1   1 |
#     y_1_1 dist 7 1   7 |
#          value         |
#     x_1_2 dist 7 1   1 |
#          value   7   1 |
#     y_1_2 dist   7   7 |
#          value         |
#     x_1_3 dist   7   1 |
#          value 7 1   1 |
#     y_1_3 dist 7 1   7 |
#          value         |
#     x_1_4 dist 7 1   1 |
#          value   7   1 |
#     y_1_4 dist   7   7 |
#          value         |
#     x_1_5 dist   7   1 |
#          value 7 1   1 |
#     y_1_5 dist 7 1   7 |
#          value         |
#     x_1_6 dist 7 1   1 |
#          value   7   1 |
#     y_1_6 dist   7   7 |
#          value         |
#     x_1_7 dist   7   1 |
#          value 7 1   1 |
#     y_1_7 dist 7 1   7 |
#          value         |
#     x_1_8 dist 7 1   1 |
#          value   7   1 |
#     y_1_8 dist   7   7 |
#          value         |
#     x_1_9 dist   7   1 |
#          value 7 1   1 |
#     y_1_9 dist 7 1   7 |
#          value         |
#    x_1_10 dist 7 1   1 |
#          value   7   1 |
#    y_1_10 dist   7   7 |
#          value         |
#    x_1_11 dist   7   1 |
#          value 7 1   1 |
#    y_1_11 dist 7 1   7 |
#          value         |
#    x_1_12 dist 7 1   1 |
#          value   7   1 |
#    y_1_12 dist   7   7 |
#          value         |
#    x_1_13 dist   7   1 |
#          value 7 1   1 |
#    y_1_13 dist 7 1   7 |
#          value         |
#    x_1_14 dist 7 1   1 |
#          value   7   1 |
#    y_1_14 dist   7   7 |
#          value         |
#    x_1_15 dist   7   1 |
#          value 7 1   1 |
#    y_1_15 dist 7 1   7 |
#          value         |
#    x_1_16 dist 7 1   1 |
#          value   7   1 |
#    y_1_16 dist   7   7 |
#          value         |
#    x_1_17 dist   7   1 |
#          value 7 1   1 |
#    y_1_17 dist 7 1   7 |
#          value         |
#    x_1_18 dist 7 1   1 |
#          value   7   1 |
#    y_1_18 dist   7   7 |
#          value         |
#    x_1_19 dist   7   1 |
#          value 7 1   1 |
#    y_1_19 dist 7 1   7 |
#          value         |
#     x_2_0 dist         |
#          value   7   1 |
#     y_2_0 dist   7   7 |
#          value         |
#     x_2_1 dist   7   1 |
#          value 7 1   1 |
#     y_2_1 dist 7 1   7 |
#          value         |
#     x_2_2 dist 7 1   1 |
#          value   7   1 |
#     y_2_2 dist   7   7 |
#          value         |
#     x_2_3 dist   7   1 |
#          value 7 1   1 |
#     y_2_3 dist 7 1   7 |
#          value         |
#     x_2_4 dist 7 1   1 |
#          value   7   1 |
#     y_2_4 dist   7   7 |
#          value         |
#     x_2_5 dist   7   1 |
#          value 7 1   1 |
#     y_2_5 dist 7 1   7 |
#          value         |
#     x_2_6 dist 7 1   1 |
#          value   7   1 |
#     y_2_6 dist   7   7 |
#          value         |
#     x_2_7 dist   7   1 |
#          value 7 1   1 |
#     y_2_7 dist 7 1   7 |
#          value         |
#     x_2_8 dist 7 1   1 |
#          value   7   1 |
#     y_2_8 dist   7   7 |
#          value         |
#     x_2_9 dist   7   1 |
#          value 7 1   1 |
#     y_2_9 dist 7 1   7 |
#          value         |
#    x_2_10 dist 7 1   1 |
#          value   7   1 |
#    y_2_10 dist   7   7 |
#          value         |
#    x_2_11 dist   7   1 |
#          value 7 1   1 |
#    y_2_11 dist 7 1   7 |
#          value         |
#    x_2_12 dist 7 1   1 |
#          value   7   1 |
#    y_2_12 dist   7   7 |
#          value         |
#    x_2_13 dist   7   1 |
#          value 7 1   1 |
#    y_2_13 dist 7 1   7 |
#          value         |
#    x_2_14 dist 7 1   1 |
#          value   7   1 |
#    y_2_14 dist   7   7 |
#          value         |
#    x_2_15 dist   7   1 |
#          value 7 1   1 |
#    y_2_15 dist 7 1   7 |
#          value         |
#    x_2_16 dist 7 1   1 |
#          value   7   1 |
#    y_2_16 dist   7   7 |
#          value         |
#    x_2_17 dist   7   1 |
#          value 7 1   1 |
#    y_2_17 dist 7 1   7 |
#          value         |
#    x_2_18 dist 7 1   1 |
#          value   7   1 |
#    y_2_18 dist   7   7 |
#          value         |
#    x_2_19 dist   7   1 |
#          value 7 1   1 |
#    y_2_19 dist 7 1   7 |
#          value         |
#     x_3_0 dist         |
#          value   7   1 |
#     y_3_0 dist   7   7 |
#          value         |
#     x_3_1 dist   7   1 |
#          value 7 1   1 |
#     y_3_1 dist 7 1   7 |
#          value         |
#     x_3_2 dist 7 1   1 |
#          value   7   1 |
#     y_3_2 dist   7   7 |
#          value         |
#     x_3_3 dist   7   1 |
#          value 7 1   1 |
#     y_3_3 dist 7 1   7 |
#          value         |
#     x_3_4 dist 7 1   1 |
#          value   7   1 |
#     y_3_4 dist   7   7 |
#          value         |
#     x_3_5 dist   7   1 |
#          value 7 1   1 |
#     y_3_5 dist 7 1   7 |
#          value         |
#     x_3_6 dist 7 1   1 |
#          value   7   1 |
#     y_3_6 dist   7   7 |
#          value         |
#     x_3_7 dist   7   1 |
#          value 7 1   1 |
#     y_3_7 dist 7 1   7 |
#          value         |
#     x_3_8 dist 7 1   1 |
#          value   7   1 |
#     y_3_8 dist   7   7 |
#          value         |
#     x_3_9 dist   7   1 |
#          value 7 1   1 |
#     y_3_9 dist 7 1   7 |
#          value         |
#    x_3_10 dist 7 1   1 |
#          value   7   1 |
#    y_3_10 dist   7   7 |
#          value         |
#    x_3_11 dist   7   1 |
#          value 7 1   1 |
#    y_3_11 dist 7 1   7 |
#          value         |
#    x_3_12 dist 7 1   1 |
#          value   7   1 |
#    y_3_12 dist   7   7 |
#          value         |
#    x_3_13 dist   7   1 |
#          value 7 1   1 |
#    y_3_13 dist 7 1   7 |
#          value         |
#    x_3_14 dist 7 1   1 |
#          value   7   1 |
#    y_3_14 dist   7   7 |
#          value         |
#    x_3_15 dist   7   1 |
#          value 7 1   1 |
#    y_3_15 dist 7 1   7 |
#          value         |
#    x_3_16 dist 7 1   1 |
#          value   7   1 |
#    y_3_16 dist   7   7 |
#          value         |
#    x_3_17 dist   7   1 |
#          value 7 1   1 |
#    y_3_17 dist 7 1   7 |
#          value         |
#    x_3_18 dist 7 1   1 |
#          value   7   1 |
#    y_3_18 dist   7   7 |
#          value         |
#    x_3_19 dist   7   1 |
#          value 7 1   1 |
#    y_3_19 dist 7 1   7 |
#          value         |
#     x_4_0 dist         |
#          value   7   1 |
#     y_4_0 dist   7   7 |
#          value         |
#     x_4_1 dist   7   1 |
#          value 7 1   1 |
#     y_4_1 dist 7 1   7 |
#          value         |
#     x_4_2 dist 7 1   1 |
#          value   7   1 |
#     y_4_2 dist   7   7 |
#          value         |
#     x_4_3 dist   7   1 |
#          value 7 1   1 |
#     y_4_3 dist 7 1   7 |
#          value         |
#     x_4_4 dist 7 1   1 |
#          value   7   1 |
#     y_4_4 dist   7   7 |
#          value         |
#     x_4_5 dist   7   1 |
#          value 7 1   1 |
#     y_4_5 dist 7 1   7 |
#          value         |
#     x_4_6 dist 7 1   1 |
#          value   7   1 |
#     y_4_6 dist   7   7 |
#          value         |
#     x_4_7 dist   7   1 |
#          value 7 1   1 |
#     y_4_7 dist 7 1   7 |
#          value         |
#     x_4_8 dist 7 1   1 |
#          value   7   1 |
#     y_4_8 dist   7   7 |
#          value         |
#     x_4_9 dist   7   1 |
#          value 7 1   1 |
#     y_4_9 dist 7 1   7 |
#          value         |
#    x_4_10 dist 7 1   1 |
#          value   7   1 |
#    y_4_10 dist   7   7 |
#          value         |
#    x_4_11 dist   7   1 |
#          value 7 1   1 |
#    y_4_11 dist 7 1   7 |
#          value         |
#    x_4_12 dist 7 1   1 |
#          value   7   1 |
#    y_4_12 dist   7   7 |
#          value         |
#    x_4_13 dist   7   1 |
#          value 7 1   1 |
#    y_4_13 dist 7 1   7 |
#          value         |
#    x_4_14 dist 7 1   1 |
#          value   7   1 |
#    y_4_14 dist   7   7 |
#          value         |
#    x_4_15 dist   7   1 |
#          value 7 1   1 |
#    y_4_15 dist 7 1   7 |
#          value         |
#    x_4_16 dist 7 1   1 |
#          value   7   1 |
#    y_4_16 dist   7   7 |
#          value         |
#    x_4_17 dist   7   1 |
#          value 7 1   1 |
#    y_4_17 dist 7 1   7 |
#          value         |
#    x_4_18 dist 7 1   1 |
#          value   7   1 |
#    y_4_18 dist   7   7 |
#          value         |
#    x_4_19 dist   7   1 |
#          value 7 1   1 |
#    y_4_19 dist 7 1   7 |
#          value         |
#     x_5_0 dist         |
#          value   7   1 |
#     y_5_0 dist   7   7 |
#          value         |
#     x_5_1 dist   7   1 |
#          value 7 1   1 |
#     y_5_1 dist 7 1   7 |
#          value         |
#     x_5_2 dist 7 1   1 |
#          value   7   1 |
#     y_5_2 dist   7   7 |
#          value         |
#     x_5_3 dist   7   1 |
#          value 7 1   1 |
#     y_5_3 dist 7 1   7 |
#          value         |
#     x_5_4 dist 7 1   1 |
#          value   7   1 |
#     y_5_4 dist   7   7 |
#          value         |
#     x_5_5 dist   7   1 |
#          value 7 1   1 |
#     y_5_5 dist 7 1   7 |
#          value         |
#     x_5_6 dist 7 1   1 |
#          value   7   1 |
#     y_5_6 dist   7   7 |
#          value         |
#     x_5_7 dist   7   1 |
#          value 7 1   1 |
#     y_5_7 dist 7 1   7 |
#          value         |
#     x_5_8 dist 7 1   1 |
#          value   7   1 |
#     y_5_8 dist   7   7 |
#          value         |
#     x_5_9 dist   7   1 |
#          value 7 1   1 |
#     y_5_9 dist 7 1   7 |
#          value         |
#    x_5_10 dist 7 1   1 |
#          value   7   1 |
#    y_5_10 dist   7   7 |
#          value         |
#    x_5_11 dist   7   1 |
#          value 7 1   1 |
#    y_5_11 dist 7 1   7 |
#          value         |
#    x_5_12 dist 7 1   1 |
#          value   7   1 |
#    y_5_12 dist   7   7 |
#          value         |
#    x_5_13 dist   7   1 |
#          value 7 1   1 |
#    y_5_13 dist 7 1   7 |
#          value         |
#    x_5_14 dist 7 1   1 |
#          value   7   1 |
#    y_5_14 dist   7   7 |
#          value         |
#    x_5_15 dist   7   1 |
#          value 7 1   1 |
#    y_5_15 dist 7 1   7 |
#          value         |
#    x_5_16 dist 7 1   1 |
#          value   7   1 |
#    y_5_16 dist   7   7 |
#          value         |
#    x_5_17 dist   7   1 |
#          value 7 1   1 |
#    y_5_17 dist 7 1   7 |
#          value         |
#    x_5_18 dist 7 1   1 |
#          value   7   1 |
#    y_5_18 dist   7   7 |
#          value         |
#    x_5_19 dist   7   1 |
#          value 7 1   1 |
#    y_5_19 dist 7 1   7 |
#          value         |
#     x_6_0 dist         |
#          value   7   1 |
#     y_6_0 dist   7   7 |
#          value         |
#     x_6_1 dist   7   1 |
#          value 7 1   1 |
#     y_6_1 dist 7 1   7 |
#          value         |
#     x_6_2 dist 7 1   1 |
#          value   7   1 |
#     y_6_2 dist   7   7 |
#          value         |
#     x_6_3 dist   7   1 |
#          value 7 1   1 |
#     y_6_3 dist 7 1   7 |
#          value         |
#     x_6_4 dist 7 1   1 |
#          value   7   1 |
#     y_6_4 dist   7   7 |
#          value         |
#     x_6_5 dist   7   1 |
#          value 7 1   1 |
#     y_6_5 dist 7 1   7 |
#          value         |
#     x_6_6 dist 7 1   1 |
#          value   7   1 |
#     y_6_6 dist   7   7 |
#          value         |
#     x_6_7 dist   7   1 |
#          value 7 1   1 |
#     y_6_7 dist 7 1   7 |
#          value         |
#     x_6_8 dist 7 1   1 |
#          value   7   1 |
#     y_6_8 dist   7   7 |
#          value         |
#     x_6_9 dist   7   1 |
#          value 7 1   1 |
#     y_6_9 dist 7 1   7 |
#          value         |
#    x_6_10 dist 7 1   1 |
#          value   7   1 |
#    y_6_10 dist   7   7 |
#          value         |
#    x_6_11 dist   7   1 |
#          value 7 1   1 |
#    y_6_11 dist 7 1   7 |
#          value         |
#    x_6_12 dist 7 1   1 |
#          value   7   1 |
#    y_6_12 dist   7   7 |
#          value         |
#    x_6_13 dist   7   1 |
#          value 7 1   1 |
#    y_6_13 dist 7 1   7 |
#          value         |
#    x_6_14 dist 7 1   1 |
#          value   7   1 |
#    y_6_14 dist   7   7 |
#          value         |
#    x_6_15 dist   7   1 |
#          value 7 1   1 |
#    y_6_15 dist 7 1   7 |
#          value         |
#    x_6_16 dist 7 1   1 |
#          value   7   1 |
#    y_6_16 dist   7   7 |
#          value         |
#    x_6_17 dist   7   1 |
#          value 7 1   1 |
#    y_6_17 dist 7 1   7 |
#          value         |
#    x_6_18 dist 7 1   1 |
#          value   7   1 |
#    y_6_18 dist   7   7 |
#          value         |
#    x_6_19 dist   7   1 |
#          value 7 1   1 |
#    y_6_19 dist 7 1   7 |
#          value         |
#     x_7_0 dist         |
#          value   7   1 |
#     y_7_0 dist   7   7 |
#          value         |
#     x_7_1 dist   7   1 |
#          value 7 1   1 |
#     y_7_1 dist 7 1   7 |
#          value         |
#     x_7_2 dist 7 1   1 |
#          value   7   1 |
#     y_7_2 dist   7   7 |
#          value         |
#     x_7_3 dist   7   1 |
#          value 7 1   1 |
#     y_7_3 dist 7 1   7 |
#          value         |
#     x_7_4 dist 7 1   1 |
#          value   7   1 |
#     y_7_4 dist   7   7 |
#          value         |
#     x_7_5 dist   7   1 |
#          value 7 1   1 |
#     y_7_5 dist 7 1   7 |
#          value         |
#     x_7_6 dist 7 1   1 |
#          value   7   1 |
#     y_7_6 dist   7   7 |
#          value         |
#     x_7_7 dist   7   1 |
#          value 7 1   1 |
#     y_7_7 dist 7 1   7 |
#          value         |
#     x_7_8 dist 7 1   1 |
#          value   7   1 |
#     y_7_8 dist   7   7 |
#          value         |
#     x_7_9 dist   7   1 |
#          value 7 1   1 |
#     y_7_9 dist 7 1   7 |
#          value         |
#    x_7_10 dist 7 1   1 |
#          value   7   1 |
#    y_7_10 dist   7   7 |
#          value         |
#    x_7_11 dist   7   1 |
#          value 7 1   1 |
#    y_7_11 dist 7 1   7 |
#          value         |
#    x_7_12 dist 7 1   1 |
#          value   7   1 |
#    y_7_12 dist   7   7 |
#          value         |
#    x_7_13 dist   7   1 |
#          value 7 1   1 |
#    y_7_13 dist 7 1   7 |
#          value         |
#    x_7_14 dist 7 1   1 |
#          value   7   1 |
#    y_7_14 dist   7   7 |
#          value         |
#    x_7_15 dist   7   1 |
#          value 7 1   1 |
#    y_7_15 dist 7 1   7 |
#          value         |
#    x_7_16 dist 7 1   1 |
#          value   7   1 |
#    y_7_16 dist   7   7 |
#          value         |
#    x_7_17 dist   7   1 |
#          value 7 1   1 |
#    y_7_17 dist 7 1   7 |
#          value         |
#    x_7_18 dist 7 1   1 |
#          value   7   1 |
#    y_7_18 dist   7   7 |
#          value         |
#    x_7_19 dist   7   1 |
#          value 7 1   1 |
#    y_7_19 dist 7 1   7 |
#          value         |
#     x_8_0 dist         |
#          value   7   1 |
#     y_8_0 dist   7   7 |
#          value         |
#     x_8_1 dist   7   1 |
#          value 7 1   1 |
#     y_8_1 dist 7 1   7 |
#          value         |
#     x_8_2 dist 7 1   1 |
#          value   7   1 |
#     y_8_2 dist   7   7 |
#          value         |
#     x_8_3 dist   7   1 |
#          value 7 1   1 |
#     y_8_3 dist 7 1   7 |
#          value         |
#     x_8_4 dist 7 1   1 |
#          value   7   1 |
#     y_8_4 dist   7   7 |
#          value         |
#     x_8_5 dist   7   1 |
#          value 7 1   1 |
#     y_8_5 dist 7 1   7 |
#          value         |
#     x_8_6 dist 7 1   1 |
#          value   7   1 |
#     y_8_6 dist   7   7 |
#          value         |
#     x_8_7 dist   7   1 |
#          value 7 1   1 |
#     y_8_7 dist 7 1   7 |
#          value         |
#     x_8_8 dist 7 1   1 |
#          value   7   1 |
#     y_8_8 dist   7   7 |
#          value         |
#     x_8_9 dist   7   1 |
#          value 7 1   1 |
#     y_8_9 dist 7 1   7 |
#          value         |
#    x_8_10 dist 7 1   1 |
#          value   7   1 |
#    y_8_10 dist   7   7 |
#          value         |
#    x_8_11 dist   7   1 |
#          value 7 1   1 |
#    y_8_11 dist 7 1   7 |
#          value         |
#    x_8_12 dist 7 1   1 |
#          value   7   1 |
#    y_8_12 dist   7   7 |
#          value         |
#    x_8_13 dist   7   1 |
#          value 7 1   1 |
#    y_8_13 dist 7 1   7 |
#          value         |
#    x_8_14 dist 7 1   1 |
#          value   7   1 |
#    y_8_14 dist   7   7 |
#          value         |
#    x_8_15 dist   7   1 |
#          value 7 1   1 |
#    y_8_15 dist 7 1   7 |
#          value         |
#    x_8_16 dist 7 1   1 |
#          value   7   1 |
#    y_8_16 dist   7   7 |
#          value         |
#    x_8_17 dist   7   1 |
#          value 7 1   1 |
#    y_8_17 dist 7 1   7 |
#          value         |
#    x_8_18 dist 7 1   1 |
#          value   7   1 |
#    y_8_18 dist   7   7 |
#          value         |
#    x_8_19 dist   7   1 |
#          value 7 1   1 |
#    y_8_19 dist 7 1   7 |
#          value         |
#     x_9_0 dist         |
#          value   7   1 |
#     y_9_0 dist   7   7 |
#          value         |
#     x_9_1 dist   7   1 |
#          value 7 1   1 |
#     y_9_1 dist 7 1   7 |
#          value         |
#     x_9_2 dist 7 1   1 |
#          value   7   1 |
#     y_9_2 dist   7   7 |
#          value         |
#     x_9_3 dist   7   1 |
#          value 7 1   1 |
#     y_9_3 dist 7 1   7 |
#          value         |
#     x_9_4 dist 7 1   1 |
#          value   7   1 |
#     y_9_4 dist   7   7 |
#          value         |
#     x_9_5 dist   7   1 |
#          value 7 1   1 |
#     y_9_5 dist 7 1   7 |
#          value         |
#     x_9_6 dist 7 1   1 |
#          value   7   1 |
#     y_9_6 dist   7   7 |
#          value         |
#     x_9_7 dist   7   1 |
#          value 7 1   1 |
#     y_9_7 dist 7 1   7 |
#          value         |
#     x_9_8 dist 7 1   1 |
#          value   7   1 |
#     y_9_8 dist   7   7 |
#          value         |
#     x_9_9 dist   7   1 |
#          value 7 1   1 |
#     y_9_9 dist 7 1   7 |
#          value         |
#    x_9_10 dist 7 1   1 |
#          value   7   1 |
#    y_9_10 dist   7   7 |
#          value         |
#    x_9_11 dist   7   1 |
#          value 7 1   1 |
#    y_9_11 dist 7 1   7 |
#          value         |
#    x_9_12 dist 7 1   1 |
#          value   7   1 |
#    y_9_12 dist   7   7 |
#          value         |
#    x_9_13 dist   7   1 |
#          value 7 1   1 |
#    y_9_13 dist 7 1   7 |
#          value         |
#    x_9_14 dist 7 1   1 |
#          value   7   1 |
#    y_9_14 dist   7   7 |
#          value         |
#    x_9_15 dist   7   1 |
#          value 7 1   1 |
#    y_9_15 dist 7 1   7 |
#          value         |
#    x_9_16 dist 7 1   1 |
#          value   7   1 |
#    y_9_16 dist   7   7 |
#          value         |
#    x_9_17 dist   7   1 |
#          value 7 1   1 |
#    y_9_17 dist 7 1   7 |
#          value         |
#    x_9_18 dist 7 1   1 |
#          value   7   1 |
#    y_9_18 dist   7   7 |
#          value         |
#    x_9_19 dist   7   1 |
#          value 7 1   1 |
#    y_9_19 dist 7 1   7 |
#          value         |
#    x_10_0 dist         |
#          value   7   1 |
#    y_10_0 dist   7   7 |
#          value         |
#    x_10_1 dist   7   1 |
#          value 7 1   1 |
#    y_10_1 dist 7 1   7 |
#          value         |
#    x_10_2 dist 7 1   1 |
#          value   7   1 |
#    y_10_2 dist   7   7 |
#          value         |
#    x_10_3 dist   7   1 |
#          value 7 1   1 |
#    y_10_3 dist 7 1   7 |
#          value         |
#    x_10_4 dist 7 1   1 |
#          value   7   1 |
#    y_10_4 dist   7   7 |
#          value         |
#    x_10_5 dist   7   1 |
#          value 7 1   1 |
#    y_10_5 dist 7 1   7 |
#          value         |
#    x_10_6 dist 7 1   1 |
#          value   7   1 |
#    y_10_6 dist   7   7 |
#          value         |
#    x_10_7 dist   7   1 |
#          value 7 1   1 |
#    y_10_7 dist 7 1   7 |
#          value         |
#    x_10_8 dist 7 1   1 |
#          value   7   1 |
#    y_10_8 dist   7   7 |
#          value         |
#    x_10_9 dist   7   1 |
#          value 7 1   1 |
#    y_10_9 dist 7 1   7 |
#          value         |
#   x_10_10 dist 7 1   1 |
#          value   7   1 |
#   y_10_10 dist   7   7 |
#          value         |
#   x_10_11 dist   7   1 |
#          value 7 1   1 |
#   y_10_11 dist 7 1   7 |
#          value         |
#   x_10_12 dist 7 1   1 |
#          value   7   1 |
#   y_10_12 dist   7   7 |
#          value         |
#   x_10_13 dist   7   1 |
#          value 7 1   1 |
#   y_10_13 dist 7 1   7 |
#          value         |
#   x_10_14 dist 7 1   1 |
#          value   7   1 |
#   y_10_14 dist   7   7 |
#          value         |
#   x_10_15 dist   7   1 |
#          value 7 1   1 |
#   y_10_15 dist 7 1   7 |
#          value         |
#   x_10_16 dist 7 1   1 |
#          value   7   1 |
#   y_10_16 dist   7   7 |
#          value         |
#   x_10_17 dist   7   1 |
#          value 7 1   1 |
#   y_10_17 dist 7 1   7 |
#          value         |
#   x_10_18 dist 7 1   1 |
#          value   7   1 |
#   y_10_18 dist   7   7 |
#          value         |
#   x_10_19 dist   7   1 |
#          value 7 1   1 |
#   y_10_19 dist 7 1   7 |
#          value         |
#    x_11_0 dist         |
#          value   7   1 |
#    y_11_0 dist   7   7 |
#          value         |
#    x_11_1 dist   7   1 |
#          value 7 1   1 |
#    y_11_1 dist 7 1   7 |
#          value         |
#    x_11_2 dist 7 1   1 |
#          value   7   1 |
#    y_11_2 dist   7   7 |
#          value         |
#    x_11_3 dist   7   1 |
#          value 7 1   1 |
#    y_11_3 dist 7 1   7 |
#          value         |
#    x_11_4 dist 7 1   1 |
#          value   7   1 |
#    y_11_4 dist   7   7 |
#          value         |
#    x_11_5 dist   7   1 |
#          value 7 1   1 |
#    y_11_5 dist 7 1   7 |
#          value         |
#    x_11_6 dist 7 1   1 |
#          value   7   1 |
#    y_11_6 dist   7   7 |
#          value         |
#    x_11_7 dist   7   1 |
#          value 7 1   1 |
#    y_11_7 dist 7 1   7 |
#          value         |
#    x_11_8 dist 7 1   1 |
#          value   7   1 |
#    y_11_8 dist   7   7 |
#          value         |
#    x_11_9 dist   7   1 |
#          value 7 1   1 |
#    y_11_9 dist 7 1   7 |
#          value         |
#   x_11_10 dist 7 1   1 |
#          value   7   1 |
#   y_11_10 dist   7   7 |
#          value         |
#   x_11_11 dist   7   1 |
#          value 7 1   1 |
#   y_11_11 dist 7 1   7 |
#          value         |
#   x_11_12 dist 7 1   1 |
#          value   7   1 |
#   y_11_12 dist   7   7 |
#          value         |
#   x_11_13 dist   7   1 |
#          value 7 1   1 |
#   y_11_13 dist 7 1   7 |
#          value         |
#   x_11_14 dist 7 1   1 |
#          value   7   1 |
#   y_11_14 dist   7   7 |
#          value         |
#   x_11_15 dist   7   1 |
#          value 7 1   1 |
#   y_11_15 dist 7 1   7 |
#          value         |
#   x_11_16 dist 7 1   1 |
#          value   7   1 |
#   y_11_16 dist   7   7 |
#          value         |
#   x_11_17 dist   7   1 |
#          value 7 1   1 |
#   y_11_17 dist 7 1   7 |
#          value         |
#   x_11_18 dist 7 1   1 |
#          value   7   1 |
#   y_11_18 dist   7   7 |
#          value         |
#   x_11_19 dist   7   1 |
#          value 7 1   1 |
#   y_11_19 dist 7 1   7 |
#          value         |
#    x_12_0 dist         |
#          value   7   1 |
#    y_12_0 dist   7   7 |
#          value         |
#    x_12_1 dist   7   1 |
#          value 7 1   1 |
#    y_12_1 dist 7 1   7 |
#          value         |
#    x_12_2 dist 7 1   1 |
#          value   7   1 |
#    y_12_2 dist   7   7 |
#          value         |
#    x_12_3 dist   7   1 |
#          value 7 1   1 |
#    y_12_3 dist 7 1   7 |
#          value         |
#    x_12_4 dist 7 1   1 |
#          value   7   1 |
#    y_12_4 dist   7   7 |
#          value         |
#    x_12_5 dist   7   1 |
#          value 7 1   1 |
#    y_12_5 dist 7 1   7 |
#          value         |
#    x_12_6 dist 7 1   1 |
#          value   7   1 |
#    y_12_6 dist   7   7 |
#          value         |
#    x_12_7 dist   7   1 |
#          value 7 1   1 |
#    y_12_7 dist 7 1   7 |
#          value         |
#    x_12_8 dist 7 1   1 |
#          value   7   1 |
#    y_12_8 dist   7   7 |
#          value         |
#    x_12_9 dist   7   1 |
#          value 7 1   1 |
#    y_12_9 dist 7 1   7 |
#          value         |
#   x_12_10 dist 7 1   1 |
#          value   7   1 |
#   y_12_10 dist   7   7 |
#          value         |
#   x_12_11 dist   7   1 |
#          value 7 1   1 |
#   y_12_11 dist 7 1   7 |
#          value         |
#   x_12_12 dist 7 1   1 |
#          value   7   1 |
#   y_12_12 dist   7   7 |
#          value         |
#   x_12_13 dist   7   1 |
#          value 7 1   1 |
#   y_12_13 dist 7 1   7 |
#          value         |
#   x_12_14 dist 7 1   1 |
#          value   7   1 |
#   y_12_14 dist   7   7 |
#          value         |
#   x_12_15 dist   7   1 |
#          value 7 1   1 |
#   y_12_15 dist 7 1   7 |
#          value         |
#   x_12_16 dist 7 1   1 |
#          value   7   1 |
#   y_12_16 dist   7   7 |
#          value         |
#   x_12_17 dist   7   1 |
#          value 7 1   1 |
#   y_12_17 dist 7 1   7 |
#          value         |
#   x_12_18 dist 7 1   1 |
#          value   7   1 |
#   y_12_18 dist   7   7 |
#          value         |
#   x_12_19 dist   7   1 |
#          value 7 1   1 |
#   y_12_19 dist 7 1   7 |
#          value         |
#    x_13_0 dist         |
#          value   7   1 |
#    y_13_0 dist   7   7 |
#          value         |
#    x_13_1 dist   7   1 |
#          value 7 1   1 |
#    y_13_1 dist 7 1   7 |
#          value         |
#    x_13_2 dist 7 1   1 |
#          value   7   1 |
#    y_13_2 dist   7   7 |
#          value         |
#    x_13_3 dist   7   1 |
#          value 7 1   1 |
#    y_13_3 dist 7 1   7 |
#          value         |
#    x_13_4 dist 7 1   1 |
#          value   7   1 |
#    y_13_4 dist   7   7 |
#          value         |
#    x_13_5 dist   7   1 |
#          value 7 1   1 |
#    y_13_5 dist 7 1   7 |
#          value         |
#    x_13_6 dist 7 1   1 |
#          value   7   1 |
#    y_13_6 dist   7   7 |
#          value         |
#    x_13_7 dist   7   1 |
#          value 7 1   1 |
#    y_13_7 dist 7 1   7 |
#          value         |
#    x_13_8 dist 7 1   1 |
#          value   7   1 |
#    y_13_8 dist   7   7 |
#          value         |
#    x_13_9 dist   7   1 |
#          value 7 1   1 |
#    y_13_9 dist 7 1   7 |
#          value         |
#   x_13_10 dist 7 1   1 |
#          value   7   1 |
#   y_13_10 dist   7   7 |
#          value         |
#   x_13_11 dist   7   1 |
#          value 7 1   1 |
#   y_13_11 dist 7 1   7 |
#          value         |
#   x_13_12 dist 7 1   1 |
#          value   7   1 |
#   y_13_12 dist   7   7 |
#          value         |
#   x_13_13 dist   7   1 |
#          value 7 1   1 |
#   y_13_13 dist 7 1   7 |
#          value         |
#   x_13_14 dist 7 1   1 |
#          value   7   1 |
#   y_13_14 dist   7   7 |
#          value         |
#   x_13_15 dist   7   1 |
#          value 7 1   1 |
#   y_13_15 dist 7 1   7 |
#          value         |
#   x_13_16 dist 7 1   1 |
#          value   7   1 |
#   y_13_16 dist   7   7 |
#          value         |
#   x_13_17 dist   7   1 |
#          value 7 1   1 |
#   y_13_17 dist 7 1   7 |
#          value         |
#   x_13_18 dist 7 1   1 |
#          value   7   1 |
#   y_13_18 dist   7   7 |
#          value         |
#   x_13_19 dist   7   1 |
#          value 7 1   1 |
#   y_13_19 dist 7 1   7 |
#          value         |
#    x_14_0 dist         |
#          value   7   1 |
#    y_14_0 dist   7   7 |
#          value         |
#    x_14_1 dist   7   1 |
#          value 7 1   1 |
#    y_14_1 dist 7 1   7 |
#          value         |
#    x_14_2 dist 7 1   1 |
#          value   7   1 |
#    y_14_2 dist   7   7 |
#          value         |
#    x_14_3 dist   7   1 |
#          value 7 1   1 |
#    y_14_3 dist 7 1   7 |
#          value         |
#    x_14_4 dist 7 1   1 |
#          value   7   1 |
#    y_14_4 dist   7   7 |
#          value         |
#    x_14_5 dist   7   1 |
#          value 7 1   1 |
#    y_14_5 dist 7 1   7 |
#          value         |
#    x_14_6 dist 7 1   1 |
#          value   7   1 |
#    y_14_6 dist   7   7 |
#          value         |
#    x_14_7 dist   7   1 |
#          value 7 1   1 |
#    y_14_7 dist 7 1   7 |
#          value         |
#    x_14_8 dist 7 1   1 |
#          value   7   1 |
#    y_14_8 dist   7   7 |
#          value         |
#    x_14_9 dist   7   1 |
#          value 7 1   1 |
#    y_14_9 dist 7 1   7 |
#          value         |
#   x_14_10 dist 7 1   1 |
#          value   7   1 |
#   y_14_10 dist   7   7 |
#          value         |
#   x_14_11 dist   7   1 |
#          value 7 1   1 |
#   y_14_11 dist 7 1   7 |
#          value         |
#   x_14_12 dist 7 1   1 |
#          value   7   1 |
#   y_14_12 dist   7   7 |
#          value         |
#   x_14_13 dist   7   1 |
#          value 7 1   1 |
#   y_14_13 dist 7 1   7 |
#          value         |
#   x_14_14 dist 7 1   1 |
#          value   7   1 |
#   y_14_14 dist   7   7 |
#          value         |
#   x_14_15 dist   7   1 |
#          value 7 1   1 |
#   y_14_15 dist 7 1   7 |
#          value         |
#   x_14_16 dist 7 1   1 |
#          value   7   1 |
#   y_14_16 dist   7   7 |
#          value         |
#   x_14_17 dist   7   1 |
#          value 7 1   1 |
#   y_14_17 dist 7 1   7 |
#          value         |
#   x_14_18 dist 7 1   1 |
#          value   7   1 |
#   y_14_18 dist   7   7 |
#          value         |
#   x_14_19 dist   7   1 |
#          value 7 1   1 |
#   y_14_19 dist 7 1   7 |
#          value         |
#    x_15_0 dist         |
#          value   7   1 |
#    y_15_0 dist   7   7 |
#          value         |
#    x_15_1 dist   7   1 |
#          value 7 1   1 |
#    y_15_1 dist 7 1   7 |
#          value         |
#    x_15_2 dist 7 1   1 |
#          value   7   1 |
#    y_15_2 dist   7   7 |
#          value         |
#    x_15_3 dist   7   1 |
#          value 7 1   1 |
#    y_15_3 dist 7 1   7 |
#          value         |
#    x_15_4 dist 7 1   1 |
#          value   7   1 |
#    y_15_4 dist   7   7 |
#          value         |
#    x_15_5 dist   7   1 |
#          value 7 1   1 |
#    y_15_5 dist 7 1   7 |
#          value         |
#    x_15_6 dist 7 1   1 |
#          value   7   1 |
#    y_15_6 dist   7   7 |
#          value         |
#    x_15_7 dist   7   1 |
#          value 7 1   1 |
#    y_15_7 dist 7 1   7 |
#          value         |
#    x_15_8 dist 7 1   1 |
#          value   7   1 |
#    y_15_8 dist   7   7 |
#          value         |
#    x_15_9 dist   7   1 |
#          value 7 1   1 |
#    y_15_9 dist 7 1   7 |
#          value         |
#   x_15_10 dist 7 1   1 |
#          value   7   1 |
#   y_15_10 dist   7   7 |
#          value         |
#   x_15_11 dist   7   1 |
#          value 7 1   1 |
#   y_15_11 dist 7 1   7 |
#          value         |
#   x_15_12 dist 7 1   1 |
#          value   7   1 |
#   y_15_12 dist   7   7 |
#          value         |
#   x_15_13 dist   7   1 |
#          value 7 1   1 |
#   y_15_13 dist 7 1   7 |
#          value         |
#   x_15_14 dist 7 1   1 |
#          value   7   1 |
#   y_15_14 dist   7   7 |
#          value         |
#   x_15_15 dist   7   1 |
#          value 7 1   1 |
#   y_15_15 dist 7 1   7 |
#          value         |
#   x_15_16 dist 7 1   1 |
#          value   7   1 |
#   y_15_16 dist   7   7 |
#          value         |
#   x_15_17 dist   7   1 |
#          value 7 1   1 |
#   y_15_17 dist 7 1   7 |
#          value         |
#   x_15_18 dist 7 1   1 |
#          value   7   1 |
#   y_15_18 dist   7   7 |
#          value         |
#   x_15_19 dist   7   1 |
#          value 7 1   1 |
#   y_15_19 dist 7 1   7 |
#          value         |
#    x_16_0 dist         |
#          value   7   1 |
#    y_16_0 dist   7   7 |
#          value         |
#    x_16_1 dist   7   1 |
#          value 7 1   1 |
#    y_16_1 dist 7 1   7 |
#          value         |
#    x_16_2 dist 7 1   1 |
#          value   7   1 |
#    y_16_2 dist   7   7 |
#          value         |
#    x_16_3 dist   7   1 |
#          value 7 1   1 |
#    y_16_3 dist 7 1   7 |
#          value         |
#    x_16_4 dist 7 1   1 |
#          value   7   1 |
#    y_16_4 dist   7   7 |
#          value         |
#    x_16_5 dist   7   1 |
#          value 7 1   1 |
#    y_16_5 dist 7 1   7 |
#          value         |
#    x_16_6 dist 7 1   1 |
#          value   7   1 |
#    y_16_6 dist   7   7 |
#          value         |
#    x_16_7 dist   7   1 |
#          value 7 1   1 |
#    y_16_7 dist 7 1   7 |
#          value         |
#    x_16_8 dist 7 1   1 |
#          value   7   1 |
#    y_16_8 dist   7   7 |
#          value         |
#    x_16_9 dist   7   1 |
#          value 7 1   1 |
#    y_16_9 dist 7 1   7 |
#          value         |
#   x_16_10 dist 7 1   1 |
#          value   7   1 |
#   y_16_10 dist   7   7 |
#          value         |
#   x_16_11 dist   7   1 |
#          value 7 1   1 |
#   y_16_11 dist 7 1   7 |
#          value         |
#   x_16_12 dist 7 1   1 |
#          value   7   1 |
#   y_16_12 dist   7   7 |
#          value         |
#   x_16_13 dist   7   1 |
#          value 7 1   1 |
#   y_16_13 dist 7 1   7 |
#          value         |
#   x_16_14 dist 7 1   1 |
#          value   7   1 |
#   y_16_14 dist   7   7 |
#          value         |
#   x_16_15 dist   7   1 |
#          value 7 1   1 |
#   y_16_15 dist 7 1   7 |
#          value         |
#   x_16_16 dist 7 1   1 |
#          value   7   1 |
#   y_16_16 dist   7   7 |
#          value         |
#   x_16_17 dist   7   1 |
#          value 7 1   1 |
#   y_16_17 dist 7 1   7 |
#          value         |
#   x_16_18 dist 7 1   1 |
#          value   7   1 |
#   y_16_18 dist   7   7 |
#          value         |
#   x_16_19 dist   7   1 |
#          value 7 1   1 |
#   y_16_19 dist 7 1   7 |
#          value         |
#    x_17_0 dist         |
#          value   7   1 |
#    y_17_0 dist   7   7 |
#          value         |
#    x_17_1 dist   7   1 |
#          value 7 1   1 |
#    y_17_1 dist 7 1   7 |
#          value         |
#    x_17_2 dist 7 1   1 |
#          value   7   1 |
#    y_17_2 dist   7   7 |
#          value         |
#    x_17_3 dist   7   1 |
#          value 7 1   1 |
#    y_17_3 dist 7 1   7 |
#          value         |
#    x_17_4 dist 7 1   1 |
#          value   7   1 |
#    y_17_4 dist   7   7 |
#          value         |
#    x_17_5 dist   7   1 |
#          value 7 1   1 |
#    y_17_5 dist 7 1   7 |
#          value         |
#    x_17_6 dist 7 1   1 |
#          value   7   1 |
#    y_17_6 dist   7   7 |
#          value         |
#    x_17_7 dist   7   1 |
#          value 7 1   1 |
#    y_17_7 dist 7 1   7 |
#          value         |
#    x_17_8 dist 7 1   1 |
#          value   7   1 |
#    y_17_8 dist   7   7 |
#          value         |
#    x_17_9 dist   7   1 |
#          value 7 1   1 |
#    y_17_9 dist 7 1   7 |
#          value         |
#   x_17_10 dist 7 1   1 |
#          value   7   1 |
#   y_17_10 dist   7   7 |
#          value         |
#   x_17_11 dist   7   1 |
#          value 7 1   1 |
#   y_17_11 dist 7 1   7 |
#          value         |
#   x_17_12 dist 7 1   1 |
#          value   7   1 |
#   y_17_12 dist   7   7 |
#          value         |
#   x_17_13 dist   7   1 |
#          value 7 1   1 |
#   y_17_13 dist 7 1   7 |
#          value         |
#   x_17_14 dist 7 1   1 |
#          value   7   1 |
#   y_17_14 dist   7   7 |
#          value         |
#   x_17_15 dist   7   1 |
#          value 7 1   1 |
#   y_17_15 dist 7 1   7 |
#          value         |
#   x_17_16 dist 7 1   1 |
#          value   7   1 |
#   y_17_16 dist   7   7 |
#          value         |
#   x_17_17 dist   7   1 |
#          value 7 1   1 |
#   y_17_17 dist 7 1   7 |
#          value         |
#   x_17_18 dist 7 1   1 |
#          value   7   1 |
#   y_17_18 dist   7   7 |
#          value         |
#   x_17_19 dist   7   1 |
#          value 7 1   1 |
#   y_17_19 dist 7 1   7 |
#          value         |
#    x_18_0 dist         |
#          value   7   1 |
#    y_18_0 dist   7   7 |
#          value         |
#    x_18_1 dist   7   1 |
#          value 7 1   1 |
#    y_18_1 dist 7 1   7 |
#          value         |
#    x_18_2 dist 7 1   1 |
#          value   7   1 |
#    y_18_2 dist   7   7 |
#          value         |
#    x_18_3 dist   7   1 |
#          value 7 1   1 |
#    y_18_3 dist 7 1   7 |
#          value         |
#    x_18_4 dist 7 1   1 |
#          value   7   1 |
#    y_18_4 dist   7   7 |
#          value         |
#    x_18_5 dist   7   1 |
#          value 7 1   1 |
#    y_18_5 dist 7 1   7 |
#          value         |
#    x_18_6 dist 7 1   1 |
#          value   7   1 |
#    y_18_6 dist   7   7 |
#          value         |
#    x_18_7 dist   7   1 |
#          value 7 1   1 |
#    y_18_7 dist 7 1   7 |
#          value         |
#    x_18_8 dist 7 1   1 |
#          value   7   1 |
#    y_18_8 dist   7   7 |
#          value         |
#    x_18_9 dist   7   1 |
#          value 7 1   1 |
#    y_18_9 dist 7 1   7 |
#          value         |
#   x_18_10 dist 7 1   1 |
#          value   7   1 |
#   y_18_10 dist   7   7 |
#          value         |
#   x_18_11 dist   7   1 |
#          value 7 1   1 |
#   y_18_11 dist 7 1   7 |
#          value         |
#   x_18_12 dist 7 1   1 |
#          value   7   1 |
#   y_18_12 dist   7   7 |
#          value         |
#   x_18_13 dist   7   1 |
#          value 7 1   1 |
#   y_18_13 dist 7 1   7 |
#          value         |
#   x_18_14 dist 7 1   1 |
#          value   7   1 |
#   y_18_14 dist   7   7 |
#          value         |
#   x_18_15 dist   7   1 |
#          value 7 1   1 |
#   y_18_15 dist 7 1   7 |
#          value         |
#   x_18_16 dist 7 1   1 |
#          value   7   1 |
#   y_18_16 dist   7   7 |
#          value         |
#   x_18_17 dist   7   1 |
#          value 7 1   1 |
#   y_18_17 dist 7 1   7 |
#          value         |
#   x_18_18 dist 7 1   1 |
#          value   7   1 |
#   y_18_18 dist   7   7 |
#          value         |
#   x_18_19 dist   7   1 |
#          value 7 1   1 |
#   y_18_19 dist 7 1   7 |
#          value         |
#    x_19_0 dist         |
#          value   7   1 |
#    y_19_0 dist   7   7 |
#          value         |
#    x_19_1 dist   7   1 |
#          value 7 1   1 |
#    y_19_1 dist 7 1   7 |
#          value         |
#    x_19_2 dist 7 1   1 |
#          value   7   1 |
#    y_19_2 dist   7   7 |
#          value         |
#    x_19_3 dist   7   1 |
#          value 7 1   1 |
#    y_19_3 dist 7 1   7 |
#          value         |
#    x_19_4 dist 7 1   1 |
#          value   7   1 |
#    y_19_4 dist   7   7 |
#          value         |
#    x_19_5 dist   7   1 |
#          value 7 1   1 |
#    y_19_5 dist 7 1   7 |
#          value         |
#    x_19_6 dist 7 1   1 |
#          value   7   1 |
#    y_19_6 dist   7   7 |
#          value         |
#    x_19_7 dist   7   1 |
#          value 7 1   1 |
#    y_19_7 dist 7 1   7 |
#          value         |
#    x_19_8 dist 7 1   1 |
#          value   7   1 |
#    y_19_8 dist   7   7 |
#          value         |
#    x_19_9 dist   7   1 |
#          value 7 1   1 |
#    y_19_9 dist 7 1   7 |
#          value         |
#   x_19_10 dist 7 1   1 |
#          value   7   1 |
#   y_19_10 dist   7   7 |
#          value         |
#   x_19_11 dist   7   1 |
#          value 7 1   1 |
#   y_19_11 dist 7 1   7 |
#          value         |
#   x_19_12 dist 7 1   1 |
#          value   7   1 |
#   y_19_12 dist   7   7 |
#          value         |
#   x_19_13 dist   7   1 |
#          value 7 1   1 |
#   y_19_13 dist 7 1   7 |
#          value         |
#   x_19_14 dist 7 1   1 |
#          value   7   1 |
#   y_19_14 dist   7   7 |
#          value         |
#   x_19_15 dist   7   1 |
#          value 7 1   1 |
#   y_19_15 dist 7 1   7 |
#          value         |
#   x_19_16 dist 7 1   1 |
#          value   7   1 |
#   y_19_16 dist   7   7 |
#          value         |
#   x_19_17 dist   7   1 |
#          value 7 1   1 |
#   y_19_17 dist 7 1   7 |
#          value         |
#   x_19_18 dist 7 1   1 |
#          value   7   1 |
#   y_19_18 dist   7   7 |
#          value         |
#   x_19_19 dist   7   1 |
#          value 7 1   1 |
#   y_19_19 dist 7 1   7 |
#          value         |
#    x_20_0 dist         |
#          value   7   1 |
#    y_20_0 dist   7   7 |
#          value         |
#    x_20_1 dist   7   1 |
#          value 7 1   1 |
#    y_20_1 dist 7 1   7 |
#          value         |
#    x_20_2 dist 7 1   1 |
#          value   7   1 |
#    y_20_2 dist   7   7 |
#          value         |
#    x_20_3 dist   7   1 |
#          value 7 1   1 |
#    y_20_3 dist 7 1   7 |
#          value         |
#    x_20_4 dist 7 1   1 |
#          value   7   1 |
#    y_20_4 dist   7   7 |
#          value         |
#    x_20_5 dist   7   1 |
#          value 7 1   1 |
#    y_20_5 dist 7 1   7 |
#          value         |
#    x_20_6 dist 7 1   1 |
#          value   7   1 |
#    y_20_6 dist   7   7 |
#          value         |
#    x_20_7 dist   7   1 |
#          value 7 1   1 |
#    y_20_7 dist 7 1   7 |
#          value         |
#    x_20_8 dist 7 1   1 |
#          value   7   1 |
#    y_20_8 dist   7   7 |
#          value         |
#    x_20_9 dist   7   1 |
#          value 7 1   1 |
#    y_20_9 dist 7 1   7 |
#          value         |
#   x_20_10 dist 7 1   1 |
#          value   7   1 |
#   y_20_10 dist   7   7 |
#          value         |
#   x_20_11 dist   7   1 |
#          value 7 1   1 |
# ...
#   x_167_0 dist         |
#          value   7   1 |
#   y_167_0 dist   7   7 |
#          value         |
#   x_167_1 dist   7   1 |
#          value 7 1   1 |
#   y_167_1 dist 7 1   7 |
#          value         |
#   x_167_2 dist 7 1   1 |
#          value   7   1 |
#   y_167_2 dist   7   7 |
#          value         |
#   x_167_3 dist   7   1 |
#          value 7 1   1 |
#   y_167_3 dist 7 1   7 |
#          value         |
#   x_167_4 dist 7 1   1 |
#          value   7   1 |
#   y_167_4 dist   7   7 |
#          value         |
#   x_167_5 dist   7   1 |
#          value 7 1   1 |
#   y_167_5 dist 7 1   7 |
#          value         |
#   x_167_6 dist 7 1   1 |
#          value   7   1 |
#   y_167_6 dist   7   7 |
#          value         |
#   x_167_7 dist   7   1 |
#          value 7 1   1 |
#   y_167_7 dist 7 1   7 |
#          value         |
#   x_167_8 dist 7 1   1 |
#          value   7   1 |
#   y_167_8 dist   7   7 |
#          value         |
#   x_167_9 dist   7   1 |
#          value 7 1   1 |
#   y_167_9 dist 7 1   7 |
#          value         |
#  x_167_10 dist 7 1   1 |
#          value   7   1 |
#  y_167_10 dist   7   7 |
#          value         |
#  x_167_11 dist   7   1 |
#          value 7 1   1 |
#  y_167_11 dist 7 1   7 |
#          value         |
#  x_167_12 dist 7 1   1 |
#          value   7   1 |
#  y_167_12 dist   7   7 |
#          value         |
#  x_167_13 dist   7   1 |
#          value 7 1   1 |
#  y_167_13 dist 7 1   7 |
#          value         |
#  x_167_14 dist 7 1   1 |
#          value   7   1 |
#  y_167_14 dist   7   7 |
#          value         |
#  x_167_15 dist   7   1 |
#          value 7 1   1 |
#  y_167_15 dist 7 1   7 |
#          value         |
#  x_167_16 dist 7 1   1 |
#          value   7   1 |
#  y_167_16 dist   7   7 |
#          value         |
#  x_167_17 dist   7   1 |
#          value 7 1   1 |
#  y_167_17 dist 7 1   7 |
#          value         |
#  x_167_18 dist 7 1   1 |
#          value   7   1 |
#  y_167_18 dist   7   7 |
#          value         |
#  x_167_19 dist   7   1 |
#          value 7 1   1 |
#  y_167_19 dist 7 1   7 |
#          value         |
#   x_168_0 dist         |
#          value   7   1 |
#   y_168_0 dist   7   7 |
#          value         |
#   x_168_1 dist   7   1 |
#          value 7 1   1 |
#   y_168_1 dist 7 1   7 |
#          value         |
#   x_168_2 dist 7 1   1 |
#          value   7   1 |
#   y_168_2 dist   7   7 |
#          value         |
#   x_168_3 dist   7   1 |
#          value 7 1   1 |
#   y_168_3 dist 7 1   7 |
#          value         |
#   x_168_4 dist 7 1   1 |
#          value   7   1 |
#   y_168_4 dist   7   7 |
#          value         |
#   x_168_5 dist   7   1 |
#          value 7 1   1 |
#   y_168_5 dist 7 1   7 |
#          value         |
#   x_168_6 dist 7 1   1 |
#          value   7   1 |
#   y_168_6 dist   7   7 |
#          value         |
#   x_168_7 dist   7   1 |
#          value 7 1   1 |
#   y_168_7 dist 7 1   7 |
#          value         |
#   x_168_8 dist 7 1   1 |
#          value   7   1 |
#   y_168_8 dist   7   7 |
#          value         |
#   x_168_9 dist   7   1 |
#          value 7 1   1 |
#   y_168_9 dist 7 1   7 |
#          value         |
#  x_168_10 dist 7 1   1 |
#          value   7   1 |
#  y_168_10 dist   7   7 |
#          value         |
#  x_168_11 dist   7   1 |
#          value 7 1   1 |
#  y_168_11 dist 7 1   7 |
#          value         |
#  x_168_12 dist 7 1   1 |
#          value   7   1 |
#  y_168_12 dist   7   7 |
#          value         |
#  x_168_13 dist   7   1 |
#          value 7 1   1 |
#  y_168_13 dist 7 1   7 |
#          value         |
#  x_168_14 dist 7 1   1 |
#          value   7   1 |
#  y_168_14 dist   7   7 |
#          value         |
#  x_168_15 dist   7   1 |
#          value 7 1   1 |
#  y_168_15 dist 7 1   7 |
#          value         |
#  x_168_16 dist 7 1   1 |
#          value   7   1 |
#  y_168_16 dist   7   7 |
#          value         |
#  x_168_17 dist   7   1 |
#          value 7 1   1 |
#  y_168_17 dist 7 1   7 |
#          value         |
#  x_168_18 dist 7 1   1 |
#          value   7   1 |
#  y_168_18 dist   7   7 |
#          value         |
#  x_168_19 dist   7   1 |
#          value 7 1   1 |
#  y_168_19 dist 7 1   7 |
#          value         |
#   x_169_0 dist         |
#          value   7   1 |
#   y_169_0 dist   7   7 |
#          value         |
#   x_169_1 dist   7   1 |
#          value 7 1   1 |
#   y_169_1 dist 7 1   7 |
#          value         |
#   x_169_2 dist 7 1   1 |
#          value   7   1 |
#   y_169_2 dist   7   7 |
#          value         |
#   x_169_3 dist   7   1 |
#          value 7 1   1 |
#   y_169_3 dist 7 1   7 |
#          value         |
#   x_169_4 dist 7 1   1 |
#          value   7   1 |
#   y_169_4 dist   7   7 |
#          value         |
#   x_169_5 dist   7   1 |
#          value 7 1   1 |
#   y_169_5 dist 7 1   7 |
#          value         |
#   x_169_6 dist 7 1   1 |
#          value   7   1 |
#   y_169_6 dist   7   7 |
#          value         |
#   x_169_7 dist   7   1 |
#          value 7 1   1 |
#   y_169_7 dist 7 1   7 |
#          value         |
#   x_169_8 dist 7 1   1 |
#          value   7   1 |
#   y_169_8 dist   7   7 |
#          value         |
#   x_169_9 dist   7   1 |
#          value 7 1   1 |
#   y_169_9 dist 7 1   7 |
#          value         |
#  x_169_10 dist 7 1   1 |
#          value   7   1 |
#  y_169_10 dist   7   7 |
#          value         |
#  x_169_11 dist   7   1 |
#          value 7 1   1 |
#  y_169_11 dist 7 1   7 |
#          value         |
#  x_169_12 dist 7 1   1 |
#          value   7   1 |
#  y_169_12 dist   7   7 |
#          value         |
#  x_169_13 dist   7   1 |
#          value 7 1   1 |
#  y_169_13 dist 7 1   7 |
#          value         |
#  x_169_14 dist 7 1   1 |
#          value   7   1 |
#  y_169_14 dist   7   7 |
#          value         |
#  x_169_15 dist   7   1 |
#          value 7 1   1 |
#  y_169_15 dist 7 1   7 |
#          value         |
#  x_169_16 dist 7 1   1 |
#          value   7   1 |
#  y_169_16 dist   7   7 |
#          value         |
#  x_169_17 dist   7   1 |
#          value 7 1   1 |
#  y_169_17 dist 7 1   7 |
#          value         |
#  x_169_18 dist 7 1   1 |
#          value   7   1 |
#  y_169_18 dist   7   7 |
#          value         |
#  x_169_19 dist   7   1 |
#          value 7 1   1 |
#  y_169_19 dist 7 1   7 |
#          value         |
#   x_170_0 dist         |
#          value   7   1 |
#   y_170_0 dist   7   7 |
#          value         |
#   x_170_1 dist   7   1 |
#          value 7 1   1 |
#   y_170_1 dist 7 1   7 |
#          value         |
#   x_170_2 dist 7 1   1 |
#          value   7   1 |
#   y_170_2 dist   7   7 |
#          value         |
#   x_170_3 dist   7   1 |
#          value 7 1   1 |
#   y_170_3 dist 7 1   7 |
#          value         |
#   x_170_4 dist 7 1   1 |
#          value   7   1 |
#   y_170_4 dist   7   7 |
#          value         |
#   x_170_5 dist   7   1 |
#          value 7 1   1 |
#   y_170_5 dist 7 1   7 |
#          value         |
#   x_170_6 dist 7 1   1 |
#          value   7   1 |
#   y_170_6 dist   7   7 |
#          value         |
#   x_170_7 dist   7   1 |
#          value 7 1   1 |
#   y_170_7 dist 7 1   7 |
#          value         |
#   x_170_8 dist 7 1   1 |
#          value   7   1 |
#   y_170_8 dist   7   7 |
#          value         |
#   x_170_9 dist   7   1 |
#          value 7 1   1 |
#   y_170_9 dist 7 1   7 |
#          value         |
#  x_170_10 dist 7 1   1 |
#          value   7   1 |
#  y_170_10 dist   7   7 |
#          value         |
#  x_170_11 dist   7   1 |
#          value 7 1   1 |
#  y_170_11 dist 7 1   7 |
#          value         |
#  x_170_12 dist 7 1   1 |
#          value   7   1 |
#  y_170_12 dist   7   7 |
#          value         |
#  x_170_13 dist   7   1 |
#          value 7 1   1 |
#  y_170_13 dist 7 1   7 |
#          value         |
#  x_170_14 dist 7 1   1 |
#          value   7   1 |
#  y_170_14 dist   7   7 |
#          value         |
#  x_170_15 dist   7   1 |
#          value 7 1   1 |
#  y_170_15 dist 7 1   7 |
#          value         |
#  x_170_16 dist 7 1   1 |
#          value   7   1 |
#  y_170_16 dist   7   7 |
#          value         |
#  x_170_17 dist   7   1 |
#          value 7 1   1 |
#  y_170_17 dist 7 1   7 |
#          value         |
#  x_170_18 dist 7 1   1 |
#          value   7   1 |
#  y_170_18 dist   7   7 |
#          value         |
#  x_170_19 dist   7   1 |
#          value 7 1   1 |
#  y_170_19 dist 7 1   7 |
#          value         |
#   x_171_0 dist         |
#          value   7   1 |
#   y_171_0 dist   7   7 |
#          value         |
#   x_171_1 dist   7   1 |
#          value 7 1   1 |
#   y_171_1 dist 7 1   7 |
#          value         |
#   x_171_2 dist 7 1   1 |
#          value   7   1 |
#   y_171_2 dist   7   7 |
#          value         |
#   x_171_3 dist   7   1 |
#          value 7 1   1 |
#   y_171_3 dist 7 1   7 |
#          value         |
#   x_171_4 dist 7 1   1 |
#          value   7   1 |
#   y_171_4 dist   7   7 |
#          value         |
#   x_171_5 dist   7   1 |
#          value 7 1   1 |
#   y_171_5 dist 7 1   7 |
#          value         |
#   x_171_6 dist 7 1   1 |
#          value   7   1 |
#   y_171_6 dist   7   7 |
#          value         |
#   x_171_7 dist   7   1 |
#          value 7 1   1 |
#   y_171_7 dist 7 1   7 |
#          value         |
#   x_171_8 dist 7 1   1 |
#          value   7   1 |
#   y_171_8 dist   7   7 |
#          value         |
#   x_171_9 dist   7   1 |
#          value 7 1   1 |
#   y_171_9 dist 7 1   7 |
#          value         |
#  x_171_10 dist 7 1   1 |
#          value   7   1 |
#  y_171_10 dist   7   7 |
#          value         |
#  x_171_11 dist   7   1 |
#          value 7 1   1 |
#  y_171_11 dist 7 1   7 |
#          value         |
#  x_171_12 dist 7 1   1 |
#          value   7   1 |
#  y_171_12 dist   7   7 |
#          value         |
#  x_171_13 dist   7   1 |
#          value 7 1   1 |
#  y_171_13 dist 7 1   7 |
#          value         |
#  x_171_14 dist 7 1   1 |
#          value   7   1 |
#  y_171_14 dist   7   7 |
#          value         |
#  x_171_15 dist   7   1 |
#          value 7 1   1 |
#  y_171_15 dist 7 1   7 |
#          value         |
#  x_171_16 dist 7 1   1 |
#          value   7   1 |
#  y_171_16 dist   7   7 |
#          value         |
#  x_171_17 dist   7   1 |
#          value 7 1   1 |
#  y_171_17 dist 7 1   7 |
#          value         |
#  x_171_18 dist 7 1   1 |
#          value   7   1 |
#  y_171_18 dist   7   7 |
#          value         |
#  x_171_19 dist   7   1 |
#          value 7 1   1 |
#  y_171_19 dist 7 1   7 |
#          value         |
# 	Training step: 0
# 	    0	5.906041628815407
# 	Training step: 1
# 	    1	5.866538540152616
# 	Training step: 2
# 	    2	5.8287614689316865
# 	Training step: 3
# 	    3	5.792788767260174
# 	Training step: 4
# 	    4	5.758686296329942
# 	Training step: 5
# 	    5	5.726500045421512
# 	Training step: 6
# 	    6	5.696240802143896
# 	Training step: 7
# 	    7	5.667865416061047
# 	Training step: 8
# 	    8	5.641312000363372
# 	Training step: 9
# 	    9	5.616493118640989
# 	Training step: 10
# 	   10	5.593320198946221
# 	Training step: 11
# 	   11	5.571693313953489
# 	Training step: 12
# 	   12	5.551518781795058
# 	Training step: 13
# 	   13	5.532711437136628
# 	Training step: 14
# 	   14	5.515202012172965
# 	Training step: 15
# 	   15	5.498919535792151
# 	Training step: 16
# 	   16	5.483801553415698
# 	Training step: 17
# 	   17	5.469798669149709
# 	Training step: 18
# 	   18	5.4568484284156975
# 	Training step: 19
# 	   19	5.444896893168605
# 	Training step: 20
# 	   20	5.433877634447675
# 	Training step: 21
# 	   21	5.423722519985465
# 	Training step: 22
# 	   22	5.414363417514535
# 	Training step: 23
# 	   23	5.405728220385174
# 	Training step: 24
# 	   24	5.397752770712209
# 	Training step: 25
# 	   25	5.390369503997093
# 	Training step: 26
# 	   26	5.383530727652616
# 	Training step: 27
# 	   27	5.377179097020349
# 	Training step: 28
# 	   28	5.371277707122093
# 	Training step: 29
# 	   29	5.365782271984012
# 	Training step: 30
# 	   30	5.360653047783431
# 	Training step: 31
# 	   31	5.355864484920058
# 	Training step: 32
# 	   32	5.351390466024709
# 	Training step: 33
# 	   33	5.347204873728198
# 	Training step: 34
# 	   34	5.343292946039244
# 	Training step: 35
# 	   35	5.339645030886628
# 	Training step: 36
# 	   36	5.336249772892442
# 	Training step: 37
# 	   37	5.333095248909884
# 	Training step: 38
# 	   38	5.3301740779433135
# 	Training step: 39
# 	   39	5.327476607921511
# 	Training step: 40
# 	   40	5.324986941315407
# 	Training step: 41
# 	   41	5.322685206213663
# 	Training step: 42
# 	   42	5.320561182776163
# 	Training step: 43
# 	   43	5.318591592478198
# 	Training step: 44
# 	   44	5.31675656340843
# 	Training step: 45
# 	   45	5.315044172420058
# 	Training step: 46
# 	   46	5.313443064135174
# 	Training step: 47
# 	   47	5.31194585755814
# 	Training step: 48
# 	   48	5.31053949400436
# 	Training step: 49
# 	   49	5.309223405704942
# 	Training step: 50
# 	   50	5.307989643895349
# 	Training step: 51
# 	   51	5.306833098655523
# 	Training step: 52
# 	   52	5.305749795603198
# 	Training step: 53
# 	   53	5.304734057049418
# 	Training step: 54
# 	   54	5.303776230922965
# 	Training step: 55
# 	   55	5.302880291606105
# 	Training step: 56
# 	   56	5.302030909338662
# 	Training step: 57
# 	   57	5.301231490734011
# 	Training step: 58
# 	   58	5.300469544876454
# 	Training step: 59
# 	   59	5.299745639534883
# 	Training step: 60
# 	   60	5.299052393713663
# 	Training step: 61
# 	   61	5.298391510719477
# 	Training step: 62
# 	   62	5.2977550417877906
# 	Training step: 63
# 	   63	5.2971446902252906
# 	Training step: 64
# 	   64	5.296554778343023
# 	Training step: 65
# 	   65	5.2959932549055235
# 	Training step: 66
# 	   66	5.295452171148256
# 	Training step: 67
# 	   67	5.2949309593023255
# 	Training step: 68
# 	   68	5.294430754905523
# 	Training step: 69
# 	   69	5.293948719113372
# 	Training step: 70
# 	   70	5.2934825808502906
# 	Training step: 71
# 	   71	5.293031204578488
# 	Training step: 72
# 	   72	5.2925928869912795
# 	Training step: 73
# 	   73	5.292168763626454
# 	Training step: 74
# 	   74	5.291750885719477
# 	Training step: 75
# 	   75	5.291346066497093
# 	Training step: 76
# 	   76	5.290950899345931
# 	Training step: 77
# 	   77	5.290563680959302
# 	Training step: 78
# 	   78	5.290182140261628
# 	Training step: 79
# 	   79	5.289809683866279
# 	Training step: 80
# 	   80	5.28944574400436
# 	Training step: 81
# 	   81	5.2890880496002906
# 	Training step: 82
# 	   82	5.288737736191861
# 	Training step: 83
# 	   83	5.288394803779069
# 	Training step: 84
# 	   84	5.288052439135174
# 	Training step: 85
# 	   85	5.287719158793605
# 	Training step: 86
# 	   86	5.287388149527616
# 	Training step: 87
# 	   87	5.2870667923328485
# 	Training step: 88
# 	   88	5.286744867369186
# 	Training step: 89
# 	   89	5.286428052325581
# 	Training step: 90
# 	   90	5.28611577943314
# 	Training step: 91
# 	   91	5.285804642078489
# 	Training step: 92
# 	   92	5.285498046875
# 	Training step: 93
# 	   93	5.28519656159157
# 	Training step: 94
# 	   94	5.284894508539244
# 	Training step: 95
# 	   95	5.284598133175872
# 	Training step: 96
# 	   96	5.284304596656977
# 	Training step: 97
# 	   97	5.2840138989825585
# 	Training step: 98
# 	   98	5.283723201308139
# 	Training step: 99
# 	   99	5.283439316860465

# %%
from pyro.infer import Predictive


num_samples = 1000
predictive = Predictive(model, guide=guide, num_samples=num_samples)

# %%
svi_samples = {k: v.detach().cpu().numpy()
           for k, v in predictive(sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size, include_prior=False).items()
           if k != "obs"}

# %%
dir(svi)
# Out:
# ['__abstractmethods__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_categorical',
#  '_idx_by_chain',
#  '_reset',
#  '_traces',
#  'chain_ids',
#  'evaluate_loss',
#  'exec_traces',
#  'guide',
#  'information_criterion',
#  'log_weights',
#  'loss',
#  'loss_and_grads',
#  'marginal',
#  'model',
#  'num_chains',
#  'num_samples',
#  'num_steps',
#  'optim',
#  'run',
#  'step']

# %%
svi_samples["probs_x"].shape
# Out:
# (1000, 1, 7, 7)

# %%
translation_matrix = np.mean(svi_samples["probs_x"], axis=0).reshape((7,7))

# %%
pyro.get_param_store()

# %%
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}

# %%
confusion_matrix_test_table = pd.DataFrame(
data=translation_matrix,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table
# Out:
#                         Not_Oriented  Oriented  Precieved_Not_Oriented  \
# Not_Oriented                0.522551  0.005990                0.291232
# Oriented                    0.004407  0.726990                0.015010
# Precieved_Not_Oriented      0.293806  0.015000                0.313824
# Precieved_Oriented          0.004289  0.180034                0.007618
# Slanted                     0.060348  0.004428                0.610174
# Unidentified                0.079511  0.179855                0.225463
# No_sample                   0.226838  0.273374                0.148346
#
#                         Precieved_Oriented   Slanted  Unidentified  No_sample
# Not_Oriented                      0.005623  0.006234      0.161763   0.006605
# Oriented                          0.016219  0.003330      0.229130   0.004908
# Precieved_Not_Oriented            0.011298  0.004338      0.353251   0.008478
# Precieved_Oriented                0.036539  0.003174      0.763774   0.004582
# Slanted                           0.015538  0.013559      0.278881   0.017069
# Unidentified                      0.019644  0.003299      0.485070   0.007163
# No_sample                         0.003117  0.002603      0.264377   0.081344

# %%
test_class_count = confusion_matrix_test_table.sum(axis=1)
test_class_count
# Out:
# Not_Oriented              0.999999
# Oriented                  0.999994
# Precieved_Not_Oriented    0.999996
# Precieved_Oriented        1.000009
# Slanted                   0.999997
# Unidentified              1.000007
# No_sample                 0.999999
# dtype: float32

# %%
sequences[0,:]
# Out:
# tensor([2, 4, 1, 4, 4, 3, 3, 3, 1, 3, 3, 1, 1, 3, 1, 1, 3, 1, 3, 1],
#        dtype=torch.int32)

# %%
translation_matrix = np.mean(svi_samples["probs_x"], axis=0).reshape((7,7))

# %%
confusion_matrix_test_table = pd.DataFrame(
data=translation_matrix,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table
# Out:
#                         Not_Oriented  Oriented  Precieved_Not_Oriented  \
# Not_Oriented                0.522551  0.005990                0.291232
# Oriented                    0.004407  0.726990                0.015010
# Precieved_Not_Oriented      0.293806  0.015000                0.313824
# Precieved_Oriented          0.004289  0.180034                0.007618
# Slanted                     0.060348  0.004428                0.610174
# Unidentified                0.079511  0.179855                0.225463
# No_sample                   0.226838  0.273374                0.148346
#
#                         Precieved_Oriented   Slanted  Unidentified  No_sample
# Not_Oriented                      0.005623  0.006234      0.161763   0.006605
# Oriented                          0.016219  0.003330      0.229130   0.004908
# Precieved_Not_Oriented            0.011298  0.004338      0.353251   0.008478
# Precieved_Oriented                0.036539  0.003174      0.763774   0.004582
# Slanted                           0.015538  0.013559      0.278881   0.017069
# Unidentified                      0.019644  0.003299      0.485070   0.007163
# No_sample                         0.003117  0.002603      0.264377   0.081344

# %%
# Dataset loading
def load_sequences_np(dataset_path):
    sequences = {"train": {}}
    
#     sequence_list = [torch.Tensor(x) for x in np.load(str(dataset_path))]
    
    sequences_tensor = np.load(str(dataset_path))
    
    
    sequences["train"]["sequence_lengths"] = np.array([len(sequence) for sequence in sequences_tensor])
    sequences["train"]["sequences"] = sequences_tensor
    return sequences

# %%
data = load_sequences_np(args.dataset_path)

# %%
sequences = data['train']['sequences']
lengths = data['train']['sequence_lengths']

# %%
sequences.reshape(-1)

# %%
lengths

# %%
emission_matrix_np = np.load(args.emission_matrix_path)

# %%
from hmmlearn import hmm

# %%
model = hmm.MultinomialHMM(n_components=7, n_iter=10000, params="st", init_params="st")

# %%
model.emissionprob_ = emission_matrix_np

# %%
model.fit(sequences.reshape(-1, 1), lengths)

# %%
model.emissionprob_

# %%
model.transmat_

# %%
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}
confusion_matrix_test_table = pd.DataFrame(
data=model.transmat_,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
model = hmm.MultinomialHMM(n_components=7, n_iter=50, params="st", init_params="st")
model.emissionprob_ = emission_matrix_np
model.fit(sequences.reshape(-1, 1), lengths)
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}
confusion_matrix_test_table = pd.DataFrame(
data=model.transmat_,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
model = hmm.MultinomialHMM(n_components=7, n_iter=500, params="st", init_params="st")
model.emissionprob_ = emission_matrix_np
model.fit(sequences.reshape(-1, 1), lengths)
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}
confusion_matrix_test_table = pd.DataFrame(
data=model.transmat_,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
transition_matrix = np.array([[9.17269248e-001, 6.53003806e-118, 8.23362715e-002,
        7.72427778e-085, 1.53698963e-014, 3.43175139e-011,
        3.94480110e-004],
       [1.49172147e-161, 8.73311971e-001, 1.82502958e-049,
        1.26687948e-001, 8.14069900e-008, 1.46260187e-014,
        1.51752796e-026],
       [1.41727846e-003, 1.18840441e-019, 9.49950247e-001,
        1.82914991e-003, 9.07768488e-003, 2.60561958e-002,
        1.16694438e-002],
       [6.51786889e-084, 1.39464295e-002, 1.01244429e-018,
        8.97187712e-001, 8.36640492e-002, 4.86750640e-005,
        5.15313390e-003],
       [6.15269241e-003, 2.86600087e-010, 3.19099140e-002,
        4.01633777e-002, 9.05916897e-001, 1.58571186e-002,
        1.00840900e-032],
       [3.72329494e-005, 5.49847908e-003, 2.38550441e-002,
        3.82597321e-003, 7.01993013e-002, 8.82466367e-001,
        1.41176022e-002],
       [3.63508204e-009, 4.16695519e-002, 1.42071041e-001,
        2.19540222e-032, 6.30280002e-029, 1.49592737e-001,
        6.66666667e-001]])
print(f"HMM transitions")
print(f"Oriented to slanted: {transition_matrix[1, 4] + transition_matrix[3,4]}")
print(f"slanted to oriented: {transition_matrix[4, 1] + transition_matrix[4,3]}")
print(f"unoriented to slanted: {transition_matrix[0, 4] + transition_matrix[2,4]}")
print(f"slanted to unoriented: {transition_matrix[4, 0] + transition_matrix[4,2]}")

# %%
sequences[1, :]

# %%
model.decode(sequences[1,:].reshape(-1,1))

# %%
sequences[0, :]

# %%
model.decode(sequences[0,:].reshape(-1,1))

# %%
naive_transition_matrix = np.zeros((7,7))
for sequence in sequences:
    prev_state = 6
    for state in sequence:
#         print(state)
        naive_transition_matrix[prev_state, state] += 1
        prev_state = state

# %%
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}
naive_transition_matrix = naive_transition_matrix / np.sum(naive_transition_matrix, axis=1).reshape((-1, 1))
print(naive_transition_matrix.sum(axis=1))

confusion_matrix_test_table = pd.DataFrame(
data=naive_transition_matrix,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
transition_matrix = naive_transition_matrix
print(f"Naive CNN transitions")
print(f"Oriented to slanted: {transition_matrix[1, 4] + transition_matrix[3,4]}")
print(f"slanted to oriented: {transition_matrix[4, 1] + transition_matrix[4,3]}")
print(f"unoriented to slanted: {transition_matrix[0, 4] + transition_matrix[2,4]}")
print(f"slanted to unoriented: {transition_matrix[4, 0] + transition_matrix[4,2]}")

# %%
X, Z = model.sample(100)

# %%
X

# %%
Z
