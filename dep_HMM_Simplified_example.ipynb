# %%
# Magics

# %%
# Imports

# %%
import argparse
import logging
import sys
from pathlib import Path

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.distributions import constraints

import pyro
import pyro.contrib.examples.polyphonic_data_loader as poly
import pyro.distributions as dist
from pyro import poutine
from pyro.infer import SVI, JitTraceEnum_ELBO, TraceEnum_ELBO, TraceTMC_ELBO
from pyro.infer.autoguide import AutoDelta
from pyro.ops.indexing import Vindex
from pyro.optim import Adam
from pyro.util import ignore_jit_warnings

# %%
# Settings

# %%
torch.set_default_tensor_type('torch.cuda.FloatTensor')
seed = 0
batch_size = 8
learning_rate = 0.05
num_steps = 200

# %%
# Code

# %%
# Dataset loading
def load_sequences():
    
    transition = torch.Tensor([[0.9,  0.05, 0.05],
                              [0.05, 0.9, 0.05],
                              [0.05, 0.05, 0.9],
                              ]
                               )
    emission = torch.Tensor(
    [
        [0.6, 0.3, 0.1],
        [0.1, 0.7, 0.2],
        [0.2, 0.3, 0.5],
    ])
    
    samples = []
    
    for j in torch.range(0, 50):
        observations = []
        
        state = pyro.sample("x_{}_0".format(j),
                                    dist.Categorical(torch.Tensor([1.0/3, 1.0/3, 1.0/3])),
                                   )
        emission_p_t = emission[state]

        observation = pyro.sample("y_{}_0".format(j),
                                    dist.Categorical(emission_p_t),
                                   )
        for k in torch.range(1, 50):
            transition_p_t = transition[state]
            
            state = pyro.sample("x_{}_{}".format(j, k),
                                    dist.Categorical(transition_p_t),
                                   )
            emission_p_t = emission[state]
            
            observation = pyro.sample("y_{}_{}".format(j, k),
                                    dist.Categorical(emission_p_t),
                                   )
        
            observations.append(observation)
            
        sample = torch.Tensor(observations)
        samples.append(sample)

    sequences_tensor = torch.vstack(samples)
    
    return sequences_tensor, torch.Tensor(np.array([len(sequence) for sequence in sequences_tensor])).to(torch.int), emission, transition

# %%
sequences, lengths, emission, transition = load_sequences()
# Out:
# C:\Users\cwild\.conda\envs\nic\lib\site-packages\ipykernel_launcher.py:18: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
# C:\Users\cwild\.conda\envs\nic\lib\site-packages\ipykernel_launcher.py:29: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).

# %%
sequences
# Out:
# tensor([[0., 2., 1.,  ..., 0., 1., 0.],
#         [0., 1., 2.,  ..., 2., 1., 0.],
#         [1., 1., 1.,  ..., 2., 2., 1.],
#         ...,
#         [0., 2., 2.,  ..., 1., 1., 0.],
#         [1., 0., 2.,  ..., 0., 0., 0.],
#         [0., 0., 0.,  ..., 1., 0., 0.]])

# %%
def model_0(sequences, lengths, emission_matrix, data_dim = 3, batch_size=None, include_prior=True, prediction=False):
    with ignore_jit_warnings():
        num_sequences, max_length = map(int, sequences.shape)
        assert lengths.shape == (num_sequences,)
        assert lengths.max() <= max_length
        


    with poutine.mask(mask=include_prior):
        probs_x = pyro.sample("probs_x",
                              dist.Dirichlet(0.9 * torch.eye(3) + 0.1)
                                  .to_event(1))

    tones_plate = pyro.plate("tones", data_dim, dim=-1)


    for i in pyro.plate("sequences", len(sequences)):
        length = lengths[i]
        sequence = sequences[i, :length]
        if prediction:
            print(f"{i} {length} {sequence}")
        x = 0
        for t in pyro.markov(range(length)):

            x = pyro.sample("x_{}_{}".format(i, t), dist.Categorical(probs_x[x]),
                            infer={"enumerate": "parallel"})
            with tones_plate:
                p_y_t = emission_matrix[x]

                pyro.sample("y_{}_{}".format(i, t), 
                            dist.Categorical(p_y_t),
                            obs=sequence[t])

# %%
num_observations = float(lengths.sum())
pyro.set_rng_seed(seed)
pyro.clear_param_store()

# %%
# We'll train using MAP Baum-Welch, i.e. MAP estimation while marginalizing
# out the hidden state x. This is accomplished via an automatic guide that
# learns point estimates of all of our conditional probability tables,
# named probs_*.
guide = AutoDelta(poutine.block(model_0, expose_fn=lambda msg: msg["name"].startswith("probs_")))

# %%
first_available_dim = -2

# %%
guide_trace = poutine.trace(guide).get_trace(
    sequences, lengths, emission)

# %%
model_trace = poutine.trace(
    poutine.replay(poutine.enum(model_0, first_available_dim), guide_trace)).get_trace(
    sequences, lengths, emission)
logging.info(model_trace.format_shapes())
print(model_trace.format_shapes())
# Out:
#  Trace Shapes:
#   Param Sites:
#  Sample Sites:
#   probs_x dist        | 3 3
#          value        | 3 3
#     tones dist        |
#          value      3 |
# sequences dist        |
#          value     51 |
#     x_0_0 dist        |
#          value   3  1 |
#     y_0_0 dist   3  3 |
#          value        |
#     x_0_1 dist   3  1 |
#          value 3 1  1 |
#     y_0_1 dist 3 1  3 |
#          value        |
#     x_0_2 dist 3 1  1 |
#          value   3  1 |
#     y_0_2 dist   3  3 |
#          value        |
#     x_0_3 dist   3  1 |
#          value 3 1  1 |
#     y_0_3 dist 3 1  3 |
#          value        |
#     x_0_4 dist 3 1  1 |
#          value   3  1 |
#     y_0_4 dist   3  3 |
#          value        |
#     x_0_5 dist   3  1 |
#          value 3 1  1 |
#     y_0_5 dist 3 1  3 |
#          value        |
#     x_0_6 dist 3 1  1 |
#          value   3  1 |
#     y_0_6 dist   3  3 |
#          value        |
#     x_0_7 dist   3  1 |
#          value 3 1  1 |
#     y_0_7 dist 3 1  3 |
#          value        |
#     x_0_8 dist 3 1  1 |
#          value   3  1 |
#     y_0_8 dist   3  3 |
#          value        |
#     x_0_9 dist   3  1 |
#          value 3 1  1 |
#     y_0_9 dist 3 1  3 |
#          value        |
#    x_0_10 dist 3 1  1 |
#          value   3  1 |
#    y_0_10 dist   3  3 |
#          value        |
#    x_0_11 dist   3  1 |
#          value 3 1  1 |
#    y_0_11 dist 3 1  3 |
#          value        |
#    x_0_12 dist 3 1  1 |
#          value   3  1 |
#    y_0_12 dist   3  3 |
#          value        |
#    x_0_13 dist   3  1 |
#          value 3 1  1 |
#    y_0_13 dist 3 1  3 |
#          value        |
#    x_0_14 dist 3 1  1 |
#          value   3  1 |
#    y_0_14 dist   3  3 |
#          value        |
#    x_0_15 dist   3  1 |
#          value 3 1  1 |
#    y_0_15 dist 3 1  3 |
#          value        |
#    x_0_16 dist 3 1  1 |
#          value   3  1 |
#    y_0_16 dist   3  3 |
#          value        |
#    x_0_17 dist   3  1 |
#          value 3 1  1 |
#    y_0_17 dist 3 1  3 |
#          value        |
#    x_0_18 dist 3 1  1 |
#          value   3  1 |
#    y_0_18 dist   3  3 |
#          value        |
#    x_0_19 dist   3  1 |
#          value 3 1  1 |
#    y_0_19 dist 3 1  3 |
#          value        |
#    x_0_20 dist 3 1  1 |
#          value   3  1 |
#    y_0_20 dist   3  3 |
#          value        |
#    x_0_21 dist   3  1 |
#          value 3 1  1 |
#    y_0_21 dist 3 1  3 |
#          value        |
#    x_0_22 dist 3 1  1 |
#          value   3  1 |
#    y_0_22 dist   3  3 |
#          value        |
#    x_0_23 dist   3  1 |
#          value 3 1  1 |
#    y_0_23 dist 3 1  3 |
#          value        |
#    x_0_24 dist 3 1  1 |
#          value   3  1 |
#    y_0_24 dist   3  3 |
#          value        |
#    x_0_25 dist   3  1 |
#          value 3 1  1 |
#    y_0_25 dist 3 1  3 |
#          value        |
#    x_0_26 dist 3 1  1 |
#          value   3  1 |
#    y_0_26 dist   3  3 |
#          value        |
#    x_0_27 dist   3  1 |
#          value 3 1  1 |
#    y_0_27 dist 3 1  3 |
#          value        |
#    x_0_28 dist 3 1  1 |
#          value   3  1 |
#    y_0_28 dist   3  3 |
#          value        |
#    x_0_29 dist   3  1 |
#          value 3 1  1 |
#    y_0_29 dist 3 1  3 |
#          value        |
#    x_0_30 dist 3 1  1 |
#          value   3  1 |
#    y_0_30 dist   3  3 |
#          value        |
#    x_0_31 dist   3  1 |
#          value 3 1  1 |
#    y_0_31 dist 3 1  3 |
#          value        |
#    x_0_32 dist 3 1  1 |
#          value   3  1 |
#    y_0_32 dist   3  3 |
#          value        |
#    x_0_33 dist   3  1 |
#          value 3 1  1 |
#    y_0_33 dist 3 1  3 |
#          value        |
#    x_0_34 dist 3 1  1 |
#          value   3  1 |
#    y_0_34 dist   3  3 |
#          value        |
#    x_0_35 dist   3  1 |
#          value 3 1  1 |
#    y_0_35 dist 3 1  3 |
#          value        |
#    x_0_36 dist 3 1  1 |
#          value   3  1 |
#    y_0_36 dist   3  3 |
#          value        |
#    x_0_37 dist   3  1 |
#          value 3 1  1 |
#    y_0_37 dist 3 1  3 |
#          value        |
#    x_0_38 dist 3 1  1 |
#          value   3  1 |
#    y_0_38 dist   3  3 |
#          value        |
#    x_0_39 dist   3  1 |
#          value 3 1  1 |
#    y_0_39 dist 3 1  3 |
#          value        |
#    x_0_40 dist 3 1  1 |
#          value   3  1 |
#    y_0_40 dist   3  3 |
#          value        |
#    x_0_41 dist   3  1 |
#          value 3 1  1 |
#    y_0_41 dist 3 1  3 |
#          value        |
#    x_0_42 dist 3 1  1 |
#          value   3  1 |
#    y_0_42 dist   3  3 |
#          value        |
#    x_0_43 dist   3  1 |
#          value 3 1  1 |
#    y_0_43 dist 3 1  3 |
#          value        |
#    x_0_44 dist 3 1  1 |
#          value   3  1 |
#    y_0_44 dist   3  3 |
#          value        |
#    x_0_45 dist   3  1 |
#          value 3 1  1 |
#    y_0_45 dist 3 1  3 |
#          value        |
#    x_0_46 dist 3 1  1 |
#          value   3  1 |
#    y_0_46 dist   3  3 |
#          value        |
#    x_0_47 dist   3  1 |
#          value 3 1  1 |
#    y_0_47 dist 3 1  3 |
#          value        |
#    x_0_48 dist 3 1  1 |
#          value   3  1 |
#    y_0_48 dist   3  3 |
#          value        |
#    x_0_49 dist   3  1 |
#          value 3 1  1 |
#    y_0_49 dist 3 1  3 |
#          value        |
#     x_1_0 dist        |
#          value   3  1 |
#     y_1_0 dist   3  3 |
#          value        |
#     x_1_1 dist   3  1 |
#          value 3 1  1 |
#     y_1_1 dist 3 1  3 |
#          value        |
#     x_1_2 dist 3 1  1 |
#          value   3  1 |
#     y_1_2 dist   3  3 |
#          value        |
#     x_1_3 dist   3  1 |
#          value 3 1  1 |
#     y_1_3 dist 3 1  3 |
#          value        |
#     x_1_4 dist 3 1  1 |
#          value   3  1 |
#     y_1_4 dist   3  3 |
#          value        |
#     x_1_5 dist   3  1 |
#          value 3 1  1 |
#     y_1_5 dist 3 1  3 |
#          value        |
#     x_1_6 dist 3 1  1 |
#          value   3  1 |
#     y_1_6 dist   3  3 |
#          value        |
#     x_1_7 dist   3  1 |
#          value 3 1  1 |
#     y_1_7 dist 3 1  3 |
#          value        |
#     x_1_8 dist 3 1  1 |
#          value   3  1 |
#     y_1_8 dist   3  3 |
#          value        |
#     x_1_9 dist   3  1 |
#          value 3 1  1 |
#     y_1_9 dist 3 1  3 |
#          value        |
#    x_1_10 dist 3 1  1 |
#          value   3  1 |
#    y_1_10 dist   3  3 |
#          value        |
#    x_1_11 dist   3  1 |
#          value 3 1  1 |
#    y_1_11 dist 3 1  3 |
#          value        |
#    x_1_12 dist 3 1  1 |
#          value   3  1 |
#    y_1_12 dist   3  3 |
#          value        |
#    x_1_13 dist   3  1 |
#          value 3 1  1 |
#    y_1_13 dist 3 1  3 |
#          value        |
#    x_1_14 dist 3 1  1 |
#          value   3  1 |
#    y_1_14 dist   3  3 |
#          value        |
#    x_1_15 dist   3  1 |
#          value 3 1  1 |
#    y_1_15 dist 3 1  3 |
#          value        |
#    x_1_16 dist 3 1  1 |
#          value   3  1 |
#    y_1_16 dist   3  3 |
#          value        |
#    x_1_17 dist   3  1 |
#          value 3 1  1 |
#    y_1_17 dist 3 1  3 |
#          value        |
#    x_1_18 dist 3 1  1 |
#          value   3  1 |
#    y_1_18 dist   3  3 |
#          value        |
#    x_1_19 dist   3  1 |
#          value 3 1  1 |
#    y_1_19 dist 3 1  3 |
#          value        |
#    x_1_20 dist 3 1  1 |
#          value   3  1 |
#    y_1_20 dist   3  3 |
#          value        |
#    x_1_21 dist   3  1 |
#          value 3 1  1 |
#    y_1_21 dist 3 1  3 |
#          value        |
#    x_1_22 dist 3 1  1 |
#          value   3  1 |
#    y_1_22 dist   3  3 |
#          value        |
#    x_1_23 dist   3  1 |
#          value 3 1  1 |
#    y_1_23 dist 3 1  3 |
#          value        |
#    x_1_24 dist 3 1  1 |
#          value   3  1 |
#    y_1_24 dist   3  3 |
#          value        |
#    x_1_25 dist   3  1 |
#          value 3 1  1 |
#    y_1_25 dist 3 1  3 |
#          value        |
#    x_1_26 dist 3 1  1 |
#          value   3  1 |
#    y_1_26 dist   3  3 |
#          value        |
#    x_1_27 dist   3  1 |
#          value 3 1  1 |
#    y_1_27 dist 3 1  3 |
#          value        |
#    x_1_28 dist 3 1  1 |
#          value   3  1 |
#    y_1_28 dist   3  3 |
#          value        |
#    x_1_29 dist   3  1 |
#          value 3 1  1 |
#    y_1_29 dist 3 1  3 |
#          value        |
#    x_1_30 dist 3 1  1 |
#          value   3  1 |
#    y_1_30 dist   3  3 |
#          value        |
#    x_1_31 dist   3  1 |
#          value 3 1  1 |
#    y_1_31 dist 3 1  3 |
#          value        |
#    x_1_32 dist 3 1  1 |
#          value   3  1 |
#    y_1_32 dist   3  3 |
#          value        |
#    x_1_33 dist   3  1 |
#          value 3 1  1 |
#    y_1_33 dist 3 1  3 |
#          value        |
#    x_1_34 dist 3 1  1 |
#          value   3  1 |
#    y_1_34 dist   3  3 |
#          value        |
#    x_1_35 dist   3  1 |
#          value 3 1  1 |
#    y_1_35 dist 3 1  3 |
#          value        |
#    x_1_36 dist 3 1  1 |
#          value   3  1 |
#    y_1_36 dist   3  3 |
#          value        |
#    x_1_37 dist   3  1 |
#          value 3 1  1 |
#    y_1_37 dist 3 1  3 |
#          value        |
#    x_1_38 dist 3 1  1 |
#          value   3  1 |
#    y_1_38 dist   3  3 |
#          value        |
#    x_1_39 dist   3  1 |
#          value 3 1  1 |
#    y_1_39 dist 3 1  3 |
#          value        |
#    x_1_40 dist 3 1  1 |
#          value   3  1 |
#    y_1_40 dist   3  3 |
#          value        |
#    x_1_41 dist   3  1 |
#          value 3 1  1 |
#    y_1_41 dist 3 1  3 |
#          value        |
#    x_1_42 dist 3 1  1 |
#          value   3  1 |
#    y_1_42 dist   3  3 |
#          value        |
#    x_1_43 dist   3  1 |
#          value 3 1  1 |
#    y_1_43 dist 3 1  3 |
#          value        |
#    x_1_44 dist 3 1  1 |
#          value   3  1 |
#    y_1_44 dist   3  3 |
#          value        |
#    x_1_45 dist   3  1 |
#          value 3 1  1 |
#    y_1_45 dist 3 1  3 |
#          value        |
#    x_1_46 dist 3 1  1 |
#          value   3  1 |
#    y_1_46 dist   3  3 |
#          value        |
#    x_1_47 dist   3  1 |
#          value 3 1  1 |
#    y_1_47 dist 3 1  3 |
#          value        |
#    x_1_48 dist 3 1  1 |
#          value   3  1 |
#    y_1_48 dist   3  3 |
#          value        |
#    x_1_49 dist   3  1 |
#          value 3 1  1 |
#    y_1_49 dist 3 1  3 |
#          value        |
#     x_2_0 dist        |
#          value   3  1 |
#     y_2_0 dist   3  3 |
#          value        |
#     x_2_1 dist   3  1 |
#          value 3 1  1 |
#     y_2_1 dist 3 1  3 |
#          value        |
#     x_2_2 dist 3 1  1 |
#          value   3  1 |
#     y_2_2 dist   3  3 |
#          value        |
#     x_2_3 dist   3  1 |
#          value 3 1  1 |
#     y_2_3 dist 3 1  3 |
#          value        |
#     x_2_4 dist 3 1  1 |
#          value   3  1 |
#     y_2_4 dist   3  3 |
#          value        |
#     x_2_5 dist   3  1 |
#          value 3 1  1 |
#     y_2_5 dist 3 1  3 |
#          value        |
#     x_2_6 dist 3 1  1 |
#          value   3  1 |
#     y_2_6 dist   3  3 |
#          value        |
#     x_2_7 dist   3  1 |
#          value 3 1  1 |
#     y_2_7 dist 3 1  3 |
#          value        |
#     x_2_8 dist 3 1  1 |
#          value   3  1 |
#     y_2_8 dist   3  3 |
#          value        |
#     x_2_9 dist   3  1 |
#          value 3 1  1 |
#     y_2_9 dist 3 1  3 |
#          value        |
#    x_2_10 dist 3 1  1 |
#          value   3  1 |
#    y_2_10 dist   3  3 |
#          value        |
#    x_2_11 dist   3  1 |
#          value 3 1  1 |
#    y_2_11 dist 3 1  3 |
#          value        |
#    x_2_12 dist 3 1  1 |
#          value   3  1 |
#    y_2_12 dist   3  3 |
#          value        |
#    x_2_13 dist   3  1 |
#          value 3 1  1 |
#    y_2_13 dist 3 1  3 |
#          value        |
#    x_2_14 dist 3 1  1 |
#          value   3  1 |
#    y_2_14 dist   3  3 |
#          value        |
#    x_2_15 dist   3  1 |
#          value 3 1  1 |
#    y_2_15 dist 3 1  3 |
#          value        |
#    x_2_16 dist 3 1  1 |
#          value   3  1 |
#    y_2_16 dist   3  3 |
#          value        |
#    x_2_17 dist   3  1 |
#          value 3 1  1 |
#    y_2_17 dist 3 1  3 |
#          value        |
#    x_2_18 dist 3 1  1 |
#          value   3  1 |
#    y_2_18 dist   3  3 |
#          value        |
#    x_2_19 dist   3  1 |
#          value 3 1  1 |
#    y_2_19 dist 3 1  3 |
#          value        |
#    x_2_20 dist 3 1  1 |
#          value   3  1 |
#    y_2_20 dist   3  3 |
#          value        |
#    x_2_21 dist   3  1 |
#          value 3 1  1 |
#    y_2_21 dist 3 1  3 |
#          value        |
#    x_2_22 dist 3 1  1 |
#          value   3  1 |
#    y_2_22 dist   3  3 |
#          value        |
#    x_2_23 dist   3  1 |
#          value 3 1  1 |
#    y_2_23 dist 3 1  3 |
#          value        |
#    x_2_24 dist 3 1  1 |
#          value   3  1 |
#    y_2_24 dist   3  3 |
#          value        |
#    x_2_25 dist   3  1 |
#          value 3 1  1 |
#    y_2_25 dist 3 1  3 |
#          value        |
#    x_2_26 dist 3 1  1 |
#          value   3  1 |
#    y_2_26 dist   3  3 |
#          value        |
#    x_2_27 dist   3  1 |
#          value 3 1  1 |
#    y_2_27 dist 3 1  3 |
#          value        |
#    x_2_28 dist 3 1  1 |
#          value   3  1 |
#    y_2_28 dist   3  3 |
#          value        |
#    x_2_29 dist   3  1 |
#          value 3 1  1 |
#    y_2_29 dist 3 1  3 |
#          value        |
#    x_2_30 dist 3 1  1 |
#          value   3  1 |
#    y_2_30 dist   3  3 |
#          value        |
#    x_2_31 dist   3  1 |
#          value 3 1  1 |
#    y_2_31 dist 3 1  3 |
#          value        |
#    x_2_32 dist 3 1  1 |
#          value   3  1 |
#    y_2_32 dist   3  3 |
#          value        |
#    x_2_33 dist   3  1 |
#          value 3 1  1 |
#    y_2_33 dist 3 1  3 |
#          value        |
#    x_2_34 dist 3 1  1 |
#          value   3  1 |
#    y_2_34 dist   3  3 |
#          value        |
#    x_2_35 dist   3  1 |
#          value 3 1  1 |
#    y_2_35 dist 3 1  3 |
#          value        |
#    x_2_36 dist 3 1  1 |
#          value   3  1 |
#    y_2_36 dist   3  3 |
#          value        |
#    x_2_37 dist   3  1 |
#          value 3 1  1 |
#    y_2_37 dist 3 1  3 |
#          value        |
#    x_2_38 dist 3 1  1 |
#          value   3  1 |
#    y_2_38 dist   3  3 |
#          value        |
#    x_2_39 dist   3  1 |
#          value 3 1  1 |
#    y_2_39 dist 3 1  3 |
#          value        |
#    x_2_40 dist 3 1  1 |
#          value   3  1 |
#    y_2_40 dist   3  3 |
#          value        |
#    x_2_41 dist   3  1 |
#          value 3 1  1 |
#    y_2_41 dist 3 1  3 |
#          value        |
#    x_2_42 dist 3 1  1 |
#          value   3  1 |
#    y_2_42 dist   3  3 |
#          value        |
#    x_2_43 dist   3  1 |
#          value 3 1  1 |
#    y_2_43 dist 3 1  3 |
#          value        |
#    x_2_44 dist 3 1  1 |
#          value   3  1 |
#    y_2_44 dist   3  3 |
#          value        |
#    x_2_45 dist   3  1 |
#          value 3 1  1 |
#    y_2_45 dist 3 1  3 |
#          value        |
#    x_2_46 dist 3 1  1 |
#          value   3  1 |
#    y_2_46 dist   3  3 |
#          value        |
#    x_2_47 dist   3  1 |
#          value 3 1  1 |
#    y_2_47 dist 3 1  3 |
#          value        |
#    x_2_48 dist 3 1  1 |
#          value   3  1 |
#    y_2_48 dist   3  3 |
#          value        |
#    x_2_49 dist   3  1 |
#          value 3 1  1 |
#    y_2_49 dist 3 1  3 |
#          value        |
#     x_3_0 dist        |
#          value   3  1 |
#     y_3_0 dist   3  3 |
#          value        |
#     x_3_1 dist   3  1 |
#          value 3 1  1 |
#     y_3_1 dist 3 1  3 |
#          value        |
#     x_3_2 dist 3 1  1 |
#          value   3  1 |
#     y_3_2 dist   3  3 |
#          value        |
#     x_3_3 dist   3  1 |
#          value 3 1  1 |
#     y_3_3 dist 3 1  3 |
#          value        |
#     x_3_4 dist 3 1  1 |
#          value   3  1 |
#     y_3_4 dist   3  3 |
#          value        |
#     x_3_5 dist   3  1 |
#          value 3 1  1 |
#     y_3_5 dist 3 1  3 |
#          value        |
#     x_3_6 dist 3 1  1 |
#          value   3  1 |
#     y_3_6 dist   3  3 |
#          value        |
#     x_3_7 dist   3  1 |
#          value 3 1  1 |
#     y_3_7 dist 3 1  3 |
#          value        |
#     x_3_8 dist 3 1  1 |
#          value   3  1 |
#     y_3_8 dist   3  3 |
#          value        |
#     x_3_9 dist   3  1 |
#          value 3 1  1 |
#     y_3_9 dist 3 1  3 |
#          value        |
#    x_3_10 dist 3 1  1 |
#          value   3  1 |
#    y_3_10 dist   3  3 |
#          value        |
#    x_3_11 dist   3  1 |
#          value 3 1  1 |
#    y_3_11 dist 3 1  3 |
#          value        |
#    x_3_12 dist 3 1  1 |
#          value   3  1 |
#    y_3_12 dist   3  3 |
#          value        |
#    x_3_13 dist   3  1 |
#          value 3 1  1 |
#    y_3_13 dist 3 1  3 |
#          value        |
#    x_3_14 dist 3 1  1 |
#          value   3  1 |
#    y_3_14 dist   3  3 |
#          value        |
#    x_3_15 dist   3  1 |
#          value 3 1  1 |
#    y_3_15 dist 3 1  3 |
#          value        |
#    x_3_16 dist 3 1  1 |
#          value   3  1 |
#    y_3_16 dist   3  3 |
#          value        |
#    x_3_17 dist   3  1 |
#          value 3 1  1 |
#    y_3_17 dist 3 1  3 |
#          value        |
#    x_3_18 dist 3 1  1 |
#          value   3  1 |
#    y_3_18 dist   3  3 |
#          value        |
#    x_3_19 dist   3  1 |
#          value 3 1  1 |
#    y_3_19 dist 3 1  3 |
#          value        |
#    x_3_20 dist 3 1  1 |
#          value   3  1 |
#    y_3_20 dist   3  3 |
#          value        |
#    x_3_21 dist   3  1 |
#          value 3 1  1 |
#    y_3_21 dist 3 1  3 |
#          value        |
#    x_3_22 dist 3 1  1 |
#          value   3  1 |
#    y_3_22 dist   3  3 |
#          value        |
#    x_3_23 dist   3  1 |
#          value 3 1  1 |
#    y_3_23 dist 3 1  3 |
#          value        |
#    x_3_24 dist 3 1  1 |
#          value   3  1 |
#    y_3_24 dist   3  3 |
#          value        |
#    x_3_25 dist   3  1 |
#          value 3 1  1 |
#    y_3_25 dist 3 1  3 |
#          value        |
#    x_3_26 dist 3 1  1 |
#          value   3  1 |
#    y_3_26 dist   3  3 |
#          value        |
#    x_3_27 dist   3  1 |
#          value 3 1  1 |
#    y_3_27 dist 3 1  3 |
#          value        |
#    x_3_28 dist 3 1  1 |
#          value   3  1 |
#    y_3_28 dist   3  3 |
#          value        |
#    x_3_29 dist   3  1 |
#          value 3 1  1 |
#    y_3_29 dist 3 1  3 |
#          value        |
#    x_3_30 dist 3 1  1 |
#          value   3  1 |
#    y_3_30 dist   3  3 |
#          value        |
#    x_3_31 dist   3  1 |
#          value 3 1  1 |
#    y_3_31 dist 3 1  3 |
#          value        |
#    x_3_32 dist 3 1  1 |
#          value   3  1 |
#    y_3_32 dist   3  3 |
#          value        |
#    x_3_33 dist   3  1 |
#          value 3 1  1 |
#    y_3_33 dist 3 1  3 |
#          value        |
#    x_3_34 dist 3 1  1 |
#          value   3  1 |
#    y_3_34 dist   3  3 |
#          value        |
#    x_3_35 dist   3  1 |
#          value 3 1  1 |
#    y_3_35 dist 3 1  3 |
#          value        |
#    x_3_36 dist 3 1  1 |
#          value   3  1 |
#    y_3_36 dist   3  3 |
#          value        |
#    x_3_37 dist   3  1 |
#          value 3 1  1 |
#    y_3_37 dist 3 1  3 |
#          value        |
#    x_3_38 dist 3 1  1 |
#          value   3  1 |
#    y_3_38 dist   3  3 |
#          value        |
#    x_3_39 dist   3  1 |
#          value 3 1  1 |
#    y_3_39 dist 3 1  3 |
#          value        |
#    x_3_40 dist 3 1  1 |
#          value   3  1 |
#    y_3_40 dist   3  3 |
#          value        |
#    x_3_41 dist   3  1 |
#          value 3 1  1 |
#    y_3_41 dist 3 1  3 |
#          value        |
#    x_3_42 dist 3 1  1 |
#          value   3  1 |
#    y_3_42 dist   3  3 |
#          value        |
#    x_3_43 dist   3  1 |
#          value 3 1  1 |
#    y_3_43 dist 3 1  3 |
#          value        |
#    x_3_44 dist 3 1  1 |
#          value   3  1 |
#    y_3_44 dist   3  3 |
#          value        |
#    x_3_45 dist   3  1 |
#          value 3 1  1 |
#    y_3_45 dist 3 1  3 |
#          value        |
#    x_3_46 dist 3 1  1 |
#          value   3  1 |
#    y_3_46 dist   3  3 |
#          value        |
#    x_3_47 dist   3  1 |
#          value 3 1  1 |
#    y_3_47 dist 3 1  3 |
#          value        |
#    x_3_48 dist 3 1  1 |
#          value   3  1 |
#    y_3_48 dist   3  3 |
#          value        |
#    x_3_49 dist   3  1 |
#          value 3 1  1 |
#    y_3_49 dist 3 1  3 |
#          value        |
#     x_4_0 dist        |
#          value   3  1 |
#     y_4_0 dist   3  3 |
#          value        |
#     x_4_1 dist   3  1 |
#          value 3 1  1 |
#     y_4_1 dist 3 1  3 |
#          value        |
#     x_4_2 dist 3 1  1 |
#          value   3  1 |
#     y_4_2 dist   3  3 |
#          value        |
#     x_4_3 dist   3  1 |
#          value 3 1  1 |
#     y_4_3 dist 3 1  3 |
#          value        |
#     x_4_4 dist 3 1  1 |
#          value   3  1 |
#     y_4_4 dist   3  3 |
#          value        |
#     x_4_5 dist   3  1 |
#          value 3 1  1 |
#     y_4_5 dist 3 1  3 |
#          value        |
#     x_4_6 dist 3 1  1 |
#          value   3  1 |
#     y_4_6 dist   3  3 |
#          value        |
#     x_4_7 dist   3  1 |
#          value 3 1  1 |
#     y_4_7 dist 3 1  3 |
#          value        |
#     x_4_8 dist 3 1  1 |
#          value   3  1 |
#     y_4_8 dist   3  3 |
#          value        |
#     x_4_9 dist   3  1 |
#          value 3 1  1 |
#     y_4_9 dist 3 1  3 |
#          value        |
#    x_4_10 dist 3 1  1 |
#          value   3  1 |
#    y_4_10 dist   3  3 |
#          value        |
#    x_4_11 dist   3  1 |
#          value 3 1  1 |
#    y_4_11 dist 3 1  3 |
#          value        |
#    x_4_12 dist 3 1  1 |
#          value   3  1 |
#    y_4_12 dist   3  3 |
#          value        |
#    x_4_13 dist   3  1 |
#          value 3 1  1 |
#    y_4_13 dist 3 1  3 |
#          value        |
#    x_4_14 dist 3 1  1 |
#          value   3  1 |
#    y_4_14 dist   3  3 |
#          value        |
#    x_4_15 dist   3  1 |
#          value 3 1  1 |
#    y_4_15 dist 3 1  3 |
#          value        |
#    x_4_16 dist 3 1  1 |
#          value   3  1 |
#    y_4_16 dist   3  3 |
#          value        |
#    x_4_17 dist   3  1 |
#          value 3 1  1 |
#    y_4_17 dist 3 1  3 |
#          value        |
#    x_4_18 dist 3 1  1 |
#          value   3  1 |
#    y_4_18 dist   3  3 |
#          value        |
#    x_4_19 dist   3  1 |
#          value 3 1  1 |
#    y_4_19 dist 3 1  3 |
#          value        |
#    x_4_20 dist 3 1  1 |
#          value   3  1 |
#    y_4_20 dist   3  3 |
#          value        |
#    x_4_21 dist   3  1 |
#          value 3 1  1 |
#    y_4_21 dist 3 1  3 |
#          value        |
#    x_4_22 dist 3 1  1 |
#          value   3  1 |
#    y_4_22 dist   3  3 |
#          value        |
#    x_4_23 dist   3  1 |
#          value 3 1  1 |
#    y_4_23 dist 3 1  3 |
#          value        |
#    x_4_24 dist 3 1  1 |
#          value   3  1 |
#    y_4_24 dist   3  3 |
#          value        |
#    x_4_25 dist   3  1 |
#          value 3 1  1 |
#    y_4_25 dist 3 1  3 |
#          value        |
#    x_4_26 dist 3 1  1 |
#          value   3  1 |
#    y_4_26 dist   3  3 |
#          value        |
#    x_4_27 dist   3  1 |
#          value 3 1  1 |
#    y_4_27 dist 3 1  3 |
#          value        |
#    x_4_28 dist 3 1  1 |
#          value   3  1 |
#    y_4_28 dist   3  3 |
#          value        |
#    x_4_29 dist   3  1 |
#          value 3 1  1 |
#    y_4_29 dist 3 1  3 |
#          value        |
#    x_4_30 dist 3 1  1 |
#          value   3  1 |
#    y_4_30 dist   3  3 |
#          value        |
#    x_4_31 dist   3  1 |
#          value 3 1  1 |
#    y_4_31 dist 3 1  3 |
#          value        |
#    x_4_32 dist 3 1  1 |
#          value   3  1 |
#    y_4_32 dist   3  3 |
#          value        |
#    x_4_33 dist   3  1 |
#          value 3 1  1 |
#    y_4_33 dist 3 1  3 |
#          value        |
#    x_4_34 dist 3 1  1 |
#          value   3  1 |
#    y_4_34 dist   3  3 |
#          value        |
#    x_4_35 dist   3  1 |
#          value 3 1  1 |
#    y_4_35 dist 3 1  3 |
#          value        |
#    x_4_36 dist 3 1  1 |
#          value   3  1 |
#    y_4_36 dist   3  3 |
#          value        |
#    x_4_37 dist   3  1 |
#          value 3 1  1 |
#    y_4_37 dist 3 1  3 |
#          value        |
#    x_4_38 dist 3 1  1 |
#          value   3  1 |
#    y_4_38 dist   3  3 |
#          value        |
#    x_4_39 dist   3  1 |
#          value 3 1  1 |
#    y_4_39 dist 3 1  3 |
#          value        |
#    x_4_40 dist 3 1  1 |
#          value   3  1 |
#    y_4_40 dist   3  3 |
#          value        |
#    x_4_41 dist   3  1 |
#          value 3 1  1 |
#    y_4_41 dist 3 1  3 |
#          value        |
#    x_4_42 dist 3 1  1 |
#          value   3  1 |
#    y_4_42 dist   3  3 |
#          value        |
#    x_4_43 dist   3  1 |
#          value 3 1  1 |
#    y_4_43 dist 3 1  3 |
#          value        |
#    x_4_44 dist 3 1  1 |
#          value   3  1 |
#    y_4_44 dist   3  3 |
#          value        |
#    x_4_45 dist   3  1 |
#          value 3 1  1 |
#    y_4_45 dist 3 1  3 |
#          value        |
#    x_4_46 dist 3 1  1 |
#          value   3  1 |
#    y_4_46 dist   3  3 |
#          value        |
#    x_4_47 dist   3  1 |
#          value 3 1  1 |
#    y_4_47 dist 3 1  3 |
#          value        |
#    x_4_48 dist 3 1  1 |
#          value   3  1 |
#    y_4_48 dist   3  3 |
#          value        |
#    x_4_49 dist   3  1 |
#          value 3 1  1 |
#    y_4_49 dist 3 1  3 |
#          value        |
#     x_5_0 dist        |
#          value   3  1 |
#     y_5_0 dist   3  3 |
#          value        |
#     x_5_1 dist   3  1 |
#          value 3 1  1 |
#     y_5_1 dist 3 1  3 |
#          value        |
#     x_5_2 dist 3 1  1 |
#          value   3  1 |
#     y_5_2 dist   3  3 |
#          value        |
#     x_5_3 dist   3  1 |
#          value 3 1  1 |
#     y_5_3 dist 3 1  3 |
#          value        |
#     x_5_4 dist 3 1  1 |
#          value   3  1 |
#     y_5_4 dist   3  3 |
#          value        |
#     x_5_5 dist   3  1 |
#          value 3 1  1 |
#     y_5_5 dist 3 1  3 |
#          value        |
#     x_5_6 dist 3 1  1 |
#          value   3  1 |
#     y_5_6 dist   3  3 |
#          value        |
#     x_5_7 dist   3  1 |
#          value 3 1  1 |
#     y_5_7 dist 3 1  3 |
#          value        |
#     x_5_8 dist 3 1  1 |
#          value   3  1 |
#     y_5_8 dist   3  3 |
#          value        |
#     x_5_9 dist   3  1 |
#          value 3 1  1 |
#     y_5_9 dist 3 1  3 |
#          value        |
#    x_5_10 dist 3 1  1 |
#          value   3  1 |
#    y_5_10 dist   3  3 |
#          value        |
#    x_5_11 dist   3  1 |
#          value 3 1  1 |
#    y_5_11 dist 3 1  3 |
#          value        |
#    x_5_12 dist 3 1  1 |
#          value   3  1 |
#    y_5_12 dist   3  3 |
#          value        |
#    x_5_13 dist   3  1 |
#          value 3 1  1 |
#    y_5_13 dist 3 1  3 |
#          value        |
#    x_5_14 dist 3 1  1 |
#          value   3  1 |
#    y_5_14 dist   3  3 |
#          value        |
#    x_5_15 dist   3  1 |
#          value 3 1  1 |
#    y_5_15 dist 3 1  3 |
#          value        |
#    x_5_16 dist 3 1  1 |
#          value   3  1 |
#    y_5_16 dist   3  3 |
#          value        |
#    x_5_17 dist   3  1 |
#          value 3 1  1 |
#    y_5_17 dist 3 1  3 |
#          value        |
#    x_5_18 dist 3 1  1 |
#          value   3  1 |
#    y_5_18 dist   3  3 |
#          value        |
#    x_5_19 dist   3  1 |
#          value 3 1  1 |
#    y_5_19 dist 3 1  3 |
#          value        |
#    x_5_20 dist 3 1  1 |
#          value   3  1 |
#    y_5_20 dist   3  3 |
#          value        |
#    x_5_21 dist   3  1 |
#          value 3 1  1 |
#    y_5_21 dist 3 1  3 |
#          value        |
#    x_5_22 dist 3 1  1 |
#          value   3  1 |
#    y_5_22 dist   3  3 |
#          value        |
#    x_5_23 dist   3  1 |
#          value 3 1  1 |
#    y_5_23 dist 3 1  3 |
#          value        |
#    x_5_24 dist 3 1  1 |
#          value   3  1 |
#    y_5_24 dist   3  3 |
#          value        |
#    x_5_25 dist   3  1 |
#          value 3 1  1 |
#    y_5_25 dist 3 1  3 |
#          value        |
#    x_5_26 dist 3 1  1 |
#          value   3  1 |
#    y_5_26 dist   3  3 |
#          value        |
#    x_5_27 dist   3  1 |
#          value 3 1  1 |
#    y_5_27 dist 3 1  3 |
#          value        |
#    x_5_28 dist 3 1  1 |
#          value   3  1 |
#    y_5_28 dist   3  3 |
#          value        |
#    x_5_29 dist   3  1 |
#          value 3 1  1 |
#    y_5_29 dist 3 1  3 |
#          value        |
#    x_5_30 dist 3 1  1 |
#          value   3  1 |
#    y_5_30 dist   3  3 |
#          value        |
#    x_5_31 dist   3  1 |
#          value 3 1  1 |
#    y_5_31 dist 3 1  3 |
#          value        |
#    x_5_32 dist 3 1  1 |
#          value   3  1 |
#    y_5_32 dist   3  3 |
#          value        |
#    x_5_33 dist   3  1 |
#          value 3 1  1 |
#    y_5_33 dist 3 1  3 |
#          value        |
#    x_5_34 dist 3 1  1 |
#          value   3  1 |
#    y_5_34 dist   3  3 |
#          value        |
#    x_5_35 dist   3  1 |
#          value 3 1  1 |
#    y_5_35 dist 3 1  3 |
#          value        |
#    x_5_36 dist 3 1  1 |
#          value   3  1 |
#    y_5_36 dist   3  3 |
#          value        |
#    x_5_37 dist   3  1 |
#          value 3 1  1 |
#    y_5_37 dist 3 1  3 |
#          value        |
#    x_5_38 dist 3 1  1 |
#          value   3  1 |
#    y_5_38 dist   3  3 |
#          value        |
#    x_5_39 dist   3  1 |
#          value 3 1  1 |
#    y_5_39 dist 3 1  3 |
#          value        |
#    x_5_40 dist 3 1  1 |
#          value   3  1 |
#    y_5_40 dist   3  3 |
#          value        |
#    x_5_41 dist   3  1 |
#          value 3 1  1 |
#    y_5_41 dist 3 1  3 |
#          value        |
#    x_5_42 dist 3 1  1 |
#          value   3  1 |
#    y_5_42 dist   3  3 |
#          value        |
#    x_5_43 dist   3  1 |
#          value 3 1  1 |
#    y_5_43 dist 3 1  3 |
#          value        |
#    x_5_44 dist 3 1  1 |
#          value   3  1 |
#    y_5_44 dist   3  3 |
#          value        |
#    x_5_45 dist   3  1 |
#          value 3 1  1 |
#    y_5_45 dist 3 1  3 |
#          value        |
#    x_5_46 dist 3 1  1 |
#          value   3  1 |
#    y_5_46 dist   3  3 |
#          value        |
#    x_5_47 dist   3  1 |
#          value 3 1  1 |
#    y_5_47 dist 3 1  3 |
#          value        |
#    x_5_48 dist 3 1  1 |
#          value   3  1 |
#    y_5_48 dist   3  3 |
#          value        |
#    x_5_49 dist   3  1 |
#          value 3 1  1 |
#    y_5_49 dist 3 1  3 |
#          value        |
#     x_6_0 dist        |
#          value   3  1 |
#     y_6_0 dist   3  3 |
#          value        |
#     x_6_1 dist   3  1 |
#          value 3 1  1 |
#     y_6_1 dist 3 1  3 |
#          value        |
#     x_6_2 dist 3 1  1 |
#          value   3  1 |
#     y_6_2 dist   3  3 |
#          value        |
#     x_6_3 dist   3  1 |
#          value 3 1  1 |
#     y_6_3 dist 3 1  3 |
#          value        |
#     x_6_4 dist 3 1  1 |
#          value   3  1 |
#     y_6_4 dist   3  3 |
#          value        |
#     x_6_5 dist   3  1 |
#          value 3 1  1 |
#     y_6_5 dist 3 1  3 |
#          value        |
#     x_6_6 dist 3 1  1 |
#          value   3  1 |
#     y_6_6 dist   3  3 |
#          value        |
#     x_6_7 dist   3  1 |
#          value 3 1  1 |
#     y_6_7 dist 3 1  3 |
#          value        |
#     x_6_8 dist 3 1  1 |
#          value   3  1 |
#     y_6_8 dist   3  3 |
#          value        |
#     x_6_9 dist   3  1 |
#          value 3 1  1 |
#     y_6_9 dist 3 1  3 |
#          value        |
#    x_6_10 dist 3 1  1 |
#          value   3  1 |
#    y_6_10 dist   3  3 |
#          value        |
#    x_6_11 dist   3  1 |
#          value 3 1  1 |
#    y_6_11 dist 3 1  3 |
#          value        |
#    x_6_12 dist 3 1  1 |
#          value   3  1 |
#    y_6_12 dist   3  3 |
#          value        |
#    x_6_13 dist   3  1 |
#          value 3 1  1 |
#    y_6_13 dist 3 1  3 |
#          value        |
#    x_6_14 dist 3 1  1 |
#          value   3  1 |
#    y_6_14 dist   3  3 |
#          value        |
#    x_6_15 dist   3  1 |
#          value 3 1  1 |
#    y_6_15 dist 3 1  3 |
#          value        |
#    x_6_16 dist 3 1  1 |
#          value   3  1 |
#    y_6_16 dist   3  3 |
#          value        |
#    x_6_17 dist   3  1 |
#          value 3 1  1 |
#    y_6_17 dist 3 1  3 |
#          value        |
#    x_6_18 dist 3 1  1 |
#          value   3  1 |
#    y_6_18 dist   3  3 |
#          value        |
#    x_6_19 dist   3  1 |
#          value 3 1  1 |
#    y_6_19 dist 3 1  3 |
#          value        |
#    x_6_20 dist 3 1  1 |
#          value   3  1 |
#    y_6_20 dist   3  3 |
#          value        |
#    x_6_21 dist   3  1 |
#          value 3 1  1 |
#    y_6_21 dist 3 1  3 |
#          value        |
#    x_6_22 dist 3 1  1 |
#          value   3  1 |
#    y_6_22 dist   3  3 |
#          value        |
#    x_6_23 dist   3  1 |
#          value 3 1  1 |
#    y_6_23 dist 3 1  3 |
#          value        |
#    x_6_24 dist 3 1  1 |
#          value   3  1 |
#    y_6_24 dist   3  3 |
#          value        |
#    x_6_25 dist   3  1 |
#          value 3 1  1 |
#    y_6_25 dist 3 1  3 |
#          value        |
#    x_6_26 dist 3 1  1 |
#          value   3  1 |
#    y_6_26 dist   3  3 |
#          value        |
#    x_6_27 dist   3  1 |
#          value 3 1  1 |
#    y_6_27 dist 3 1  3 |
#          value        |
#    x_6_28 dist 3 1  1 |
#          value   3  1 |
#    y_6_28 dist   3  3 |
#          value        |
#    x_6_29 dist   3  1 |
#          value 3 1  1 |
#    y_6_29 dist 3 1  3 |
#          value        |
#    x_6_30 dist 3 1  1 |
#          value   3  1 |
#    y_6_30 dist   3  3 |
#          value        |
#    x_6_31 dist   3  1 |
#          value 3 1  1 |
#    y_6_31 dist 3 1  3 |
#          value        |
#    x_6_32 dist 3 1  1 |
#          value   3  1 |
#    y_6_32 dist   3  3 |
#          value        |
#    x_6_33 dist   3  1 |
#          value 3 1  1 |
#    y_6_33 dist 3 1  3 |
#          value        |
#    x_6_34 dist 3 1  1 |
#          value   3  1 |
#    y_6_34 dist   3  3 |
#          value        |
#    x_6_35 dist   3  1 |
#          value 3 1  1 |
#    y_6_35 dist 3 1  3 |
#          value        |
#    x_6_36 dist 3 1  1 |
#          value   3  1 |
#    y_6_36 dist   3  3 |
#          value        |
#    x_6_37 dist   3  1 |
#          value 3 1  1 |
#    y_6_37 dist 3 1  3 |
#          value        |
#    x_6_38 dist 3 1  1 |
#          value   3  1 |
#    y_6_38 dist   3  3 |
#          value        |
#    x_6_39 dist   3  1 |
#          value 3 1  1 |
#    y_6_39 dist 3 1  3 |
#          value        |
#    x_6_40 dist 3 1  1 |
#          value   3  1 |
#    y_6_40 dist   3  3 |
#          value        |
#    x_6_41 dist   3  1 |
#          value 3 1  1 |
#    y_6_41 dist 3 1  3 |
#          value        |
#    x_6_42 dist 3 1  1 |
#          value   3  1 |
#    y_6_42 dist   3  3 |
#          value        |
#    x_6_43 dist   3  1 |
#          value 3 1  1 |
#    y_6_43 dist 3 1  3 |
#          value        |
#    x_6_44 dist 3 1  1 |
#          value   3  1 |
#    y_6_44 dist   3  3 |
#          value        |
#    x_6_45 dist   3  1 |
#          value 3 1  1 |
#    y_6_45 dist 3 1  3 |
#          value        |
#    x_6_46 dist 3 1  1 |
#          value   3  1 |
#    y_6_46 dist   3  3 |
#          value        |
#    x_6_47 dist   3  1 |
#          value 3 1  1 |
#    y_6_47 dist 3 1  3 |
#          value        |
#    x_6_48 dist 3 1  1 |
#          value   3  1 |
#    y_6_48 dist   3  3 |
#          value        |
#    x_6_49 dist   3  1 |
#          value 3 1  1 |
#    y_6_49 dist 3 1  3 |
#          value        |
#     x_7_0 dist        |
#          value   3  1 |
#     y_7_0 dist   3  3 |
#          value        |
#     x_7_1 dist   3  1 |
#          value 3 1  1 |
#     y_7_1 dist 3 1  3 |
#          value        |
#     x_7_2 dist 3 1  1 |
#          value   3  1 |
#     y_7_2 dist   3  3 |
#          value        |
#     x_7_3 dist   3  1 |
#          value 3 1  1 |
#     y_7_3 dist 3 1  3 |
#          value        |
#     x_7_4 dist 3 1  1 |
#          value   3  1 |
#     y_7_4 dist   3  3 |
#          value        |
#     x_7_5 dist   3  1 |
#          value 3 1  1 |
#     y_7_5 dist 3 1  3 |
#          value        |
#     x_7_6 dist 3 1  1 |
#          value   3  1 |
#     y_7_6 dist   3  3 |
#          value        |
#     x_7_7 dist   3  1 |
#          value 3 1  1 |
#     y_7_7 dist 3 1  3 |
#          value        |
#     x_7_8 dist 3 1  1 |
#          value   3  1 |
#     y_7_8 dist   3  3 |
#          value        |
#     x_7_9 dist   3  1 |
#          value 3 1  1 |
#     y_7_9 dist 3 1  3 |
#          value        |
#    x_7_10 dist 3 1  1 |
#          value   3  1 |
#    y_7_10 dist   3  3 |
#          value        |
#    x_7_11 dist   3  1 |
#          value 3 1  1 |
#    y_7_11 dist 3 1  3 |
#          value        |
#    x_7_12 dist 3 1  1 |
#          value   3  1 |
#    y_7_12 dist   3  3 |
#          value        |
#    x_7_13 dist   3  1 |
#          value 3 1  1 |
#    y_7_13 dist 3 1  3 |
#          value        |
#    x_7_14 dist 3 1  1 |
#          value   3  1 |
#    y_7_14 dist   3  3 |
#          value        |
#    x_7_15 dist   3  1 |
#          value 3 1  1 |
#    y_7_15 dist 3 1  3 |
#          value        |
#    x_7_16 dist 3 1  1 |
#          value   3  1 |
#    y_7_16 dist   3  3 |
#          value        |
#    x_7_17 dist   3  1 |
#          value 3 1  1 |
#    y_7_17 dist 3 1  3 |
#          value        |
#    x_7_18 dist 3 1  1 |
#          value   3  1 |
#    y_7_18 dist   3  3 |
#          value        |
#    x_7_19 dist   3  1 |
#          value 3 1  1 |
#    y_7_19 dist 3 1  3 |
#          value        |
#    x_7_20 dist 3 1  1 |
#          value   3  1 |
#    y_7_20 dist   3  3 |
#          value        |
#    x_7_21 dist   3  1 |
#          value 3 1  1 |
#    y_7_21 dist 3 1  3 |
#          value        |
#    x_7_22 dist 3 1  1 |
#          value   3  1 |
#    y_7_22 dist   3  3 |
#          value        |
#    x_7_23 dist   3  1 |
#          value 3 1  1 |
#    y_7_23 dist 3 1  3 |
#          value        |
#    x_7_24 dist 3 1  1 |
#          value   3  1 |
#    y_7_24 dist   3  3 |
#          value        |
#    x_7_25 dist   3  1 |
#          value 3 1  1 |
#    y_7_25 dist 3 1  3 |
#          value        |
#    x_7_26 dist 3 1  1 |
#          value   3  1 |
#    y_7_26 dist   3  3 |
#          value        |
#    x_7_27 dist   3  1 |
#          value 3 1  1 |
#    y_7_27 dist 3 1  3 |
#          value        |
#    x_7_28 dist 3 1  1 |
#          value   3  1 |
#    y_7_28 dist   3  3 |
#          value        |
#    x_7_29 dist   3  1 |
#          value 3 1  1 |
#    y_7_29 dist 3 1  3 |
#          value        |
#    x_7_30 dist 3 1  1 |
#          value   3  1 |
#    y_7_30 dist   3  3 |
#          value        |
#    x_7_31 dist   3  1 |
#          value 3 1  1 |
#    y_7_31 dist 3 1  3 |
#          value        |
#    x_7_32 dist 3 1  1 |
#          value   3  1 |
#    y_7_32 dist   3  3 |
#          value        |
#    x_7_33 dist   3  1 |
#          value 3 1  1 |
#    y_7_33 dist 3 1  3 |
#          value        |
#    x_7_34 dist 3 1  1 |
#          value   3  1 |
#    y_7_34 dist   3  3 |
#          value        |
#    x_7_35 dist   3  1 |
#          value 3 1  1 |
#    y_7_35 dist 3 1  3 |
#          value        |
#    x_7_36 dist 3 1  1 |
#          value   3  1 |
#    y_7_36 dist   3  3 |
#          value        |
#    x_7_37 dist   3  1 |
#          value 3 1  1 |
#    y_7_37 dist 3 1  3 |
#          value        |
#    x_7_38 dist 3 1  1 |
#          value   3  1 |
#    y_7_38 dist   3  3 |
#          value        |
#    x_7_39 dist   3  1 |
#          value 3 1  1 |
#    y_7_39 dist 3 1  3 |
#          value        |
#    x_7_40 dist 3 1  1 |
#          value   3  1 |
#    y_7_40 dist   3  3 |
#          value        |
#    x_7_41 dist   3  1 |
#          value 3 1  1 |
#    y_7_41 dist 3 1  3 |
#          value        |
#    x_7_42 dist 3 1  1 |
#          value   3  1 |
#    y_7_42 dist   3  3 |
#          value        |
#    x_7_43 dist   3  1 |
#          value 3 1  1 |
#    y_7_43 dist 3 1  3 |
#          value        |
#    x_7_44 dist 3 1  1 |
#          value   3  1 |
#    y_7_44 dist   3  3 |
#          value        |
#    x_7_45 dist   3  1 |
#          value 3 1  1 |
#    y_7_45 dist 3 1  3 |
#          value        |
#    x_7_46 dist 3 1  1 |
#          value   3  1 |
#    y_7_46 dist   3  3 |
#          value        |
#    x_7_47 dist   3  1 |
#          value 3 1  1 |
#    y_7_47 dist 3 1  3 |
#          value        |
#    x_7_48 dist 3 1  1 |
#          value   3  1 |
#    y_7_48 dist   3  3 |
#          value        |
#    x_7_49 dist   3  1 |
#          value 3 1  1 |
#    y_7_49 dist 3 1  3 |
#          value        |
#     x_8_0 dist        |
#          value   3  1 |
#     y_8_0 dist   3  3 |
#          value        |
#     x_8_1 dist   3  1 |
#          value 3 1  1 |
#     y_8_1 dist 3 1  3 |
#          value        |
#     x_8_2 dist 3 1  1 |
#          value   3  1 |
#     y_8_2 dist   3  3 |
#          value        |
#     x_8_3 dist   3  1 |
#          value 3 1  1 |
#     y_8_3 dist 3 1  3 |
#          value        |
#     x_8_4 dist 3 1  1 |
#          value   3  1 |
#     y_8_4 dist   3  3 |
#          value        |
#     x_8_5 dist   3  1 |
#          value 3 1  1 |
#     y_8_5 dist 3 1  3 |
#          value        |
#     x_8_6 dist 3 1  1 |
#          value   3  1 |
#     y_8_6 dist   3  3 |
#          value        |
#     x_8_7 dist   3  1 |
#          value 3 1  1 |
#     y_8_7 dist 3 1  3 |
#          value        |
#     x_8_8 dist 3 1  1 |
#          value   3  1 |
#     y_8_8 dist   3  3 |
#          value        |
#     x_8_9 dist   3  1 |
#          value 3 1  1 |
#     y_8_9 dist 3 1  3 |
#          value        |
#    x_8_10 dist 3 1  1 |
#          value   3  1 |
#    y_8_10 dist   3  3 |
#          value        |
#    x_8_11 dist   3  1 |
#          value 3 1  1 |
#    y_8_11 dist 3 1  3 |
#          value        |
#    x_8_12 dist 3 1  1 |
#          value   3  1 |
#    y_8_12 dist   3  3 |
#          value        |
#    x_8_13 dist   3  1 |
#          value 3 1  1 |
#    y_8_13 dist 3 1  3 |
#          value        |
#    x_8_14 dist 3 1  1 |
#          value   3  1 |
#    y_8_14 dist   3  3 |
#          value        |
#    x_8_15 dist   3  1 |
#          value 3 1  1 |
#    y_8_15 dist 3 1  3 |
#          value        |
#    x_8_16 dist 3 1  1 |
#          value   3  1 |
#    y_8_16 dist   3  3 |
#          value        |
#    x_8_17 dist   3  1 |
#          value 3 1  1 |
#    y_8_17 dist 3 1  3 |
#          value        |
#    x_8_18 dist 3 1  1 |
#          value   3  1 |
#    y_8_18 dist   3  3 |
#          value        |
#    x_8_19 dist   3  1 |
#          value 3 1  1 |
#    y_8_19 dist 3 1  3 |
#          value        |
#    x_8_20 dist 3 1  1 |
#          value   3  1 |
#    y_8_20 dist   3  3 |
#          value        |
#    x_8_21 dist   3  1 |
#          value 3 1  1 |
#    y_8_21 dist 3 1  3 |
#          value        |
#    x_8_22 dist 3 1  1 |
#          value   3  1 |
#    y_8_22 dist   3  3 |
#          value        |
#    x_8_23 dist   3  1 |
#          value 3 1  1 |
#    y_8_23 dist 3 1  3 |
#          value        |
#    x_8_24 dist 3 1  1 |
#          value   3  1 |
#    y_8_24 dist   3  3 |
#          value        |
#    x_8_25 dist   3  1 |
#          value 3 1  1 |
#    y_8_25 dist 3 1  3 |
#          value        |
#    x_8_26 dist 3 1  1 |
# ...
#          value 3 1  1 |
#    y_48_7 dist 3 1  3 |
#          value        |
#    x_48_8 dist 3 1  1 |
#          value   3  1 |
#    y_48_8 dist   3  3 |
#          value        |
#    x_48_9 dist   3  1 |
#          value 3 1  1 |
#    y_48_9 dist 3 1  3 |
#          value        |
#   x_48_10 dist 3 1  1 |
#          value   3  1 |
#   y_48_10 dist   3  3 |
#          value        |
#   x_48_11 dist   3  1 |
#          value 3 1  1 |
#   y_48_11 dist 3 1  3 |
#          value        |
#   x_48_12 dist 3 1  1 |
#          value   3  1 |
#   y_48_12 dist   3  3 |
#          value        |
#   x_48_13 dist   3  1 |
#          value 3 1  1 |
#   y_48_13 dist 3 1  3 |
#          value        |
#   x_48_14 dist 3 1  1 |
#          value   3  1 |
#   y_48_14 dist   3  3 |
#          value        |
#   x_48_15 dist   3  1 |
#          value 3 1  1 |
#   y_48_15 dist 3 1  3 |
#          value        |
#   x_48_16 dist 3 1  1 |
#          value   3  1 |
#   y_48_16 dist   3  3 |
#          value        |
#   x_48_17 dist   3  1 |
#          value 3 1  1 |
#   y_48_17 dist 3 1  3 |
#          value        |
#   x_48_18 dist 3 1  1 |
#          value   3  1 |
#   y_48_18 dist   3  3 |
#          value        |
#   x_48_19 dist   3  1 |
#          value 3 1  1 |
#   y_48_19 dist 3 1  3 |
#          value        |
#   x_48_20 dist 3 1  1 |
#          value   3  1 |
#   y_48_20 dist   3  3 |
#          value        |
#   x_48_21 dist   3  1 |
#          value 3 1  1 |
#   y_48_21 dist 3 1  3 |
#          value        |
#   x_48_22 dist 3 1  1 |
#          value   3  1 |
#   y_48_22 dist   3  3 |
#          value        |
#   x_48_23 dist   3  1 |
#          value 3 1  1 |
#   y_48_23 dist 3 1  3 |
#          value        |
#   x_48_24 dist 3 1  1 |
#          value   3  1 |
#   y_48_24 dist   3  3 |
#          value        |
#   x_48_25 dist   3  1 |
#          value 3 1  1 |
#   y_48_25 dist 3 1  3 |
#          value        |
#   x_48_26 dist 3 1  1 |
#          value   3  1 |
#   y_48_26 dist   3  3 |
#          value        |
#   x_48_27 dist   3  1 |
#          value 3 1  1 |
#   y_48_27 dist 3 1  3 |
#          value        |
#   x_48_28 dist 3 1  1 |
#          value   3  1 |
#   y_48_28 dist   3  3 |
#          value        |
#   x_48_29 dist   3  1 |
#          value 3 1  1 |
#   y_48_29 dist 3 1  3 |
#          value        |
#   x_48_30 dist 3 1  1 |
#          value   3  1 |
#   y_48_30 dist   3  3 |
#          value        |
#   x_48_31 dist   3  1 |
#          value 3 1  1 |
#   y_48_31 dist 3 1  3 |
#          value        |
#   x_48_32 dist 3 1  1 |
#          value   3  1 |
#   y_48_32 dist   3  3 |
#          value        |
#   x_48_33 dist   3  1 |
#          value 3 1  1 |
#   y_48_33 dist 3 1  3 |
#          value        |
#   x_48_34 dist 3 1  1 |
#          value   3  1 |
#   y_48_34 dist   3  3 |
#          value        |
#   x_48_35 dist   3  1 |
#          value 3 1  1 |
#   y_48_35 dist 3 1  3 |
#          value        |
#   x_48_36 dist 3 1  1 |
#          value   3  1 |
#   y_48_36 dist   3  3 |
#          value        |
#   x_48_37 dist   3  1 |
#          value 3 1  1 |
#   y_48_37 dist 3 1  3 |
#          value        |
#   x_48_38 dist 3 1  1 |
#          value   3  1 |
#   y_48_38 dist   3  3 |
#          value        |
#   x_48_39 dist   3  1 |
#          value 3 1  1 |
#   y_48_39 dist 3 1  3 |
#          value        |
#   x_48_40 dist 3 1  1 |
#          value   3  1 |
#   y_48_40 dist   3  3 |
#          value        |
#   x_48_41 dist   3  1 |
#          value 3 1  1 |
#   y_48_41 dist 3 1  3 |
#          value        |
#   x_48_42 dist 3 1  1 |
#          value   3  1 |
#   y_48_42 dist   3  3 |
#          value        |
#   x_48_43 dist   3  1 |
#          value 3 1  1 |
#   y_48_43 dist 3 1  3 |
#          value        |
#   x_48_44 dist 3 1  1 |
#          value   3  1 |
#   y_48_44 dist   3  3 |
#          value        |
#   x_48_45 dist   3  1 |
#          value 3 1  1 |
#   y_48_45 dist 3 1  3 |
#          value        |
#   x_48_46 dist 3 1  1 |
#          value   3  1 |
#   y_48_46 dist   3  3 |
#          value        |
#   x_48_47 dist   3  1 |
#          value 3 1  1 |
#   y_48_47 dist 3 1  3 |
#          value        |
#   x_48_48 dist 3 1  1 |
#          value   3  1 |
#   y_48_48 dist   3  3 |
#          value        |
#   x_48_49 dist   3  1 |
#          value 3 1  1 |
#   y_48_49 dist 3 1  3 |
#          value        |
#    x_49_0 dist        |
#          value   3  1 |
#    y_49_0 dist   3  3 |
#          value        |
#    x_49_1 dist   3  1 |
#          value 3 1  1 |
#    y_49_1 dist 3 1  3 |
#          value        |
#    x_49_2 dist 3 1  1 |
#          value   3  1 |
#    y_49_2 dist   3  3 |
#          value        |
#    x_49_3 dist   3  1 |
#          value 3 1  1 |
#    y_49_3 dist 3 1  3 |
#          value        |
#    x_49_4 dist 3 1  1 |
#          value   3  1 |
#    y_49_4 dist   3  3 |
#          value        |
#    x_49_5 dist   3  1 |
#          value 3 1  1 |
#    y_49_5 dist 3 1  3 |
#          value        |
#    x_49_6 dist 3 1  1 |
#          value   3  1 |
#    y_49_6 dist   3  3 |
#          value        |
#    x_49_7 dist   3  1 |
#          value 3 1  1 |
#    y_49_7 dist 3 1  3 |
#          value        |
#    x_49_8 dist 3 1  1 |
#          value   3  1 |
#    y_49_8 dist   3  3 |
#          value        |
#    x_49_9 dist   3  1 |
#          value 3 1  1 |
#    y_49_9 dist 3 1  3 |
#          value        |
#   x_49_10 dist 3 1  1 |
#          value   3  1 |
#   y_49_10 dist   3  3 |
#          value        |
#   x_49_11 dist   3  1 |
#          value 3 1  1 |
#   y_49_11 dist 3 1  3 |
#          value        |
#   x_49_12 dist 3 1  1 |
#          value   3  1 |
#   y_49_12 dist   3  3 |
#          value        |
#   x_49_13 dist   3  1 |
#          value 3 1  1 |
#   y_49_13 dist 3 1  3 |
#          value        |
#   x_49_14 dist 3 1  1 |
#          value   3  1 |
#   y_49_14 dist   3  3 |
#          value        |
#   x_49_15 dist   3  1 |
#          value 3 1  1 |
#   y_49_15 dist 3 1  3 |
#          value        |
#   x_49_16 dist 3 1  1 |
#          value   3  1 |
#   y_49_16 dist   3  3 |
#          value        |
#   x_49_17 dist   3  1 |
#          value 3 1  1 |
#   y_49_17 dist 3 1  3 |
#          value        |
#   x_49_18 dist 3 1  1 |
#          value   3  1 |
#   y_49_18 dist   3  3 |
#          value        |
#   x_49_19 dist   3  1 |
#          value 3 1  1 |
#   y_49_19 dist 3 1  3 |
#          value        |
#   x_49_20 dist 3 1  1 |
#          value   3  1 |
#   y_49_20 dist   3  3 |
#          value        |
#   x_49_21 dist   3  1 |
#          value 3 1  1 |
#   y_49_21 dist 3 1  3 |
#          value        |
#   x_49_22 dist 3 1  1 |
#          value   3  1 |
#   y_49_22 dist   3  3 |
#          value        |
#   x_49_23 dist   3  1 |
#          value 3 1  1 |
#   y_49_23 dist 3 1  3 |
#          value        |
#   x_49_24 dist 3 1  1 |
#          value   3  1 |
#   y_49_24 dist   3  3 |
#          value        |
#   x_49_25 dist   3  1 |
#          value 3 1  1 |
#   y_49_25 dist 3 1  3 |
#          value        |
#   x_49_26 dist 3 1  1 |
#          value   3  1 |
#   y_49_26 dist   3  3 |
#          value        |
#   x_49_27 dist   3  1 |
#          value 3 1  1 |
#   y_49_27 dist 3 1  3 |
#          value        |
#   x_49_28 dist 3 1  1 |
#          value   3  1 |
#   y_49_28 dist   3  3 |
#          value        |
#   x_49_29 dist   3  1 |
#          value 3 1  1 |
#   y_49_29 dist 3 1  3 |
#          value        |
#   x_49_30 dist 3 1  1 |
#          value   3  1 |
#   y_49_30 dist   3  3 |
#          value        |
#   x_49_31 dist   3  1 |
#          value 3 1  1 |
#   y_49_31 dist 3 1  3 |
#          value        |
#   x_49_32 dist 3 1  1 |
#          value   3  1 |
#   y_49_32 dist   3  3 |
#          value        |
#   x_49_33 dist   3  1 |
#          value 3 1  1 |
#   y_49_33 dist 3 1  3 |
#          value        |
#   x_49_34 dist 3 1  1 |
#          value   3  1 |
#   y_49_34 dist   3  3 |
#          value        |
#   x_49_35 dist   3  1 |
#          value 3 1  1 |
#   y_49_35 dist 3 1  3 |
#          value        |
#   x_49_36 dist 3 1  1 |
#          value   3  1 |
#   y_49_36 dist   3  3 |
#          value        |
#   x_49_37 dist   3  1 |
#          value 3 1  1 |
#   y_49_37 dist 3 1  3 |
#          value        |
#   x_49_38 dist 3 1  1 |
#          value   3  1 |
#   y_49_38 dist   3  3 |
#          value        |
#   x_49_39 dist   3  1 |
#          value 3 1  1 |
#   y_49_39 dist 3 1  3 |
#          value        |
#   x_49_40 dist 3 1  1 |
#          value   3  1 |
#   y_49_40 dist   3  3 |
#          value        |
#   x_49_41 dist   3  1 |
#          value 3 1  1 |
#   y_49_41 dist 3 1  3 |
#          value        |
#   x_49_42 dist 3 1  1 |
#          value   3  1 |
#   y_49_42 dist   3  3 |
#          value        |
#   x_49_43 dist   3  1 |
#          value 3 1  1 |
#   y_49_43 dist 3 1  3 |
#          value        |
#   x_49_44 dist 3 1  1 |
#          value   3  1 |
#   y_49_44 dist   3  3 |
#          value        |
#   x_49_45 dist   3  1 |
#          value 3 1  1 |
#   y_49_45 dist 3 1  3 |
#          value        |
#   x_49_46 dist 3 1  1 |
#          value   3  1 |
#   y_49_46 dist   3  3 |
#          value        |
#   x_49_47 dist   3  1 |
#          value 3 1  1 |
#   y_49_47 dist 3 1  3 |
#          value        |
#   x_49_48 dist 3 1  1 |
#          value   3  1 |
#   y_49_48 dist   3  3 |
#          value        |
#   x_49_49 dist   3  1 |
#          value 3 1  1 |
#   y_49_49 dist 3 1  3 |
#          value        |
#    x_50_0 dist        |
#          value   3  1 |
#    y_50_0 dist   3  3 |
#          value        |
#    x_50_1 dist   3  1 |
#          value 3 1  1 |
#    y_50_1 dist 3 1  3 |
#          value        |
#    x_50_2 dist 3 1  1 |
#          value   3  1 |
#    y_50_2 dist   3  3 |
#          value        |
#    x_50_3 dist   3  1 |
#          value 3 1  1 |
#    y_50_3 dist 3 1  3 |
#          value        |
#    x_50_4 dist 3 1  1 |
#          value   3  1 |
#    y_50_4 dist   3  3 |
#          value        |
#    x_50_5 dist   3  1 |
#          value 3 1  1 |
#    y_50_5 dist 3 1  3 |
#          value        |
#    x_50_6 dist 3 1  1 |
#          value   3  1 |
#    y_50_6 dist   3  3 |
#          value        |
#    x_50_7 dist   3  1 |
#          value 3 1  1 |
#    y_50_7 dist 3 1  3 |
#          value        |
#    x_50_8 dist 3 1  1 |
#          value   3  1 |
#    y_50_8 dist   3  3 |
#          value        |
#    x_50_9 dist   3  1 |
#          value 3 1  1 |
#    y_50_9 dist 3 1  3 |
#          value        |
#   x_50_10 dist 3 1  1 |
#          value   3  1 |
#   y_50_10 dist   3  3 |
#          value        |
#   x_50_11 dist   3  1 |
#          value 3 1  1 |
#   y_50_11 dist 3 1  3 |
#          value        |
#   x_50_12 dist 3 1  1 |
#          value   3  1 |
#   y_50_12 dist   3  3 |
#          value        |
#   x_50_13 dist   3  1 |
#          value 3 1  1 |
#   y_50_13 dist 3 1  3 |
#          value        |
#   x_50_14 dist 3 1  1 |
#          value   3  1 |
#   y_50_14 dist   3  3 |
#          value        |
#   x_50_15 dist   3  1 |
#          value 3 1  1 |
#   y_50_15 dist 3 1  3 |
#          value        |
#   x_50_16 dist 3 1  1 |
#          value   3  1 |
#   y_50_16 dist   3  3 |
#          value        |
#   x_50_17 dist   3  1 |
#          value 3 1  1 |
#   y_50_17 dist 3 1  3 |
#          value        |
#   x_50_18 dist 3 1  1 |
#          value   3  1 |
#   y_50_18 dist   3  3 |
#          value        |
#   x_50_19 dist   3  1 |
#          value 3 1  1 |
#   y_50_19 dist 3 1  3 |
#          value        |
#   x_50_20 dist 3 1  1 |
#          value   3  1 |
#   y_50_20 dist   3  3 |
#          value        |
#   x_50_21 dist   3  1 |
#          value 3 1  1 |
#   y_50_21 dist 3 1  3 |
#          value        |
#   x_50_22 dist 3 1  1 |
#          value   3  1 |
#   y_50_22 dist   3  3 |
#          value        |
#   x_50_23 dist   3  1 |
#          value 3 1  1 |
#   y_50_23 dist 3 1  3 |
#          value        |
#   x_50_24 dist 3 1  1 |
#          value   3  1 |
#   y_50_24 dist   3  3 |
#          value        |
#   x_50_25 dist   3  1 |
#          value 3 1  1 |
#   y_50_25 dist 3 1  3 |
#          value        |
#   x_50_26 dist 3 1  1 |
#          value   3  1 |
#   y_50_26 dist   3  3 |
#          value        |
#   x_50_27 dist   3  1 |
#          value 3 1  1 |
#   y_50_27 dist 3 1  3 |
#          value        |
#   x_50_28 dist 3 1  1 |
#          value   3  1 |
#   y_50_28 dist   3  3 |
#          value        |
#   x_50_29 dist   3  1 |
#          value 3 1  1 |
#   y_50_29 dist 3 1  3 |
#          value        |
#   x_50_30 dist 3 1  1 |
#          value   3  1 |
#   y_50_30 dist   3  3 |
#          value        |
#   x_50_31 dist   3  1 |
#          value 3 1  1 |
#   y_50_31 dist 3 1  3 |
#          value        |
#   x_50_32 dist 3 1  1 |
#          value   3  1 |
#   y_50_32 dist   3  3 |
#          value        |
#   x_50_33 dist   3  1 |
#          value 3 1  1 |
#   y_50_33 dist 3 1  3 |
#          value        |
#   x_50_34 dist 3 1  1 |
#          value   3  1 |
#   y_50_34 dist   3  3 |
#          value        |
#   x_50_35 dist   3  1 |
#          value 3 1  1 |
#   y_50_35 dist 3 1  3 |
#          value        |
#   x_50_36 dist 3 1  1 |
#          value   3  1 |
#   y_50_36 dist   3  3 |
#          value        |
#   x_50_37 dist   3  1 |
#          value 3 1  1 |
#   y_50_37 dist 3 1  3 |
#          value        |
#   x_50_38 dist 3 1  1 |
#          value   3  1 |
#   y_50_38 dist   3  3 |
#          value        |
#   x_50_39 dist   3  1 |
#          value 3 1  1 |
#   y_50_39 dist 3 1  3 |
#          value        |
#   x_50_40 dist 3 1  1 |
#          value   3  1 |
#   y_50_40 dist   3  3 |
#          value        |
#   x_50_41 dist   3  1 |
#          value 3 1  1 |
#   y_50_41 dist 3 1  3 |
#          value        |
#   x_50_42 dist 3 1  1 |
#          value   3  1 |
#   y_50_42 dist   3  3 |
#          value        |
#   x_50_43 dist   3  1 |
#          value 3 1  1 |
#   y_50_43 dist 3 1  3 |
#          value        |
#   x_50_44 dist 3 1  1 |
#          value   3  1 |
#   y_50_44 dist   3  3 |
#          value        |
#   x_50_45 dist   3  1 |
#          value 3 1  1 |
#   y_50_45 dist 3 1  3 |
#          value        |
#   x_50_46 dist 3 1  1 |
#          value   3  1 |
#   y_50_46 dist   3  3 |
#          value        |
#   x_50_47 dist   3  1 |
#          value 3 1  1 |
#   y_50_47 dist 3 1  3 |
#          value        |
#   x_50_48 dist 3 1  1 |
#          value   3  1 |
#   y_50_48 dist   3  3 |
#          value        |
#   x_50_49 dist   3  1 |
#          value 3 1  1 |
#   y_50_49 dist 3 1  3 |
#          value        |

# %%
optim = Adam({'lr': learning_rate})

# %%
Elbo = TraceEnum_ELBO
elbo = Elbo(max_plate_nesting= 2,
            strict_enumeration_warning=True,
           )
svi = SVI(model_0, guide, optim, elbo)

# %%
# # We'll train on small minibatches.
for step in range(num_steps):
    print(f"\tTraining step: {step}")
    loss = svi.step(sequences, lengths, emission,)
    print('\t{: >5d}\t{}'.format(step, loss / num_observations))
    median = guide.median()["probs_x"].flatten()
    print("\t{}".format(median))
# Out:
# 	Training step: 0
# 	    0	2.4954346660539217
# 	tensor([0.3559, 0.3220, 0.3220, 0.3220, 0.3559, 0.3220, 0.3115, 0.3443, 0.3443])
# 	Training step: 1
# 	    1	2.485734911151961
# 	tensor([0.3788, 0.3110, 0.3102, 0.3105, 0.3791, 0.3105, 0.2907, 0.3546, 0.3548])
# 	Training step: 2
# 	    2	2.4773988970588237
# 	tensor([0.4010, 0.3014, 0.2976, 0.2987, 0.4026, 0.2987, 0.2711, 0.3640, 0.3649])
# 	Training step: 3
# 	    3	2.4704718137254904
# 	tensor([0.4216, 0.2945, 0.2838, 0.2869, 0.4262, 0.2869, 0.2531, 0.3722, 0.3747])
# 	Training step: 4
# 	    4	2.4649211090686274
# 	tensor([0.4400, 0.2908, 0.2692, 0.2753, 0.4495, 0.2752, 0.2368, 0.3786, 0.3846])
# 	Training step: 5
# 	    5	2.4606634880514706
# 	tensor([0.4563, 0.2893, 0.2544, 0.2640, 0.4722, 0.2638, 0.2225, 0.3828, 0.3947])
# 	Training step: 6
# 	    6	2.457596124387255
# 	tensor([0.4708, 0.2893, 0.2400, 0.2534, 0.4937, 0.2530, 0.2102, 0.3844, 0.4053])
# 	Training step: 7
# 	    7	2.455581533394608
# 	tensor([0.4836, 0.2901, 0.2263, 0.2436, 0.5135, 0.2429, 0.2000, 0.3833, 0.4166])
# 	Training step: 8
# 	    8	2.4544498697916666
# 	tensor([0.4950, 0.2914, 0.2136, 0.2350, 0.5312, 0.2338, 0.1917, 0.3799, 0.4284])
# 	Training step: 9
# 	    9	2.454006778492647
# 	tensor([0.5052, 0.2928, 0.2021, 0.2279, 0.5462, 0.2259, 0.1851, 0.3746, 0.4403])
# 	Training step: 10
# 	   10	2.4540512025122547
# 	tensor([0.5142, 0.2940, 0.1918, 0.2222, 0.5584, 0.2194, 0.1800, 0.3680, 0.4520])
# 	Training step: 11
# 	   11	2.4543918504901963
# 	tensor([0.5223, 0.2948, 0.1829, 0.2182, 0.5676, 0.2142, 0.1763, 0.3606, 0.4631])
# 	Training step: 12
# 	   12	2.4548642386642157
# 	tensor([0.5295, 0.2953, 0.1752, 0.2157, 0.5738, 0.2104, 0.1737, 0.3530, 0.4733])
# 	Training step: 13
# 	   13	2.455342754289216
# 	tensor([0.5358, 0.2956, 0.1687, 0.2147, 0.5773, 0.2080, 0.1723, 0.3457, 0.4820])
# 	Training step: 14
# 	   14	2.455743527879902
# 	tensor([0.5409, 0.2958, 0.1632, 0.2149, 0.5783, 0.2067, 0.1719, 0.3391, 0.4890])
# 	Training step: 15
# 	   15	2.4560234757965684
# 	tensor([0.5450, 0.2962, 0.1588, 0.2163, 0.5772, 0.2066, 0.1723, 0.3335, 0.4942])
# 	Training step: 16
# 	   16	2.4561651731004903
# 	tensor([0.5477, 0.2970, 0.1553, 0.2185, 0.5742, 0.2073, 0.1736, 0.3291, 0.4973])
# 	Training step: 17
# 	   17	2.4561713005514707
# 	tensor([0.5491, 0.2983, 0.1526, 0.2215, 0.5696, 0.2089, 0.1755, 0.3261, 0.4984])
# 	Training step: 18
# 	   18	2.4560567938112747
# 	tensor([0.5492, 0.3001, 0.1507, 0.2251, 0.5639, 0.2111, 0.1779, 0.3245, 0.4976])
# 	Training step: 19
# 	   19	2.4558499923406862
# 	tensor([0.5482, 0.3023, 0.1494, 0.2290, 0.5573, 0.2138, 0.1807, 0.3243, 0.4950])
# 	Training step: 20
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-18-ad9a27da10cf>", line 4, in <module>
#     loss = svi.step(sequences, lengths, emission,)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\infer\svi.py", line 128, in step
#     loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\infer\traceenum_elbo.py", line 405, in loss_and_grads
#     elbo_particle = _compute_dice_elbo(model_trace, guide_trace)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\infer\traceenum_elbo.py", line 170, in _compute_dice_elbo
#     log_factors = contract_tensor_tree(log_factors, sum_dims, ring=ring)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\ops\contract.py", line 189, in contract_tensor_tree
#     ordinal, term = _contract_component(ring, component, dims, set())
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\ops\contract.py", line 118, in _contract_component
#     term = ring.sumproduct(terms, dims - local_dims)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\ops\rings.py", line 194, in sumproduct
#     term = contract(equation, *terms, backend=self._backend)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\ops\einsum\__init__.py", line 46, in contract
#     return expr(*operands, backend=backend, out=out)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\opt_einsum\contract.py", line 763, in __call__
#     return self._contract(ops, out, backend, evaluate_constants=evaluate_constants)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\opt_einsum\contract.py", line 698, in _contract
#     **self.einsum_kwargs)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\opt_einsum\contract.py", line 573, in _core_contract
#     new_view = _tensordot(*tmp_operands, axes=(tuple(left_pos), tuple(right_pos)), backend=backend)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\opt_einsum\sharing.py", line 139, in cached_tensordot
#     return _memoize(key, tensordot, x, y, axes, backend=backend)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\opt_einsum\sharing.py", line 101, in _memoize
#     result = fn(*args, **kwargs)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\opt_einsum\contract.py", line 374, in _tensordot
#     return fn(x, y, axes=axes)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\ops\einsum\util.py", line 58, in __call__
#     return self.einsum(einsum_str, x, y)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\ops\einsum\torch_sample.py", line 66, in einsum
#     result = pyro.ops.einsum.torch_log.einsum(equation, *operands)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\pyro\ops\einsum\torch_log.py", line 35, in einsum
#     shift = shift.max(i, keepdim=True)[0]
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\cwild\.conda\envs\nic\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\cwild\.conda\envs\nic\lib\inspect.py", line 1464, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "C:\Users\cwild\.conda\envs\nic\lib\site-packages\IPython\core\ultratb.py", line 182, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "C:\Users\cwild\.conda\envs\nic\lib\linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "C:\Users\cwild\.conda\envs\nic\lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "C:\Users\cwild\.conda\envs\nic\lib\tokenize.py", line 447, in open
#     buffer = _builtin_open(filename, 'rb')
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-18-ad9a27da10cf> in <module>
#       3     print(f"\tTraining step: {step}")
# ----> 4     loss = svi.step(sequences, lengths, emission,)
#       5     print('\t{: >5d}\t{}'.format(step, loss / num_observations))
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\svi.py in step(self, *args, **kwargs)
#     127         with poutine.trace(param_only=True) as param_capture:
# --> 128             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     129
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\traceenum_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     404         for model_trace, guide_trace in self._get_traces(model, guide, args, kwargs):
# --> 405             elbo_particle = _compute_dice_elbo(model_trace, guide_trace)
#     406             if is_identically_zero(elbo_particle):
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\traceenum_elbo.py in _compute_dice_elbo(model_trace, guide_trace)
#     169             ring = SampleRing(cache=cache, dim_to_size=dim_to_size)
# --> 170             log_factors = contract_tensor_tree(log_factors, sum_dims, ring=ring)
#     171             model_trace._sharing_cache = cache  # For TraceEnumSample_ELBO.
#
# ~\.conda\envs\nic\lib\site-packages\pyro\ops\contract.py in contract_tensor_tree(tensor_tree, sum_dims, cache, ring)
#     188         # Contract this connected component down to a single tensor.
# --> 189         ordinal, term = _contract_component(ring, component, dims, set())
#     190         contracted_tree.setdefault(ordinal, []).append(term)
#
# ~\.conda\envs\nic\lib\site-packages\pyro\ops\contract.py in _contract_component(ring, tensor_tree, sum_dims, target_dims)
#     117             # Eliminate sum dims via a sumproduct contraction.
# --> 118             term = ring.sumproduct(terms, dims - local_dims)
#     119
#
# ~\.conda\envs\nic\lib\site-packages\pyro\ops\rings.py in sumproduct(self, terms, dims)
#     193         equation = ','.join(inputs) + '->' + output
# --> 194         term = contract(equation, *terms, backend=self._backend)
#     195         term._pyro_dims = output
#
# ~\.conda\envs\nic\lib\site-packages\pyro\ops\einsum\__init__.py in contract(equation, *operands, **kwargs)
#      45         expr = contract_expression(equation, *shapes)
# ---> 46         return expr(*operands, backend=backend, out=out)
#      47
#
# ~\.conda\envs\nic\lib\site-packages\opt_einsum\contract.py in __call__(self, *arrays, **kwargs)
#     762
# --> 763             return self._contract(ops, out, backend, evaluate_constants=evaluate_constants)
#     764
#
# ~\.conda\envs\nic\lib\site-packages\opt_einsum\contract.py in _contract(self, arrays, out, backend, evaluate_constants)
#     697                               evaluate_constants=evaluate_constants,
# --> 698                               **self.einsum_kwargs)
#     699
#
# ~\.conda\envs\nic\lib\site-packages\opt_einsum\contract.py in _core_contract(operands, contraction_list, backend, evaluate_constants, **einsum_kwargs)
#     572             # Contract!
# --> 573             new_view = _tensordot(*tmp_operands, axes=(tuple(left_pos), tuple(right_pos)), backend=backend)
#     574
#
# ~\.conda\envs\nic\lib\site-packages\opt_einsum\sharing.py in cached_tensordot(x, y, axes, backend)
#     138         key = 'tensordot', backend, id(x), id(y), axes
# --> 139         return _memoize(key, tensordot, x, y, axes, backend=backend)
#     140
#
# ~\.conda\envs\nic\lib\site-packages\opt_einsum\sharing.py in _memoize(key, fn, *args, **kwargs)
#     100         return cache[key]
# --> 101     result = fn(*args, **kwargs)
#     102     cache[key] = result
#
# ~\.conda\envs\nic\lib\site-packages\opt_einsum\contract.py in _tensordot(x, y, axes, backend)
#     373     fn = backends.get_func('tensordot', backend)
# --> 374     return fn(x, y, axes=axes)
#     375
#
# ~\.conda\envs\nic\lib\site-packages\pyro\ops\einsum\util.py in __call__(self, x, y, axes)
#      57         einsum_str = "{},{}->{}".format(*map("".join, (x_ix, y_ix, out_ix)))
# ---> 58         return self.einsum(einsum_str, x, y)
#
# ~\.conda\envs\nic\lib\site-packages\pyro\ops\einsum\torch_sample.py in einsum(equation, *operands)
#      65     inputs, output = equation.split('->')
# ---> 66     result = pyro.ops.einsum.torch_log.einsum(equation, *operands)
#      67     result._pyro_dims = output
#
# ~\.conda\envs\nic\lib\site-packages\pyro\ops\einsum\torch_log.py in einsum(equation, *operands)
#      34             if dim not in output:
# ---> 35                 shift = shift.max(i, keepdim=True)[0]
#      36         # avoid nan due to -inf - -inf
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\.conda\envs\nic\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\.conda\envs\nic\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2062                     except Exception:
#    2063                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2064                                             value, tb, tb_offset=tb_offset)
#    2065
#    2066                     self._showtraceback(etype, value, stb)
#
# ~\.conda\envs\nic\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# ~\.conda\envs\nic\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# ~\.conda\envs\nic\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~\.conda\envs\nic\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~\.conda\envs\nic\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
from hmmlearn import hmm

# %%
model = hmm.MultinomialHMM(n_components=3, n_iter=10000, params="st", init_params="st")

# %%
model.emissionprob_ = emission.cpu().numpy().astype(float)

# %%
model.fit(sequences.cpu().numpy().reshape(-1, 1).astype(int), lengths.cpu().numpy().astype(int))
# Out:
# WARNING:hmmlearn.base:Even though the 'startprob_' attribute is set, it will be overwritten during initialization because 'init_params' contains 's'
# WARNING:hmmlearn.base:Even though the 'transmat_' attribute is set, it will be overwritten during initialization because 'init_params' contains 't'
# MultinomialHMM(init_params='st', n_components=3, n_iter=10000, params='st',
#                random_state=RandomState(MT19937) at 0x175F7569048)

# %%
model.transmat_
# Out:
# array([[0.92999261, 0.03601261, 0.03399478],
#        [0.03824865, 0.92332934, 0.03842201],
#        [0.04142672, 0.03791173, 0.92066155]])

# %%
np.zeros

# %%
guide.median()["probs_x"]

# %%
def model_1(sequences, lengths, emission_matrix, data_dim = 3, batch_size=None, include_prior=True, prediction=False):
    with ignore_jit_warnings():
        num_sequences, max_length = map(int, sequences.shape)
        assert lengths.shape == (num_sequences,)
        assert lengths.max() <= max_length
        


    with poutine.mask(mask=include_prior):
        probs_x = pyro.sample("probs_x",
                              dist.Dirichlet(0.9 * torch.eye(3) + 0.1)
                                  .to_event(1))

    tones_plate = pyro.plate("tones", data_dim, dim=-1)


    with pyro.plate("sequences", len(sequences)):
        length = lengths[i]
        sequence = sequences[i, :length]
        if prediction:
            print(f"{i} {length} {sequence}")
        x = 0
        for t in pyro.markov(range(length)):

            x = pyro.sample("x_{}".format(t), dist.Categorical(probs_x[x]),
                            infer={"enumerate": "parallel"})
            with tones_plate:
                p_y_t = emission_matrix[x]

                pyro.sample("y_{}".format(t), 
                            dist.Categorical(p_y_t),
                            obs=sequence[t])
# Out:
# Warmup:   0%|                                                                                    | 0/600 [01:04, ?it/s]

# %%
nuts_kernel = pyro.infer.NUTS(model_1)
mcmc = pyro.infer.MCMC(nuts_kernel, num_samples=500, warmup_steps=100)
mcmc.run(sequences, lengths, emission, batch_size=batch_size)
# Out:
# Warmup:   0%|                                                                                    | 0/600 [00:00, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-2ba7ffc4b6ee> in <module>
#       1 nuts_kernel = pyro.infer.NUTS(model_1)
#       2 mcmc = pyro.infer.MCMC(nuts_kernel, num_samples=500, warmup_steps=100)
# ----> 3 mcmc.run(sequences, lengths, emission, batch_size=batch_size)
#
# ~\.conda\envs\nic\lib\site-packages\pyro\poutine\messenger.py in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#      13
#      14
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\mcmc\api.py in run(self, *args, **kwargs)
#     385             # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     386             args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 387             for x, chain_id in self.sampler.run(*args, **kwargs):
#     388                 if num_samples[chain_id] == 0:
#     389                     num_samples[chain_id] += 1
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\mcmc\api.py in run(self, *args, **kwargs)
#     169             for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, hook_w_logging,
#     170                                        i if self.num_chains > 1 else None,
# --> 171                                        *args, **kwargs):
#     172                 yield sample, i  # sample, chain_id
#     173             self.kernel.cleanup()
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\mcmc\api.py in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#     111
#     112 def _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs):
# --> 113     kernel.setup(warmup_steps, *args, **kwargs)
#     114     params = kernel.initial_params
#     115     # yield structure (key, value.shape) of params
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\mcmc\hmc.py in setup(self, warmup_steps, *args, **kwargs)
#     300         self._warmup_steps = warmup_steps
#     301         if self.model is not None:
# --> 302             self._initialize_model_properties(args, kwargs)
#     303         if self.initial_params:
#     304             z = {k: v.detach() for k, v in self.initial_params.items()}
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\mcmc\hmc.py in _initialize_model_properties(self, model_args, model_kwargs)
#     252             skip_jit_warnings=self._ignore_jit_warnings,
#     253             init_strategy=self._init_strategy,
# --> 254             initial_params=self._initial_params,
#     255         )
#     256         self.potential_fn = potential_fn
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\mcmc\util.py in initialize_model(model, model_args, model_kwargs, transforms, max_plate_nesting, jit_compile, jit_options, skip_jit_warnings, num_chains, init_strategy, initial_params)
#     380         automatic_transform_enabled = False
#     381     if max_plate_nesting is None:
# --> 382         max_plate_nesting = _guess_max_plate_nesting(model, model_args, model_kwargs)
#     383     # Wrap model in `poutine.enum` to enumerate over discrete latent sites.
#     384     # No-op if model does not have any discrete latents.
#
# ~\.conda\envs\nic\lib\site-packages\pyro\infer\mcmc\util.py in _guess_max_plate_nesting(model, args, kwargs)
#     234     """
#     235     with poutine.block():
# --> 236         model_trace = poutine.trace(model).get_trace(*args, **kwargs)
#     237     sites = [site for site in model_trace.nodes.values()
#     238              if site["type"] == "sample"]
#
# ~\.conda\envs\nic\lib\site-packages\pyro\poutine\trace_messenger.py in get_trace(self, *args, **kwargs)
#     185         Calls this poutine and returns its trace instead of the function's return value.
#     186         """
# --> 187         self(*args, **kwargs)
#     188         return self.msngr.get_trace()
#
# ~\.conda\envs\nic\lib\site-packages\pyro\poutine\trace_messenger.py in __call__(self, *args, **kwargs)
#     163                                       args=args, kwargs=kwargs)
#     164             try:
# --> 165                 ret = self.fn(*args, **kwargs)
#     166             except (ValueError, RuntimeError) as e:
#     167                 exc_type, exc_value, traceback = sys.exc_info()
#
# <ipython-input-40-e5887ffd343e> in model_1(sequences, lengths, emission_matrix, data_dim, batch_size, include_prior, prediction)
#      16
#      17     with pyro.plate("sequences", len(sequences)):
# ---> 18         length = lengths[i]
#      19         sequence = sequences[i, :length]
#      20         if prediction:
#
# NameError: name 'i' is not defined

# %%
mcmc.summary()

# %%
def emission(x):
    return None

# %%
def model_0(sequences, lengths, emission_matrix, args, batch_size=None, include_prior=True):
    with ignore_jit_warnings():
        num_sequences, max_length = map(int, sequences.shape)
        assert lengths.shape == (num_sequences,)
        assert lengths.max() <= max_length
        
    data_dim = 7
    
#     print(sequences)
#     print(lengths)
#     print(num_sequences)
#     print(max_length)


    with poutine.mask(mask=include_prior):
        probs_x = pyro.sample("probs_x",
                              dist.Dirichlet(0.9 * torch.eye(7) + 0.1)
                                  .to_event(1))
        
    with pyro.plate("sequences", num_sequences, batch_size, dim=-2) as batch:
        lengths = lengths[batch]
        
        x = (6* torch.ones(batch_size)).to(torch.int)
        y = (6 * torch.ones(batch_size)).to(torch.int)
        
        for t in pyro.markov(range(max_length if args.jit else lengths.max())):
            with poutine.mask(mask=(t < lengths).unsqueeze(-1)):
#                 print(f"prob_x: {x} {x} {probs_x[x]}")
                x = pyro.sample("x_{}".format(t), dist.Categorical(probs_x[x]),
                                infer={"enumerate": "parallel"})
#                 print(f"prob_x_sampled: {x} {x} {probs_x[x].shape}")
                
                # Note that since each tone depends on all tones at a previous time step
                # the tones at different time steps now need to live in separate plates.
                with pyro.plate("tones_{}".format(t), data_dim, dim=-1):
                    p_y_t = emission_matrix[x]
#                     print(f"p_y_t: {p_y_t.shape}")
                    y = pyro.sample("y_{}".format(t),
                                    dist.Categorical(p_y_t).expand([8, 1]),#.to_event(1),
                                    obs=sequences[batch, t],
                                   )

# %%
# def model_0(sequences, lengths, emission_matrix, args, batch_size=None, include_prior=True, prediction=False):
#     with ignore_jit_warnings():
#         num_sequences, max_length = map(int, sequences.shape)
#         assert lengths.shape == (num_sequences,)
#         assert lengths.max() <= max_length
        
#     data_dim = 7
    
# #     print(sequences)
# #     print(lengths)
# #     print(num_sequences)
# #     print(max_length)


#     with poutine.mask(mask=include_prior):
#         probs_x = pyro.sample("probs_x",
#                               dist.Dirichlet(0.9 * torch.eye(7) + 0.1)
#                                   .to_event(1))

#     tones_plate = pyro.plate("tones", data_dim, dim=-1)


#     for i in pyro.plate("sequences", len(sequences), batch_size):
#         length = lengths[i]
#         sequence = sequences[i, :length]
#         if prediction:
#             print(f"{i} {length} {sequence}")
#         x = 6
#         for t in pyro.markov(range(length)):
#             # On the next line, we'll overwrite the value of x with an updated
#             # value. If we wanted to record all x values, we could instead
#             # write x[t] = pyro.sample(...x[t-1]...).
#             x = pyro.sample("x_{}_{}".format(i, t), dist.Categorical(probs_x[x]),
#                             infer={"enumerate": "parallel"})
#             with tones_plate:
#                 p_y_t = emission_matrix[x]

#                 pyro.sample("y_{}_{}".format(i, t), 
#                             dist.Categorical(p_y_t),
#                             obs=sequence[t])
        
#         for t in pyro.markov(range(max_length if args.jit else lengths.max())):
#             with poutine.mask(mask=(t < lengths).unsqueeze(-1)):
# #                 print(f"prob_x: {x}")
#                 x = pyro.sample("x_{}".format(t), dist.Categorical(probs_x[x]),
#                                 infer={"enumerate": "parallel"})
#                 print(f"prob_x_sampled: {x.shape}")
                
#                 # Note that since each tone depends on all tones at a previous time step
#                 # the tones at different time steps now need to live in separate plates.
#                 with pyro.plate("tones_{}".format(t), data_dim, dim=-1):
#                     p_y_t = emission_matrix[x]
#                     print(f"p_y_t: {p_y_t.shape}")
#                     y = pyro.sample("y_{}".format(t),
#                                     dist.Categorical(p_y_t).expand([8, 1]),#.to_event(1),
#                                     obs=sequences[batch, t],
#                                    )

# %%
def model_0(sequences, lengths, emission_matrix, args, batch_size=None, include_prior=True, prediction=False):
    with ignore_jit_warnings():
        num_sequences, max_length = map(int, sequences.shape)
        assert lengths.shape == (num_sequences,)
        assert lengths.max() <= max_length
        
    data_dim = 7
    
#     print(sequences)
#     print(lengths)
#     print(num_sequences)
#     print(max_length)


    with poutine.mask(mask=include_prior):
        probs_x = pyro.sample("probs_x",
                              dist.Dirichlet(0.9 * torch.eye(7) + 0.1)
                                  .to_event(1))

    tones_plate = pyro.plate("tones", data_dim, dim=-1)


    for i in pyro.plate("sequences", len(sequences)):
        length = lengths[i]
        sequence = sequences[i, :length]
        if prediction:
            print(f"{i} {length} {sequence}")
        x = 6
        for t in pyro.markov(range(length)):
            # On the next line, we'll overwrite the value of x with an updated
            # value. If we wanted to record all x values, we could instead
            # write x[t] = pyro.sample(...x[t-1]...).
            x = pyro.sample("x_{}_{}".format(i, t), dist.Categorical(probs_x[x]),
                            infer={"enumerate": "parallel"})
            with tones_plate:
                p_y_t = emission_matrix[x]

                pyro.sample("y_{}_{}".format(i, t), 
                            dist.Categorical(p_y_t),
                            obs=sequence[t])
        
#         for t in pyro.markov(range(max_length if args.jit else lengths.max())):
#             with poutine.mask(mask=(t < lengths).unsqueeze(-1)):
# #                 print(f"prob_x: {x}")
#                 x = pyro.sample("x_{}".format(t), dist.Categorical(probs_x[x]),
#                                 infer={"enumerate": "parallel"})
#                 print(f"prob_x_sampled: {x.shape}")
                
#                 # Note that since each tone depends on all tones at a previous time step
#                 # the tones at different time steps now need to live in separate plates.
#                 with pyro.plate("tones_{}".format(t), data_dim, dim=-1):
#                     p_y_t = emission_matrix[x]
#                     print(f"p_y_t: {p_y_t.shape}")
#                     y = pyro.sample("y_{}".format(t),
#                                     dist.Categorical(p_y_t).expand([8, 1]),#.to_event(1),
#                                     obs=sequences[batch, t],
#                                    )

# %%
# Utility function to print latent sites' quantile information.
def summary(samples):
    site_stats = {}
    for site_name, values in samples.items():
        marginal_site = pd.DataFrame(values)
        describe = marginal_site.describe(percentiles=[.05, 0.25, 0.5, 0.75, 0.95]).transpose()
        site_stats[site_name] = describe[["mean", "std", "5%", "25%", "50%", "75%", "95%"]]
    return site_stats

# %%
def main(args):
    if args.cuda:
        torch.set_default_tensor_type('torch.cuda.FloatTensor')

    logging.info('Loading data')
    data = load_sequences(args.dataset_path)

    logging.info('-' * 40)
    model = model_0
    logging.info('Training {} on {} sequences'.format(
        model.__name__, len(data['train']['sequences'])))
    
    sequences = data['train']['sequences']
#     print(sequences)
    lengths = data['train']['sequence_lengths']
#     print(lengths)
    
    emission_matrix_np = np.load(args.emission_matrix_path)
    emission_matrix = torch.Tensor(emission_matrix_np)
    # find all the notes that are present at least once in the training set
#     present_notes = ((sequences == 1).sum(0).sum(0) > 0)
    # remove notes that are never played (we remove 37/88 notes)
#     sequences = sequences[..., present_notes]

    if args.truncate:
        lengths = lengths.clamp(max=args.truncate)
        sequences = sequences[:, :args.truncate]
    num_observations = float(lengths.sum())
    pyro.set_rng_seed(args.seed)
    pyro.clear_param_store()

    # We'll train using MAP Baum-Welch, i.e. MAP estimation while marginalizing
    # out the hidden state x. This is accomplished via an automatic guide that
    # learns point estimates of all of our conditional probability tables,
    # named probs_*.
    guide = AutoDelta(poutine.block(model, expose_fn=lambda msg: msg["name"].startswith("probs_")))

    # To help debug our tensor shapes, let's print the shape of each site's
    # distribution, value, and log_prob tensor. Note this information is
    # automatically printed on most errors inside SVI.
#     if args.print_shapes:
    first_available_dim = -2 if model is model_0 else -3
    guide_trace = poutine.trace(guide).get_trace(
        sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size)
    model_trace = poutine.trace(
        poutine.replay(poutine.enum(model, first_available_dim), guide_trace)).get_trace(
        sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size)
    logging.info(model_trace.format_shapes())
    print(model_trace.format_shapes())

    # Enumeration requires a TraceEnum elbo and declaring the max_plate_nesting.
    # All of our models have two plates: "data" and "tones".
    optim = Adam({'lr': args.learning_rate})
    if args.tmc:
        if args.jit:
            raise NotImplementedError("jit support not yet added for TraceTMC_ELBO")
        elbo = TraceTMC_ELBO(max_plate_nesting=1 if model is model_0 else 2)
        tmc_model = poutine.infer_config(
            model,
            lambda msg: {"num_samples": args.tmc_num_samples, "expand": False} if msg["infer"].get("enumerate", None) == "parallel" else {})  # noqa: E501
        svi = SVI(tmc_model, guide, optim, elbo)
    else:
        Elbo = JitTraceEnum_ELBO if args.jit else TraceEnum_ELBO
        elbo = Elbo(max_plate_nesting= 2,
                    strict_enumeration_warning=True,
                    jit_options={"time_compilation": args.time_compilation})
        svi = SVI(model, guide, optim, elbo)

    # We'll train on small minibatches.
    logging.info('Step\tLoss')
    for step in range(args.num_steps):
        print(f"\tTraining step: {step}")
        loss = svi.step(sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size)
        logging.info('{: >5d}\t{}'.format(step, loss / num_observations))
        print('\t{: >5d}\t{}'.format(step, loss / num_observations))
        
    return svi, model, guide, sequences, lengths, emission_matrix

    from pyro.infer import Predictive


    num_samples = 1000
    predictive = Predictive(model, guide=guide, num_samples=num_samples)
    svi_samples = {k: v.detach().cpu().numpy()
               for k, v in predictive(sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size, prediction=True).items()
               if k != "obs"}
    
    print(svi_samples)
    
    for site, values in summary(svi_samples).items():
        print("Site: {}".format(site))
        print(values, "\n")
        

        
    print(pyro.param("probs_x").item())

    if args.jit and args.time_compilation:
        logging.debug('time to compile: {} s.'.format(elbo._differentiable_loss.compile_time))

    # We evaluate on the entire training dataset,
    # excluding the prior term so our results are comparable across models.
    train_loss = elbo.loss(model, guide, sequences, lengths, emission_matrix, args, include_prior=False)
    logging.info('training loss = {}'.format(train_loss / num_observations))
    print('training loss = {}'.format(train_loss / num_observations))

    # We expect models with higher capacity to perform better,
    # but eventually overfit to the training set.
    capacity = sum(value.reshape(-1).size(0)
                   for value in pyro.get_param_store().values())
    logging.info('{} capacity = {} parameters'.format(model.__name__, capacity))
    print('{} capacity = {} parameters'.format(model.__name__, capacity))

# %%
# Content

# %%
assert pyro.__version__.startswith('1.6.0')
parser = argparse.ArgumentParser(description="MAP Baum-Welch learning Bach Chorales")

parser.add_argument("-n", "--num-steps", default=100, type=int)
parser.add_argument("-b", "--batch-size", default=1, type=int)
parser.add_argument("-d", "--hidden-dim", default=16, type=int)
parser.add_argument("-nn", "--nn-dim", default=48, type=int)
parser.add_argument("-nc", "--nn-channels", default=2, type=int)
parser.add_argument("-lr", "--learning-rate", default=0.05, type=float)
parser.add_argument("-t", "--truncate", type=int)
parser.add_argument("-p", "--print-shapes", action="store_true")
parser.add_argument("--seed", default=0, type=int)
parser.add_argument('--cuda', action='store_true')
parser.add_argument('--jit', action='store_true')
parser.add_argument('--time-compilation', action='store_true')
parser.add_argument('-rp', '--raftery-parameterization', action='store_true')
parser.add_argument('--tmc', action='store_true',
                    help="Use Tensor Monte Carlo instead of exact enumeration "
                         "to estimate the marginal likelihood. You probably don't want to do this, "
                         "except to see that TMC makes Monte Carlo gradient estimation feasible "
                         "even with very large numbers of non-reparametrized variables.")
parser.add_argument('--tmc-num-samples', default=10, type=int)

parser.add_argument("--dataset_path")
parser.add_argument("--emission_matrix_path")

# %%
args = parser.parse_args(["--dataset_path", f"{str(dataset_path)}", "--emission_matrix_path", f"{str(emission_matrix_path)}"])

# %%
args

# %%
svi, model, guide, sequences, lengths, emission_matrix = main(args)

# %%
from pyro.infer import Predictive


num_samples = 1000
predictive = Predictive(model, guide=guide, num_samples=num_samples)

# %%
svi_samples = {k: v.detach().cpu().numpy()
           for k, v in predictive(sequences, lengths, emission_matrix, args=args, batch_size=args.batch_size, include_prior=False).items()
           if k != "obs"}

# %%
dir(svi)

# %%
svi_samples["probs_x"].shape

# %%
translation_matrix = np.mean(svi_samples["probs_x"], axis=0).reshape((7,7))

# %%
pyro.get_param_store()

# %%
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}

# %%
confusion_matrix_test_table = pd.DataFrame(
data=translation_matrix,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
test_class_count = confusion_matrix_test_table.sum(axis=1)
test_class_count

# %%
sequences[0,:]

# %%
translation_matrix = np.mean(svi_samples["probs_x"], axis=0).reshape((7,7))

# %%
confusion_matrix_test_table = pd.DataFrame(
data=translation_matrix,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
# Dataset loading
def load_sequences_np(dataset_path):
    sequences = {"train": {}}
    
#     sequence_list = [torch.Tensor(x) for x in np.load(str(dataset_path))]
    
    sequences_tensor = np.load(str(dataset_path))
    
    
    sequences["train"]["sequence_lengths"] = np.array([len(sequence) for sequence in sequences_tensor])
    sequences["train"]["sequences"] = sequences_tensor
    return sequences

# %%
data = load_sequences_np(args.dataset_path)

# %%
sequences = data['train']['sequences']
lengths = data['train']['sequence_lengths']

# %%
sequences.reshape(-1)

# %%
lengths

# %%
emission_matrix_np = np.load(args.emission_matrix_path)

# %%
from hmmlearn import hmm

# %%
model = hmm.MultinomialHMM(n_components=7, n_iter=10000, params="st", init_params="st")

# %%
model.emissionprob_ = emission_matrix_np

# %%
model.fit(sequences.reshape(-1, 1), lengths)

# %%
model.emissionprob_

# %%
model.transmat_

# %%
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}
confusion_matrix_test_table = pd.DataFrame(
data=model.transmat_,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
model = hmm.MultinomialHMM(n_components=7, n_iter=50, params="st", init_params="st")
model.emissionprob_ = emission_matrix_np
model.fit(sequences.reshape(-1, 1), lengths)
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}
confusion_matrix_test_table = pd.DataFrame(
data=model.transmat_,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
model = hmm.MultinomialHMM(n_components=7, n_iter=500, params="st", init_params="st")
model.emissionprob_ = emission_matrix_np
model.fit(sequences.reshape(-1, 1), lengths)
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}
confusion_matrix_test_table = pd.DataFrame(
data=model.transmat_,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
transition_matrix = np.array([[9.17269248e-001, 6.53003806e-118, 8.23362715e-002,
        7.72427778e-085, 1.53698963e-014, 3.43175139e-011,
        3.94480110e-004],
       [1.49172147e-161, 8.73311971e-001, 1.82502958e-049,
        1.26687948e-001, 8.14069900e-008, 1.46260187e-014,
        1.51752796e-026],
       [1.41727846e-003, 1.18840441e-019, 9.49950247e-001,
        1.82914991e-003, 9.07768488e-003, 2.60561958e-002,
        1.16694438e-002],
       [6.51786889e-084, 1.39464295e-002, 1.01244429e-018,
        8.97187712e-001, 8.36640492e-002, 4.86750640e-005,
        5.15313390e-003],
       [6.15269241e-003, 2.86600087e-010, 3.19099140e-002,
        4.01633777e-002, 9.05916897e-001, 1.58571186e-002,
        1.00840900e-032],
       [3.72329494e-005, 5.49847908e-003, 2.38550441e-002,
        3.82597321e-003, 7.01993013e-002, 8.82466367e-001,
        1.41176022e-002],
       [3.63508204e-009, 4.16695519e-002, 1.42071041e-001,
        2.19540222e-032, 6.30280002e-029, 1.49592737e-001,
        6.66666667e-001]])
print(f"HMM transitions")
print(f"Oriented to slanted: {transition_matrix[1, 4] + transition_matrix[3,4]}")
print(f"slanted to oriented: {transition_matrix[4, 1] + transition_matrix[4,3]}")
print(f"unoriented to slanted: {transition_matrix[0, 4] + transition_matrix[2,4]}")
print(f"slanted to unoriented: {transition_matrix[4, 0] + transition_matrix[4,2]}")

# %%
sequences[1, :]

# %%
model.decode(sequences[1,:].reshape(-1,1))

# %%
sequences[0, :]

# %%
model.decode(sequences[0,:].reshape(-1,1))

# %%
naive_transition_matrix = np.zeros((7,7))
for sequence in sequences:
    prev_state = 6
    for state in sequence:
#         print(state)
        naive_transition_matrix[prev_state, state] += 1
        prev_state = state

# %%
classes = {"Not_Oriented": 0, "Oriented": 1, "Precieved_Not_Oriented": 2, "Precieved_Oriented": 3, "Slanted": 4, "Unidentified": 5, "No_sample": 6}
naive_transition_matrix = naive_transition_matrix / np.sum(naive_transition_matrix, axis=1).reshape((-1, 1))
print(naive_transition_matrix.sum(axis=1))

confusion_matrix_test_table = pd.DataFrame(
data=naive_transition_matrix,
index=list(classes.keys()),
columns=list(classes.keys()))
confusion_matrix_test_table

# %%
transition_matrix = naive_transition_matrix
print(f"Naive CNN transitions")
print(f"Oriented to slanted: {transition_matrix[1, 4] + transition_matrix[3,4]}")
print(f"slanted to oriented: {transition_matrix[4, 1] + transition_matrix[4,3]}")
print(f"unoriented to slanted: {transition_matrix[0, 4] + transition_matrix[2,4]}")
print(f"slanted to unoriented: {transition_matrix[4, 0] + transition_matrix[4,2]}")

# %%
X, Z = model.sample(100)

# %%
X

# %%
Z
